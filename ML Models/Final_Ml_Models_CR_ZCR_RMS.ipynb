# %%
# Import the neccessary modules
import pandas as pd
import numpy as np
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Read the dataset into a pandas dataframe, df

# %%
# Read the dataset into a dataframe
df = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# %% [markdown]
# **Drop Non Recquired Columns**

# %%
df
# Out:
#                                                    mfccs  zero_crossing_rate  \
# 0      [-4.7883154e+02  3.3325115e+01 -6.4487829e+00 ...            0.158221
# 1      [-4.8954865e+02  2.7738764e+01 -1.2382742e+01 ...            0.337466
# 2      [-4.35193085e+02  4.40335197e+01 -2.84056549e+...            0.287352
# 3      [-4.5051022e+02  3.5520393e+01 -2.6201200e+01 ...            0.319214
# 4      [-4.7573129e+02  2.5805241e+01 -1.5824142e+01 ...            0.154203
# ...                                                  ...                 ...
# 16851  [-4.0630850e+02  3.8935593e+01  4.7740480e-01 ...            0.251618
# 16852  [-3.3170786e+02  4.6200230e+01  3.0691259e+00 ...            0.337181
# 16853  [-3.7679736e+02  4.1225876e+01  5.9078252e-01 ...            0.247278
# 16854  [-3.2025311e+02  4.7039799e+01  2.6084688e-01 ...            0.333771
# 16855  [-3.8849210e+02  4.5433468e+01 -1.5515751e+00 ...            0.235671
#
#        spectral_bandwidth    chroma       rms class_label  \
# 0             2811.724720  0.432150  0.029986       Angry
# 1             2627.283008  0.583449  0.011966       Angry
# 2             2173.834795  0.537973  0.050250       Angry
# 3             2375.562237  0.547021  0.025544       Angry
# 4             2169.616633  0.471881  0.046953       Angry
# ...                   ...       ...       ...         ...
# 16851         2595.763125  0.489838  0.039640    Surprise
# 16852         2410.996505  0.389710  0.117963    Surprise
# 16853         2594.630202  0.492712  0.052451    Surprise
# 16854         2389.176638  0.392537  0.123277    Surprise
# 16855         2539.527857  0.501296  0.050754    Surprise
#
#                                     file_name      mfcc0      mfcc1  \
# 0                    03-01-03-02-01-01-01.wav -478.83154  33.325115
# 1          03-01-03-02-01-01-01_augmented.wav -489.54865  27.738764
# 2                    03-01-03-02-01-01-02.wav -435.19308  44.033520
# 3          03-01-03-02-01-01-02_augmented.wav -450.51022  35.520393
# 4                    03-01-03-02-01-01-04.wav -475.73130  25.805240
# ...                                       ...        ...        ...
# 16851  M_10_EVAN_S_9_SURPRISE_3_augmented.wav -406.30850  38.935593
# 16852            M_10_EVAN_S_9_SURPRISE_4.wav -331.70786  46.200230
# 16853  M_10_EVAN_S_9_SURPRISE_4_augmented.wav -376.79736  41.225876
# 16854            M_10_EVAN_S_9_SURPRISE_5.wav -320.25310  47.039800
# 16855  M_10_EVAN_S_9_SURPRISE_5_augmented.wav -388.49210  45.433468
#
#            mfcc2  ...    mfcc30    mfcc31    mfcc32    mfcc33    mfcc34  \
# 0      -6.448783  ...  0.328626  2.993545  1.607269  0.753363  0.795460
# 1     -12.382742  ...  3.152687  3.479581  0.999255  0.446273 -0.756348
# 2     -28.405655  ... -0.770171 -0.912993 -0.610560 -1.106990 -0.785358
# 3     -26.201200  ...  0.600577  0.524650  0.813930 -1.485857  0.499522
# 4     -15.824142  ... -1.276900 -2.355503  2.545179 -1.319387  0.711873
# ...          ...  ...       ...       ...       ...       ...       ...
# 16851   0.477405  ... -0.671915 -0.215386  0.026275  0.219410 -0.046814
# 16852   3.069126  ...  2.917920  2.602964  0.847366  0.522375 -0.207175
# 16853   0.590782  ...  1.994877  1.314048  1.387961  0.246608  1.195332
# 16854   0.260847  ...  2.386777  2.104635  0.633636  0.841800  0.382966
# 16855  -1.551575  ...  1.153872  1.444134  1.134689  1.218682 -0.183612
#
#          mfcc35    mfcc36    mfcc37    mfcc38    mfcc39
# 0      0.657204  0.285984  0.347409  0.218164 -0.362225
# 1     -0.987419 -0.684020 -0.347724 -0.050397 -0.133484
# 2     -0.564920 -0.417357  0.537306  0.718312  0.528304
# 3     -0.771937  0.126429  0.860468  0.581919  1.637959
# 4      0.455794 -1.546776  0.536169 -0.651819  0.355566
# ...         ...       ...       ...       ...       ...
# 16851 -2.131241 -2.373210 -1.189148  1.648045  1.386102
# 16852  0.567925  0.032568 -0.259393  0.193821  1.031203
# 16853 -0.975989 -0.565488  0.153799  1.977247  1.530025
# 16854  0.831771 -0.528826 -0.969811 -0.152325  0.219692
# 16855 -0.686899 -1.285852  1.008845  0.933691  0.729580
#
# [16856 rows x 47 columns]

# %%
df_test
# Out:
#                                                  mfccs  zero_crossing_rate  \
# 0    [-3.9012119e+02  4.4109344e+01 -1.2921607e+01 ...            0.084918
# 1    [-4.67160522e+02  2.91869411e+01 -1.70986462e+...            0.391429
# 2    [-3.4629849e+02  2.0243580e+01 -1.1391698e+01 ...            0.120882
# 3    [-3.9613730e+02  4.1812637e+01 -1.2806710e+01 ...            0.149057
# 4    [-4.08084534e+02  3.21562920e+01 -1.13426485e+...            0.128189
# ..                                                 ...                 ...
# 934  [-3.15789490e+02  4.11579781e+01 -4.66505718e+...            0.368006
# 935  [-3.0825998e+02  4.2420658e+01 -3.6246645e+00 ...            0.344019
# 936  [-2.97977112e+02  3.52298622e+01 -1.60021079e+...            0.375373
# 937  [-3.0559796e+02  3.6652721e+01 -9.1293299e-01 ...            0.360817
# 938  [-3.4388855e+02  3.9960506e+01  1.3614115e+00 ...            0.372584
#
#      spectral_bandwidth    chroma       rms class_label  \
# 0           2010.457276  0.467693  0.075098       Angry
# 1           2372.973040  0.412228  0.035136       Angry
# 2           2457.125273  0.414273  0.125970       Angry
# 3           2480.510451  0.512132  0.080969       Angry
# 4           2642.601731  0.450778  0.046662       Angry
# ..                  ...       ...       ...         ...
# 934         2421.570717  0.378931  0.104968    Surprise
# 935         2396.946955  0.391811  0.113606    Surprise
# 936         2483.153256  0.394186  0.136011    Surprise
# 937         2486.361872  0.385032  0.128843    Surprise
# 938         2388.725618  0.383467  0.112313    Surprise
#
#                         file_name      mfcc0      mfcc1      mfcc2  ...  \
# 0        03-01-03-02-01-01-03.wav -390.12120  44.109344 -12.921607  ...
# 1        03-01-03-02-01-01-14.wav -467.16052  29.186941 -17.098646  ...
# 2        03-01-03-02-01-01-30.wav -346.29850  20.243580 -11.391698  ...
# 3        03-01-03-02-01-02-25.wav -396.13730  41.812637 -12.806710  ...
# 4        03-01-03-02-01-03-01.wav -408.08453  32.156292 -11.342648  ...
# ..                            ...        ...        ...        ...  ...
# 934  M_10_EVAN_S_5_SURPRISE_3.wav -315.78950  41.157978  -4.665057  ...
# 935  M_10_EVAN_S_5_SURPRISE_4.wav -308.25998  42.420660  -3.624665  ...
# 936  M_10_EVAN_S_6_SURPRISE_2.wav -297.97710  35.229862  -1.600211  ...
# 937  M_10_EVAN_S_6_SURPRISE_5.wav -305.59796  36.652720  -0.912933  ...
# 938  M_10_EVAN_S_9_SURPRISE_2.wav -343.88855  39.960506   1.361411  ...
#
#        mfcc30    mfcc31    mfcc32    mfcc33    mfcc34    mfcc35    mfcc36  \
# 0    0.450648  2.404330  2.840697  4.679700  3.358691  2.829290  2.049688
# 1    2.546051 -0.345007  1.761566  0.331160 -0.264679 -0.082578 -0.519460
# 2    1.983120  2.254916 -0.430221  0.366129 -0.073306 -0.460280  0.677957
# 3    5.819712  1.589295  0.174151 -1.593609  1.364120  1.444026  0.774227
# 4   -1.079431  2.334728 -0.123283  0.738071 -1.139498 -0.480123  1.070031
# ..        ...       ...       ...       ...       ...       ...       ...
# 934  1.781141  2.212446  0.255170  0.355328 -0.191172  0.538170 -0.836946
# 935  1.077347  1.734812 -0.640567  0.225346 -0.893579  0.445937 -0.518387
# 936 -0.261475  1.704446  0.119918  2.339397  0.122162  0.819136  0.680564
# 937 -0.964675  1.582144  0.123939  1.008998 -0.414467  1.555154  1.006149
# 938  2.973702  1.852571 -0.603280  1.001840  1.788876  2.220832  0.560587
#
#        mfcc37    mfcc38    mfcc39
# 0   -0.031819  1.511454  1.466245
# 1   -0.226637 -2.060637 -0.626951
# 2    1.134820 -1.294887  0.309249
# 3    0.248576 -1.265227  0.026068
# 4    0.191624  1.218494  1.468383
# ..        ...       ...       ...
# 934 -0.600881 -0.154892 -0.400183
# 935  1.034477  1.081573  0.678320
# 936  0.174210 -0.836902 -0.645632
# 937  0.085300  0.355210  1.037921
# 938 -0.403364  0.905810  1.237246
#
# [939 rows x 47 columns]

# %%
       """   'zero_crossing_rate',
                'spectral_bandwidth',
                #'chroma',
                'rms',
                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
                """
# Out:
# "   'zero_crossing_rate',\n         'spectral_bandwidth',\n         #'chroma',\n         'rms',\n         'mfcc0',\n         'mfcc1',\n         'mfcc2',\n         'mfcc3',\n         'mfcc4',\n         'mfcc5',\n         'mfcc6',\n         'mfcc7',\n         'mfcc8',\n         'mfcc9',\n         'mfcc10',\n         'mfcc11',\n         'mfcc12',\n         'mfcc13',\n         'mfcc14',\n         'mfcc15',\n         'mfcc16',\n         'mfcc17',\n         'mfcc18',\n         'mfcc19',\n         'mfcc20',\n           'mfcc21',\n             'mfcc22',\n               'mfcc23',\n                  'mfcc24',\n                    'mfcc25',\n                      'mfcc26',\n                        'mfcc27',\n                          'mfcc28',\n                            'mfcc29',\n                              'mfcc30',\n                                'mfcc31',\n                                  'mfcc32',\n                                    'mfcc33',\n                                        'mfcc34',\n                                          'mfcc35',\n                                            'mfcc36',\n                                              'mfcc37',\n                                                'mfcc38',\n                                                  'mfcc39',\n         "

# %%
# Drop some columns which is not relevant to the analysis (they are not numeric)
cols_to_drop=['file_name',
              'mfccs',
              'spectral_bandwidth',

            #'zero_crossing_rate',

            #'chroma',
             # 'rms',


                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
              ]

df = df.drop(cols_to_drop, axis=1)



df_test = df_test.drop(cols_to_drop, axis=1)

# %%
df_test
# Out:
#      zero_crossing_rate    chroma       rms class_label
# 0              0.084918  0.467693  0.075098       Angry
# 1              0.391429  0.412228  0.035136       Angry
# 2              0.120882  0.414273  0.125970       Angry
# 3              0.149057  0.512132  0.080969       Angry
# 4              0.128189  0.450778  0.046662       Angry
# ..                  ...       ...       ...         ...
# 934            0.368006  0.378931  0.104968    Surprise
# 935            0.344019  0.391811  0.113606    Surprise
# 936            0.375373  0.394186  0.136011    Surprise
# 937            0.360817  0.385032  0.128843    Surprise
# 938            0.372584  0.383467  0.112313    Surprise
#
# [939 rows x 4 columns]

# %% [markdown]
# **Label Mapping**

# %%
import pandas as pd

# Sample DataFrame

# Anger, Disgust, Fear, Happiness, Neutral, Sadness and Surprise
# Define a dictionary to map old labels to new labels
label_mapping = {'Happy': '0','Surprise': '1','Angry': '2','Sad': '3','Fear': '4','Disgust': '5','Neutral': '6' }

# Use the map method to change class labels
df['class_label'] = df['class_label'].replace(label_mapping)
df_test['class_label'] = df_test['class_label'].replace(label_mapping)
# Display the updated DataFrame
print(df)
print(df_test)
# Out:
#        zero_crossing_rate    chroma       rms class_label
# 0                0.158221  0.432150  0.029986           2
# 1                0.337466  0.583449  0.011966           2
# 2                0.287352  0.537973  0.050250           2
# 3                0.319214  0.547021  0.025544           2
# 4                0.154203  0.471881  0.046953           2
# ...                   ...       ...       ...         ...
# 16851            0.251618  0.489838  0.039640           1
# 16852            0.337181  0.389710  0.117963           1
# 16853            0.247278  0.492712  0.052451           1
# 16854            0.333771  0.392537  0.123277           1
# 16855            0.235671  0.501296  0.050754           1
#
# [16856 rows x 4 columns]
#      zero_crossing_rate    chroma       rms class_label
# 0              0.084918  0.467693  0.075098           2
# 1              0.391429  0.412228  0.035136           2
# 2              0.120882  0.414273  0.125970           2
# 3              0.149057  0.512132  0.080969           2
# 4              0.128189  0.450778  0.046662           2
# ..                  ...       ...       ...         ...
# 934            0.368006  0.378931  0.104968           1
# 935            0.344019  0.391811  0.113606           1
# 936            0.375373  0.394186  0.136011           1
# 937            0.360817  0.385032  0.128843           1
# 938            0.372584  0.383467  0.112313           1
#
# [939 rows x 4 columns]

# %%
# Seperate the dataframe into X and y data
X = df.values
y = df['class_label'].values

# Delete the Survived column from X
X=df.drop('class_label', axis=1).values

# separate X and y for validation




Vx=df_test.values
Vy=df_test['class_label'].values
Vx= df_test.drop('class_label', axis=1).values

# %%
print(Vx)
# Out:
# [[0.08491834 0.46769324 0.07509841]
#  [0.39142943 0.41222763 0.03513578]
#  [0.1208824  0.41427264 0.1259701 ]
#  ...
#  [0.37537323 0.39418566 0.13601114]
#  [0.36081739 0.3850317  0.12884307]
#  [0.37258385 0.3834674  0.11231343]]

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {'0': 2710, '1': 2350, '2': 2710, '3': 2710, '4': 1800, '5': 2160, '6': 2416}

# %% [markdown]
# Using SMOTE to OverSample Training Data Only

# %%
import numpy as np
from imblearn.over_sampling import SMOTE

# Assuming you have a dataset with features X and labels y


# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X = X.astype(np.float32)
y = y.astype(np.float32)
# Fit and transform the data
X,y = smote.fit_resample(X, y)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X = scaler.fit_transform(X)

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {0.0: 2710, 1.0: 2710, 2.0: 2710, 3.0: 2710, 4.0: 2710, 5.0: 2710, 6.0: 2710}

# %%
print(X.shape)
print(y.shape)
print(Vx.shape)
print(Vy.shape)
# Out:
# (18970, 3)
# (18970,)
# (939, 3)
# (939,)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Perform Classification Using Decision Tree Classifier**

# %%
# Using simple Decision Tree classifier
from sklearn import tree
dt_clf = tree.DecisionTreeClassifier(max_depth=100,random_state=42,criterion='entropy',splitter='best')
dt_clf.fit(X, y)

print(dt_clf.score(X, y))
print(dt_clf.score(Vx, Vy))


prediction_test=dt_clf.predict(Vx)



Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 1.0
# 0.2822151224707135
# Accuracy =  0.2822151224707135
# Precision =  0.2834611832756736
# Recall =  0.2822151224707135
# F1_Score =  0.28230679891285254

# %%
print(Vx.shape)
print(Vy.shape)
print(X.shape)
print(y.shape)
# Out:
# (939, 3)
# (939,)
# (18970, 3)
# (18970,)

# %% [markdown]
# **Perform Classification Using Random Forest Classifier**
#
# Now, we would see if we could get a better results using the the Random Forests Classifier.

# %%
from sklearn import ensemble
rf_clf = ensemble.RandomForestClassifier(n_estimators=100,random_state=42,max_features="sqrt")
rf_clf.fit(X, y)



prediction_test=rf_clf.predict(Vx)

Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.3365282215122471
# Precision =  0.33661463736814057
# Recall =  0.3365282215122471
# F1_Score =  0.33521943655070147

# %% [markdown]
# Ada boost classifier

# %%
ada_clf = ensemble.AdaBoostClassifier(n_estimators=50,learning_rate=0.001,random_state=42)
ada_clf.fit(X, y)
ada_clf.score(Vx, Vy)




prediction_test=ada_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.17252396166134185
# Precision =  0.060811194518000954
# Recall =  0.17252396166134185
# F1_Score =  0.07769808160467816
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Perform Classification Using Gradient Boosting Classifier**
#
# This classifier is available in the ensemble module which we already imported. So we don’t need to import anything

# %%
gb_clf = ensemble.GradientBoostingClassifier(n_estimators=30,max_depth=5,max_features=2,learning_rate=0.001)
gb_clf.fit(X, y)
gb_clf.score(Vx,Vy)

print(dt_clf.score(Vx, Vy))


prediction_test=gb_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.2822151224707135
# Accuracy =  0.3258785942492013
# Precision =  0.32973195672635486
# Recall =  0.3258785942492013
# F1_Score =  0.30915585012694263

# %%
from sklearn.neighbors import KNeighborsClassifier

# create knn classifier
knn = KNeighborsClassifier(n_neighbors = 19)
knn.fit(X, y)
knn.score(X, y)

print(knn.score(Vx, Vy))


prediction_test=knn.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.35676251331203407
# Accuracy =  0.35676251331203407
# Precision =  0.3695004894122643
# Recall =  0.35676251331203407
# F1_Score =  0.3589669895220457

# %%
import joblib
joblib.dump(rf_clf, "rf_Zcr.joblib")
# Out:
# ['rf_Zcr.joblib']

# %%
import joblib
joblib.dump(dt_clf, "dt_Zcr.joblib")
joblib.dump(gb_clf, "rf_Zcr.joblib")
joblib.dump(knn, "rf_Zcr.joblib")
joblib.dump(rf_clf, "rf_Zcr.joblib")
joblib.dump(ada_clf, "rf_Zcr.joblib")
# Out:
# ['dt_Zcr.joblib']

# %% [markdown]
# **LSTM,BI-LSTM model**

# %% [markdown]
# **Bi_lstm
# **

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data



df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# Drop irrelevant columns

df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for BI-LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# BI-LSTM Model
bilstm = Sequential()
bilstm.add(Bidirectional(LSTM(100, return_sequences=True), input_shape=(X_reshaped.shape[1], X_reshaped.shape[2])))  # Set return_sequences=True
bilstm.add(Dropout(0.1))
bilstm.add(Bidirectional(LSTM(50)))  # This layer now receives 3D input as expected
bilstm.add(Dropout(0.1))




bilstm.add(Dense(y_categorical.shape[1], activation='softmax'))














bilstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])






# Train the model
history = bilstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)









# Evaluate the model on the test set
y_pred = bilstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall=metrics.recall_score(y_test, y_pred_classes, average='weighted')



print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 13s 28ms/step - loss: 1.8275 - accuracy: 0.2762 - val_loss: 2.8847 - val_accuracy: 0.0556
# Epoch 2/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.7230 - accuracy: 0.3012 - val_loss: 3.1884 - val_accuracy: 0.0459
# Epoch 3/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.7060 - accuracy: 0.3032 - val_loss: 3.2169 - val_accuracy: 0.0525
# Epoch 4/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6984 - accuracy: 0.3055 - val_loss: 3.2683 - val_accuracy: 0.0451
# Epoch 5/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.6933 - accuracy: 0.3062 - val_loss: 3.2735 - val_accuracy: 0.0300
# Epoch 6/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.6897 - accuracy: 0.3067 - val_loss: 3.2876 - val_accuracy: 0.0461
# Epoch 7/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6881 - accuracy: 0.3032 - val_loss: 3.2718 - val_accuracy: 0.0527
# Epoch 8/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.6867 - accuracy: 0.3048 - val_loss: 3.2864 - val_accuracy: 0.0419
# Epoch 9/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6832 - accuracy: 0.3075 - val_loss: 3.2239 - val_accuracy: 0.0419
# Epoch 10/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6821 - accuracy: 0.3083 - val_loss: 3.2388 - val_accuracy: 0.0419
# Epoch 11/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6795 - accuracy: 0.3081 - val_loss: 3.2662 - val_accuracy: 0.0416
# Epoch 12/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.6766 - accuracy: 0.3075 - val_loss: 3.2932 - val_accuracy: 0.0514
# Epoch 13/120
# 119/119 [==============================] - 3s 25ms/step - loss: 1.6741 - accuracy: 0.3089 - val_loss: 3.2393 - val_accuracy: 0.0464
# Epoch 14/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6697 - accuracy: 0.3086 - val_loss: 3.3285 - val_accuracy: 0.0424
# Epoch 15/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6681 - accuracy: 0.3114 - val_loss: 3.2528 - val_accuracy: 0.0683
# Epoch 16/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6661 - accuracy: 0.3104 - val_loss: 3.2453 - val_accuracy: 0.0659
# Epoch 17/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6633 - accuracy: 0.3105 - val_loss: 3.2590 - val_accuracy: 0.0540
# Epoch 18/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6622 - accuracy: 0.3153 - val_loss: 3.1919 - val_accuracy: 0.0735
# Epoch 19/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.6572 - accuracy: 0.3167 - val_loss: 3.1986 - val_accuracy: 0.0501
# Epoch 20/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.6548 - accuracy: 0.3188 - val_loss: 3.2428 - val_accuracy: 0.0627
# Epoch 21/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1
120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.5648 - accuracy: 0.3643 - val_loss: 3.3659 - val_accuracy: 0.1017
# Epoch 100/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.5642 - accuracy: 0.3662 - val_loss: 3.3884 - val_accuracy: 0.1020
# Epoch 101/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5646 - accuracy: 0.3658 - val_loss: 3.3444 - val_accuracy: 0.1031
# Epoch 102/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5634 - accuracy: 0.3740 - val_loss: 3.3819 - val_accuracy: 0.0986
# Epoch 103/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.5640 - accuracy: 0.3654 - val_loss: 3.3926 - val_accuracy: 0.0920
# Epoch 104/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.5628 - accuracy: 0.3670 - val_loss: 3.3890 - val_accuracy: 0.1052
# Epoch 105/120
# 119/119 [==============================] - 3s 27ms/step - loss: 1.5621 - accuracy: 0.3680 - val_loss: 3.3528 - val_accuracy: 0.1036
# Epoch 106/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.5618 - accuracy: 0.3696 - val_loss: 3.4077 - val_accuracy: 0.1062
# Epoch 107/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5636 - accuracy: 0.3657 - val_loss: 3.3919 - val_accuracy: 0.0991
# Epoch 108/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5586 - accuracy: 0.3711 - val_loss: 3.3965 - val_accuracy: 0.0978
# Epoch 109/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.5585 - accuracy: 0.3677 - val_loss: 3.3865 - val_accuracy: 0.1044
# Epoch 110/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5591 - accuracy: 0.3700 - val_loss: 3.3665 - val_accuracy: 0.1015
# Epoch 111/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.5586 - accuracy: 0.3716 - val_loss: 3.3300 - val_accuracy: 0.0988
# Epoch 112/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.5572 - accuracy: 0.3685 - val_loss: 3.3259 - val_accuracy: 0.0991
# Epoch 113/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.5594 - accuracy: 0.3688 - val_loss: 3.3446 - val_accuracy: 0.0994
# Epoch 114/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5564 - accuracy: 0.3713 - val_loss: 3.3629 - val_accuracy: 0.1023
# Epoch 115/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5556 - accuracy: 0.3724 - val_loss: 3.3887 - val_accuracy: 0.1041
# Epoch 116/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5579 - accuracy: 0.3681 - val_loss: 3.3749 - val_accuracy: 0.1073
# Epoch 117/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.5546 - accuracy: 0.3687 - val_loss: 3.4047 - val_accuracy: 0.1049
# Epoch 118/120
# 119/119 [==============================] - 5s 42ms/step - loss: 1.5569 - accuracy: 0.3692 - val_loss: 3.3796 - val_accuracy: 0.1107
# Epoch 119/120
# 119/119 [==============================] - 3s 25ms/step - loss: 1.5546 - accuracy: 0.3703 - val_loss: 3.3986 - val_accuracy: 0.1046
# Epoch 120/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5527 - accuracy: 0.3745 - val_loss: 3.3878 - val_accuracy: 0.1007
# 30/30 [==============================] - 2s 3ms/step
# Accuracy = 0.3301384451544196
# Precision = 0.27768565128631
# Recall = 0.3301384451544196
# F1 Score = 0.294769074322413

# %% [markdown]
# ***bi-lstm***

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data

df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')




df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# LSTM Model
lstm = Sequential()
lstm.add(LSTM(100, input_shape=(X_reshaped.shape[1], X_reshaped.shape[2]), return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(50, return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(20))
lstm.add(Dropout(0.1))

lstm.add(Dense(y_categorical.shape[1], activation='softmax'))

lstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])





# Train the model
history = lstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)







# Evaluate the model on the test set
y_pred = lstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall = metrics.recall_score(y_test, y_pred_classes, average='weighted')

print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 10s 22ms/step - loss: 1.8905 - accuracy: 0.2301 - val_loss: 2.6890 - val_accuracy: 0.0358
# Epoch 2/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.7632 - accuracy: 0.2847 - val_loss: 2.9951 - val_accuracy: 0.0364
# Epoch 3/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7267 - accuracy: 0.2987 - val_loss: 3.1150 - val_accuracy: 0.0453
# Epoch 4/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.7157 - accuracy: 0.3026 - val_loss: 3.1656 - val_accuracy: 0.0393
# Epoch 5/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.7104 - accuracy: 0.3022 - val_loss: 3.1417 - val_accuracy: 0.0372
# Epoch 6/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.7058 - accuracy: 0.3046 - val_loss: 3.1621 - val_accuracy: 0.0509
# Epoch 7/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7019 - accuracy: 0.3065 - val_loss: 3.1193 - val_accuracy: 0.0469
# Epoch 8/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6980 - accuracy: 0.3018 - val_loss: 3.2072 - val_accuracy: 0.0438
# Epoch 9/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6969 - accuracy: 0.3053 - val_loss: 3.1441 - val_accuracy: 0.0517
# Epoch 10/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6949 - accuracy: 0.3058 - val_loss: 3.1374 - val_accuracy: 0.0435
# Epoch 11/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6923 - accuracy: 0.3046 - val_loss: 3.1633 - val_accuracy: 0.0506
# Epoch 12/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6902 - accuracy: 0.3038 - val_loss: 3.1845 - val_accuracy: 0.0451
# Epoch 13/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.
120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6269 - accuracy: 0.3363 - val_loss: 3.2055 - val_accuracy: 0.0725
# Epoch 42/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6274 - accuracy: 0.3369 - val_loss: 3.2320 - val_accuracy: 0.0693
# Epoch 43/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6248 - accuracy: 0.3364 - val_loss: 3.2084 - val_accuracy: 0.0662
# Epoch 44/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.6260 - accuracy: 0.3390 - val_loss: 3.1839 - val_accuracy: 0.0693
# Epoch 45/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.6249 - accuracy: 0.3395 - val_loss: 3.1894 - val_accuracy: 0.0683
# Epoch 46/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6245 - accuracy: 0.3391 - val_loss: 3.1825 - val_accuracy: 0.0720
# Epoch 47/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6224 - accuracy: 0.3366 - val_loss: 3.2494 - val_accuracy: 0.0727
# Epoch 48/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6218 - accuracy: 0.3393 - val_loss: 3.2276 - val_accuracy: 0.0730
# Epoch 49/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6209 - accuracy: 0.3390 - val_loss: 3.2218 - val_accuracy: 0.0738
# Epoch 50/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6195 - accuracy: 0.3415 - val_loss: 3.2186 - val_accuracy: 0.0677
# Epoch 51/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6168 - accuracy: 0.3440 - val_loss: 3.2146 - val_accuracy: 0.0651
# Epoch 52/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.6185 - accuracy: 0.3403 - val_loss: 3.2055 - val_accuracy: 0.0704
# Epoch 53/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.6178 - accuracy: 0.3409 - val_loss: 3.2079 - val_accuracy: 0.0701
# Epoch 54/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.6188 - accuracy: 0.3394 - val_loss: 3.1982 - val_accuracy: 0.0688
# Epoch 55/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6169 - accuracy: 0.3378 - val_loss: 3.1880 - val_accuracy: 0.0791
# Epoch 56/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6151 - accuracy: 0.3385 - val_loss: 3.1893 - val_accuracy: 0.0714
# Epoch 57/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6153 - accuracy: 0.3461 - val_loss: 3.2002 - val_accuracy: 0.0730
# Epoch 58/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6157 - accuracy: 0.3399 - val_loss: 3.2131 - val_accuracy: 0.0725
# Epoch 59/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6109 - accuracy: 0.3419 - val_loss: 3.2197 - val_accuracy: 0.0683
# Epoch 60/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6124 - accuracy: 0.3424 - val_loss: 3.2010 - val_accuracy: 0.0683
# Epoch 61/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6140 - accuracy: 0.3440 - val_loss: 3.1710 - val_accuracy: 0.0696
# Epoch 62/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6122 - accuracy: 0.3439 - val_loss: 3.2308 - val_accuracy: 0.0664
# Epoch 63/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.6117 - accuracy: 0.3435 - val_loss: 3.2267 - val_accuracy: 0.0759
# Epoch 64/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.6096 - accuracy: 0.3459 - val_loss: 3.2395 - val_accuracy: 0.0733
# Epoch 65/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6106 - accuracy: 0.3480 - val_loss: 3.2315 - val_accuracy: 0.0712
# Epoch 66/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6084 - accuracy: 0.3437 - val_loss: 3.2253 - val_accuracy: 0.0749
# Epoch 67/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6063 - accuracy: 0.3445 - val_loss: 3.2033 - val_accuracy: 0.0785
# Epoch 68/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6077 - accuracy: 0.3430 - val_loss: 3.2132 - val_accuracy: 0.0717
# Epoch 69/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6088 - accuracy: 0.3432 - val_loss: 3.2113 - val_accuracy: 0.0709
# Epoch 70/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6065 - accuracy: 0.3458 - val_loss: 3.2133 - val_accuracy: 0.0717
# Epoch 71/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6064 - accuracy: 0.3457 - val_loss: 3.2484 - val_accuracy: 0.0756
# Epoch 72/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6059 - accuracy: 0.3414 - val_loss: 3.2312 - val_accuracy: 0.0622
# Epoch 73/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.6037 - accuracy: 0.3451 - val_loss: 3.2378 - val_accuracy: 0.0767
# Epoch 74/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.6018 - accuracy: 0.3484 - val_loss: 3.2311 - val_accuracy: 0.0738
# Epoch 75/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6049 - accuracy: 0.3453 - val_loss: 3.2609 - val_accuracy: 0.0685
# Epoch 76/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.6021 - accuracy: 0.3427 - val_loss: 3.2331 - val_accuracy: 0.0688
# Epoch 77/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6012 - accuracy: 0.3496 - val_loss: 3.2360 - val_accuracy: 0.0635
# Epoch 78/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5996 - accuracy: 0.3483 - val_loss: 3.2449 - val_accuracy: 0.0770
# Epoch 79/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5971 - accuracy: 0.3487 - val_loss: 3.2390 - val_accuracy: 0.0691
# Epoch 80/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.6000 - accuracy: 0.3497 - val_loss: 3.2515 - val_accuracy: 0.0717
# Epoch 81/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5986 - accuracy: 0.3448 - val_loss: 3.2593 - val_accuracy: 0.0814
# Epoch 82/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.5963 - accuracy: 0.3492 - val_loss: 3.2341 - val_accuracy: 0.0746
# Epoch 83/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.5989 - accuracy: 0.3511 - val_loss: 3.2327 - val_accuracy: 0.0696
# Epoch 84/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.5982 - accuracy: 0.3476 - val_loss: 3.2300 - val_accuracy: 0.0685
# Epoch 85/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5975 - accuracy: 0.3490 - val_loss: 3.2311 - val_accuracy: 0.0733
# Epoch 86/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5964 - accuracy: 0.3538 - val_loss: 3.2045 - val_accuracy: 0.0709
# Epoch 87/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5969 - accuracy: 0.3483 - val_loss: 3.2743 - val_accuracy: 0.0714
# Epoch 88/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5972 - accuracy: 0.3479 - val_loss: 3.2258 - val_accuracy: 0.0778
# Epoch 89/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5976 - accuracy: 0.3475 - val_loss: 3.2720 - val_accuracy: 0.0712
# Epoch 90/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5949 - accuracy: 0.3508 - val_loss: 3.2766 - val_accuracy: 0.0730
# Epoch 91/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5951 - accuracy: 0.3478 - val_loss: 3.2474 - val_accuracy: 0.0820
# Epoch 92/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.5972 - accuracy: 0.3497 - val_loss: 3.2628 - val_accuracy: 0.0749
# Epoch 93/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.5942 - accuracy: 0.3504 - val_loss: 3.2769 - val_accuracy: 0.0770
# Epoch 94/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.5924 - accuracy: 0.3481 - val_loss: 3.2801 - val_accuracy: 0.0788
# Epoch 95/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.5940 - accuracy: 0.3500 - val_loss: 3.2754 - val_accuracy: 0.0727
# Epoch 96/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5905 - accuracy: 0.3528 - val_loss: 3.2629 - val_accuracy: 0.0712
# Epoch 97/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5911 - accuracy: 0.3507 - val_loss: 3.2720 - val_accuracy: 0.0814
# Epoch 98/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5935 - accuracy: 0.3492 - val_loss: 3.2648 - val_accuracy: 0.0709
# Epoch 99/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5955 - accuracy: 0.3486 - val_loss: 3.2507 - val_accuracy: 0.0767
# Epoch 100/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5928 - accuracy: 0.3511 - val_loss: 3.2608 - val_accuracy: 0.0759
# Epoch 101/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.5943 - accuracy: 0.3484 - val_loss: 3.2364 - val_accuracy: 0.0754
# Epoch 102/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.5889 - accuracy: 0.3510 - val_loss: 3.2840 - val_accuracy: 0.0772
# Epoch 103/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5916 - accuracy: 0.3546 - val_loss: 3.2598 - val_accuracy: 0.0812
# Epoch 104/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5896 - accuracy: 0.3507 - val_loss: 3.2500 - val_accuracy: 0.0807
# Epoch 105/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5871 - accuracy: 0.3515 - val_loss: 3.2734 - val_accuracy: 0.0799
# Epoch 106/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5890 - accuracy: 0.3584 - val_loss: 3.2568 - val_accuracy: 0.0772
# Epoch 107/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5874 - accuracy: 0.3535 - val_loss: 3.2691 - val_accuracy: 0.0799
# Epoch 108/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5864 - accuracy: 0.3546 - val_loss: 3.2949 - val_accuracy: 0.0862
# Epoch 109/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5909 - accuracy: 0.3492 - val_loss: 3.3106 - val_accuracy: 0.0785
# Epoch 110/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5864 - accuracy: 0.3563 - val_loss: 3.2953 - val_accuracy: 0.0785
# Epoch 111/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.5900 - accuracy: 0.3547 - val_loss: 3.3114 - val_accuracy: 0.0772
# Epoch 112/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.5863 - accuracy: 0.3531 - val_loss: 3.2650 - val_accuracy: 0.0793
# Epoch 113/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.5847 - accuracy: 0.3567 - val_loss: 3.2662 - val_accuracy: 0.0841
# Epoch 114/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5853 - accuracy: 0.3563 - val_loss: 3.3388 - val_accuracy: 0.0846
# Epoch 115/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5845 - accuracy: 0.3561 - val_loss: 3.3003 - val_accuracy: 0.0833
# Epoch 116/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5807 - accuracy: 0.3571 - val_loss: 3.2972 - val_accuracy: 0.0836
# Epoch 117/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5833 - accuracy: 0.3581 - val_loss: 3.2984 - val_accuracy: 0.0843
# Epoch 118/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5826 - accuracy: 0.3554 - val_loss: 3.2668 - val_accuracy: 0.0791
# Epoch 119/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.5850 - accuracy: 0.3502 - val_loss: 3.2830 - val_accuracy: 0.0836
# Epoch 120/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.5810 - accuracy: 0.3562 - val_loss: 3.2762 - val_accuracy: 0.0807
# 30/30 [==============================] - 1s 3ms/step
# Accuracy = 0.31735889243876464
# Precision = 0.30678087015771843
# Recall = 0.31735889243876464
# F1 Score = 0.28390746801136074

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# 1. Make predictions with each model and convert them to integers
dt_predictions = dt_clf.predict(Vx).astype(int)
rf_predictions = rf_clf.predict(Vx).astype(int)
ada_predictions = ada_clf.predict(Vx).astype(int)
gb_predictions = gb_clf.predict(Vx).astype(int)
knn_predictions = knn.predict(Vx).astype(int)





lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)


lstm_probs = np.argmax(lstm_probs, axis=1)
bilstm_probs = np.argmax(bilstm_probs, axis=1)


# 2. Aggregate predictions for hard voting
predictions = np.array([dt_predictions, rf_predictions, ada_predictions, gb_predictions, knn_predictions,lstm_probs,bilstm_probs])

# 3. Perform hard voting
hard_votes = np.apply_along_axis(lambda x: np.bincount(x, minlength=len(np.unique(predictions))).argmax(), arr=predictions, axis=0)

# 4. Evaluate hard voting ensemble
hard_voting_accuracy = np.mean(hard_votes == Vy)
print("Hard Voting Accuracy:", hard_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, hard_votes, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, hard_votes, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, hard_votes, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step
# Hard Voting Accuracy: 0.3343982960596379
# Precision: 0.33751312539793965
# Recall: 0.3343982960596379
# F1 Score: 0.3283686309912158

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
dt_probs = dt_clf.predict_proba(Vx)
rf_probs = rf_clf.predict_proba(Vx)
ada_probs = ada_clf.predict_proba(Vx)
gb_probs = gb_clf.predict_proba(Vx)
knn_probs = knn.predict_proba(Vx)


lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)




# KNN should already be able to predict probabilities, but if not, adjustments might be needed.

# 2. Aggregate probabilities for soft voting
probabilities = np.array([dt_probs, rf_probs, ada_probs, gb_probs,knn_probs,lstm_probs,bilstm_probs])

# 3. Perform soft voting
soft_votes = np.mean(probabilities, axis=0)

# 4. Determine the final prediction based on the highest probability
soft_voting_predictions = np.argmax(soft_votes, axis=1)

# 5. Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy:", soft_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, soft_voting_predictions, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, soft_voting_predictions, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, soft_voting_predictions, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 11ms/step
# Soft Voting Accuracy: 0.8242811501597445
# Precision: 0.8295611840760729
# Recall: 0.8242811501597445
# F1 Score: 0.8169353991058335

# %%
# Combine all soft predictions



all_soft_predictions = np.mean(np.array([
    dt_probs, rf_probs, ada_probs, gb_probs,  # Assuming these models provide class probabilities
    lstm_probs, bilstm_probs
]), axis=0)

# Perform soft voting
soft_voting_predictions = np.argmax(all_soft_predictions, axis=1)

# Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy with LSTM and Bi-LSTM:", soft_voting_accuracy)
# Out:
# Soft Voting Accuracy with LSTM and Bi-LSTM: 0.8008519701810437
