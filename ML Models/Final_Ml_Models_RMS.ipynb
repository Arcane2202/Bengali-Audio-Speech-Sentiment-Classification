# %%
# Import the neccessary modules
import pandas as pd
import numpy as np
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read the dataset into a pandas dataframe, df

# %%
# Read the dataset into a dataframe
df = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# %% [markdown]
# **Drop Non Recquired Columns**

# %%
df
# Out:
#                                                    mfccs  zero_crossing_rate  \
# 0      [-4.7883154e+02  3.3325115e+01 -6.4487829e+00 ...            0.158221
# 1      [-4.8954865e+02  2.7738764e+01 -1.2382742e+01 ...            0.337466
# 2      [-4.35193085e+02  4.40335197e+01 -2.84056549e+...            0.287352
# 3      [-4.5051022e+02  3.5520393e+01 -2.6201200e+01 ...            0.319214
# 4      [-4.7573129e+02  2.5805241e+01 -1.5824142e+01 ...            0.154203
# ...                                                  ...                 ...
# 16851  [-4.0630850e+02  3.8935593e+01  4.7740480e-01 ...            0.251618
# 16852  [-3.3170786e+02  4.6200230e+01  3.0691259e+00 ...            0.337181
# 16853  [-3.7679736e+02  4.1225876e+01  5.9078252e-01 ...            0.247278
# 16854  [-3.2025311e+02  4.7039799e+01  2.6084688e-01 ...            0.333771
# 16855  [-3.8849210e+02  4.5433468e+01 -1.5515751e+00 ...            0.235671
#
#        spectral_bandwidth    chroma       rms class_label  \
# 0             2811.724720  0.432150  0.029986       Angry
# 1             2627.283008  0.583449  0.011966       Angry
# 2             2173.834795  0.537973  0.050250       Angry
# 3             2375.562237  0.547021  0.025544       Angry
# 4             2169.616633  0.471881  0.046953       Angry
# ...                   ...       ...       ...         ...
# 16851         2595.763125  0.489838  0.039640    Surprise
# 16852         2410.996505  0.389710  0.117963    Surprise
# 16853         2594.630202  0.492712  0.052451    Surprise
# 16854         2389.176638  0.392537  0.123277    Surprise
# 16855         2539.527857  0.501296  0.050754    Surprise
#
#                                     file_name      mfcc0      mfcc1  \
# 0                    03-01-03-02-01-01-01.wav -478.83154  33.325115
# 1          03-01-03-02-01-01-01_augmented.wav -489.54865  27.738764
# 2                    03-01-03-02-01-01-02.wav -435.19308  44.033520
# 3          03-01-03-02-01-01-02_augmented.wav -450.51022  35.520393
# 4                    03-01-03-02-01-01-04.wav -475.73130  25.805240
# ...                                       ...        ...        ...
# 16851  M_10_EVAN_S_9_SURPRISE_3_augmented.wav -406.30850  38.935593
# 16852            M_10_EVAN_S_9_SURPRISE_4.wav -331.70786  46.200230
# 16853  M_10_EVAN_S_9_SURPRISE_4_augmented.wav -376.79736  41.225876
# 16854            M_10_EVAN_S_9_SURPRISE_5.wav -320.25310  47.039800
# 16855  M_10_EVAN_S_9_SURPRISE_5_augmented.wav -388.49210  45.433468
#
#            mfcc2  ...    mfcc30    mfcc31    mfcc32    mfcc33    mfcc34  \
# 0      -6.448783  ...  0.328626  2.993545  1.607269  0.753363  0.795460
# 1     -12.382742  ...  3.152687  3.479581  0.999255  0.446273 -0.756348
# 2     -28.405655  ... -0.770171 -0.912993 -0.610560 -1.106990 -0.785358
# 3     -26.201200  ...  0.600577  0.524650  0.813930 -1.485857  0.499522
# 4     -15.824142  ... -1.276900 -2.355503  2.545179 -1.319387  0.711873
# ...          ...  ...       ...       ...       ...       ...       ...
# 16851   0.477405  ... -0.671915 -0.215386  0.026275  0.219410 -0.046814
# 16852   3.069126  ...  2.917920  2.602964  0.847366  0.522375 -0.207175
# 16853   0.590782  ...  1.994877  1.314048  1.387961  0.246608  1.195332
# 16854   0.260847  ...  2.386777  2.104635  0.633636  0.841800  0.382966
# 16855  -1.551575  ...  1.153872  1.444134  1.134689  1.218682 -0.183612
#
#          mfcc35    mfcc36    mfcc37    mfcc38    mfcc39
# 0      0.657204  0.285984  0.347409  0.218164 -0.362225
# 1     -0.987419 -0.684020 -0.347724 -0.050397 -0.133484
# 2     -0.564920 -0.417357  0.537306  0.718312  0.528304
# 3     -0.771937  0.126429  0.860468  0.581919  1.637959
# 4      0.455794 -1.546776  0.536169 -0.651819  0.355566
# ...         ...       ...       ...       ...       ...
# 16851 -2.131241 -2.373210 -1.189148  1.648045  1.386102
# 16852  0.567925  0.032568 -0.259393  0.193821  1.031203
# 16853 -0.975989 -0.565488  0.153799  1.977247  1.530025
# 16854  0.831771 -0.528826 -0.969811 -0.152325  0.219692
# 16855 -0.686899 -1.285852  1.008845  0.933691  0.729580
#
# [16856 rows x 47 columns]

# %%
df_test
# Out:
#                                                  mfccs  zero_crossing_rate  \
# 0    [-3.9012119e+02  4.4109344e+01 -1.2921607e+01 ...            0.084918
# 1    [-4.67160522e+02  2.91869411e+01 -1.70986462e+...            0.391429
# 2    [-3.4629849e+02  2.0243580e+01 -1.1391698e+01 ...            0.120882
# 3    [-3.9613730e+02  4.1812637e+01 -1.2806710e+01 ...            0.149057
# 4    [-4.08084534e+02  3.21562920e+01 -1.13426485e+...            0.128189
# ..                                                 ...                 ...
# 934  [-3.15789490e+02  4.11579781e+01 -4.66505718e+...            0.368006
# 935  [-3.0825998e+02  4.2420658e+01 -3.6246645e+00 ...            0.344019
# 936  [-2.97977112e+02  3.52298622e+01 -1.60021079e+...            0.375373
# 937  [-3.0559796e+02  3.6652721e+01 -9.1293299e-01 ...            0.360817
# 938  [-3.4388855e+02  3.9960506e+01  1.3614115e+00 ...            0.372584
#
#      spectral_bandwidth    chroma       rms class_label  \
# 0           2010.457276  0.467693  0.075098       Angry
# 1           2372.973040  0.412228  0.035136       Angry
# 2           2457.125273  0.414273  0.125970       Angry
# 3           2480.510451  0.512132  0.080969       Angry
# 4           2642.601731  0.450778  0.046662       Angry
# ..                  ...       ...       ...         ...
# 934         2421.570717  0.378931  0.104968    Surprise
# 935         2396.946955  0.391811  0.113606    Surprise
# 936         2483.153256  0.394186  0.136011    Surprise
# 937         2486.361872  0.385032  0.128843    Surprise
# 938         2388.725618  0.383467  0.112313    Surprise
#
#                         file_name      mfcc0      mfcc1      mfcc2  ...  \
# 0        03-01-03-02-01-01-03.wav -390.12120  44.109344 -12.921607  ...
# 1        03-01-03-02-01-01-14.wav -467.16052  29.186941 -17.098646  ...
# 2        03-01-03-02-01-01-30.wav -346.29850  20.243580 -11.391698  ...
# 3        03-01-03-02-01-02-25.wav -396.13730  41.812637 -12.806710  ...
# 4        03-01-03-02-01-03-01.wav -408.08453  32.156292 -11.342648  ...
# ..                            ...        ...        ...        ...  ...
# 934  M_10_EVAN_S_5_SURPRISE_3.wav -315.78950  41.157978  -4.665057  ...
# 935  M_10_EVAN_S_5_SURPRISE_4.wav -308.25998  42.420660  -3.624665  ...
# 936  M_10_EVAN_S_6_SURPRISE_2.wav -297.97710  35.229862  -1.600211  ...
# 937  M_10_EVAN_S_6_SURPRISE_5.wav -305.59796  36.652720  -0.912933  ...
# 938  M_10_EVAN_S_9_SURPRISE_2.wav -343.88855  39.960506   1.361411  ...
#
#        mfcc30    mfcc31    mfcc32    mfcc33    mfcc34    mfcc35    mfcc36  \
# 0    0.450648  2.404330  2.840697  4.679700  3.358691  2.829290  2.049688
# 1    2.546051 -0.345007  1.761566  0.331160 -0.264679 -0.082578 -0.519460
# 2    1.983120  2.254916 -0.430221  0.366129 -0.073306 -0.460280  0.677957
# 3    5.819712  1.589295  0.174151 -1.593609  1.364120  1.444026  0.774227
# 4   -1.079431  2.334728 -0.123283  0.738071 -1.139498 -0.480123  1.070031
# ..        ...       ...       ...       ...       ...       ...       ...
# 934  1.781141  2.212446  0.255170  0.355328 -0.191172  0.538170 -0.836946
# 935  1.077347  1.734812 -0.640567  0.225346 -0.893579  0.445937 -0.518387
# 936 -0.261475  1.704446  0.119918  2.339397  0.122162  0.819136  0.680564
# 937 -0.964675  1.582144  0.123939  1.008998 -0.414467  1.555154  1.006149
# 938  2.973702  1.852571 -0.603280  1.001840  1.788876  2.220832  0.560587
#
#        mfcc37    mfcc38    mfcc39
# 0   -0.031819  1.511454  1.466245
# 1   -0.226637 -2.060637 -0.626951
# 2    1.134820 -1.294887  0.309249
# 3    0.248576 -1.265227  0.026068
# 4    0.191624  1.218494  1.468383
# ..        ...       ...       ...
# 934 -0.600881 -0.154892 -0.400183
# 935  1.034477  1.081573  0.678320
# 936  0.174210 -0.836902 -0.645632
# 937  0.085300  0.355210  1.037921
# 938 -0.403364  0.905810  1.237246
#
# [939 rows x 47 columns]

# %%
       """   'zero_crossing_rate',
                'spectral_bandwidth',
                #'chroma',
                'rms',
                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
                """
# Out:
# "   'zero_crossing_rate',\n         'spectral_bandwidth',\n         #'chroma',\n         'rms',\n         'mfcc0',\n         'mfcc1',\n         'mfcc2',\n         'mfcc3',\n         'mfcc4',\n         'mfcc5',\n         'mfcc6',\n         'mfcc7',\n         'mfcc8',\n         'mfcc9',\n         'mfcc10',\n         'mfcc11',\n         'mfcc12',\n         'mfcc13',\n         'mfcc14',\n         'mfcc15',\n         'mfcc16',\n         'mfcc17',\n         'mfcc18',\n         'mfcc19',\n         'mfcc20',\n           'mfcc21',\n             'mfcc22',\n               'mfcc23',\n                  'mfcc24',\n                    'mfcc25',\n                      'mfcc26',\n                        'mfcc27',\n                          'mfcc28',\n                            'mfcc29',\n                              'mfcc30',\n                                'mfcc31',\n                                  'mfcc32',\n                                    'mfcc33',\n                                        'mfcc34',\n                                          'mfcc35',\n                                            'mfcc36',\n                                              'mfcc37',\n                                                'mfcc38',\n                                                  'mfcc39',\n         "

# %%
# Drop some columns which is not relevant to the analysis (they are not numeric)
cols_to_drop=['file_name',
              'mfccs',
              'spectral_bandwidth',

            'zero_crossing_rate',

            'chroma',
              #'rms',


                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
              ]

df = df.drop(cols_to_drop, axis=1)



df_test = df_test.drop(cols_to_drop, axis=1)

# %%
df_test
# Out:
#           rms class_label
# 0    0.075098       Angry
# 1    0.035136       Angry
# 2    0.125970       Angry
# 3    0.080969       Angry
# 4    0.046662       Angry
# ..        ...         ...
# 934  0.104968    Surprise
# 935  0.113606    Surprise
# 936  0.136011    Surprise
# 937  0.128843    Surprise
# 938  0.112313    Surprise
#
# [939 rows x 2 columns]

# %% [markdown]
# **Label Mapping**

# %%
import pandas as pd

# Sample DataFrame

# Anger, Disgust, Fear, Happiness, Neutral, Sadness and Surprise
# Define a dictionary to map old labels to new labels
label_mapping = {'Happy': '0','Surprise': '1','Angry': '2','Sad': '3','Fear': '4','Disgust': '5','Neutral': '6' }

# Use the map method to change class labels
df['class_label'] = df['class_label'].replace(label_mapping)
df_test['class_label'] = df_test['class_label'].replace(label_mapping)
# Display the updated DataFrame
print(df)
print(df_test)
# Out:
#             rms class_label
# 0      0.029986           2
# 1      0.011966           2
# 2      0.050250           2
# 3      0.025544           2
# 4      0.046953           2
# ...         ...         ...
# 16851  0.039640           1
# 16852  0.117963           1
# 16853  0.052451           1
# 16854  0.123277           1
# 16855  0.050754           1
#
# [16856 rows x 2 columns]
#           rms class_label
# 0    0.075098           2
# 1    0.035136           2
# 2    0.125970           2
# 3    0.080969           2
# 4    0.046662           2
# ..        ...         ...
# 934  0.104968           1
# 935  0.113606           1
# 936  0.136011           1
# 937  0.128843           1
# 938  0.112313           1
#
# [939 rows x 2 columns]

# %%
# Seperate the dataframe into X and y data
X = df.values
y = df['class_label'].values

# Delete the Survived column from X
X=df.drop('class_label', axis=1).values

# separate X and y for validation




Vx=df_test.values
Vy=df_test['class_label'].values
Vx= df_test.drop('class_label', axis=1).values

# %%
print(Vx)
# Out:
# [[0.07509841]
#  [0.03513578]
#  [0.1259701 ]
#  [0.08096906]
#  [0.04666247]
#  [0.03081111]
#  [0.07813697]
#  [0.06605648]
#  [0.09912553]
#  [0.05284236]
#  [0.21617313]
#  [0.11198089]
#  [0.04714922]
#  [0.03645779]
#  [0.08103643]
#  [0.21893972]
#  [0.0809042 ]
#  [0.03384474]
#  [0.09788466]
#  [0.05709188]
#  [0.04102628]
#  [0.07759131]
#  [0.05266907]
#  [0.04938196]
#  [0.11078709]
#  [0.02511845]
#  [0.07026456]
#  [0.1149178 ]
#  [0.35000563]
#  [0.05282647]
#  [0.06678966]
#  [0.02360743]
#  [0.05512125]
#  [0.05956145]
#  [0.0399591 ]
#  [0.06944644]
#  [0.08419794]
#  [0.03794501]
#  [0.05916286]
#  [0.13814172]
#  [0.09757397]
#  [0.09331945]
#  [0.05765005]
#  [0.09649644]
#  [0.05519571]
#  [0.04028355]
#  [0.0539455 ]
#  [0.05114908]
#  [0.19579153]
#  [0.1559184 ]
#  [0.196453  ]
#  [0.17788933]
#  [0.164851  ]
#  [0.18056706]
#  [0.16520216]
#  [0.15318538]
#  [0.10026074]
#  [0.06900006]
#  [0.10114965]
#  [0.0663002 ]
#  [0.13830067]
#  [0.118264  ]
#  [0.12901132]
#  [0.1368319 ]
#  [0.10586882]
#  [0.08675961]
#  [0.10271842]
#  [0.08787327]
#  [0.08175237]
#  [0.15759961]
#  [0.15994464]
#  [0.12308751]
#  [0.12340283]
#  [0.12595978]
#  [0.1827224 ]
#  [0.14834636]
#  [0.14501922]
#  [0.19397393]
#  [0.1843888 ]
#  [0.17579298]
#  [0.15248033]
#  [0.1533523 ]
#  [0.13680018]
#  [0.20386991]
#  [0.1629879 ]
#  [0.11825091]
#  [0.13157345]
#  [0.13775957]
#  [0.14072478]
#  [0.15020587]
#  [0.11847978]
#  [0.17737073]
#  [0.14764419]
#  [0.15278639]
#  [0.14237875]
#  [0.13425343]
#  [0.10388809]
#  [0.09208096]
#  [0.19274749]
#  [0.15716751]
#  [0.1588717 ]
#  [0.15758462]
#  [0.1243013 ]
#  [0.11738829]
#  [0.10755166]
#  [0.11024273]
#  [0.20970145]
#  [0.20235536]
#  [0.25254196]
#  [0.15728019]
#  [0.24514213]
#  [0.22704674]
#  [0.1731385 ]
#  [0.22920102]
#  [0.21595944]
#  [0.24629147]
#  [0.12887509]
#  [0.11846745]
#  [0.21009962]
#  [0.16765916]
#  [0.15677303]
#  [0.15995303]
#  [0.1769341 ]
#  [0.17970449]
#  [0.1770936 ]
#  [0.14991719]
#  [0.13499334]
#  [0.14878891]
#  [0.18607429]
#  [0.19544066]
#  [0.16905352]
#  [0.1610346 ]
#  [0.15472704]
#  [0.15206814]
#  [0.11937192]
#  [0.12989551]
#  [0.13398758]
#  [0.17123477]
#  [0.10565323]
#  [0.11848482]
#  [0.12629108]
#  [0.08501808]
#  [0.14750227]
#  [0.16346253]
#  [0.16602968]
#  [0.16365685]
#  [0.14127567]
#  [0.1445219 ]
#  [0.06990657]
#  [0.11186098]
#  [0.12493575]
#  [0.09529323]
#  [0.0778203 ]
#  [0.24180353]
#  [0.25757545]
#  [0.17899507]
#  [0.17543319]
#  [0.1023211 ]
#  [0.1226026 ]
#  [0.2048896 ]
#  [0.1877698 ]
#  [0.1529228 ]
#  [0.15764596]
#  [0.14994793]
#  [0.1459795 ]
#  [0.18229912]
#  [0.19605431]
#  [0.1709568 ]
#  [0.12244015]
#  [0.15771234]
#  [0.14272872]
#  [0.13883223]
#  [0.13810194]
#  [0.13224359]
#  [0.15853474]
#  [0.1266014 ]
#  [0.17903727]
#  [0.1351945 ]
#  [0.12017807]
#  [0.13126591]
#  [0.06885164]
#  [0.11331133]
#  [0.07518096]
#  [0.05472049]
#  [0.22152078]
#  [0.18979011]
#  [0.25437993]
#  [0.14646035]
#  [0.09940878]
#  [0.09865026]
#  [0.098048  ]
#  [0.12493466]
#  [0.10496844]
#  [0.11360568]
#  [0.13601114]
#  [0.12884307]
#  [0.11231343]]

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {'0': 2710, '1': 2350, '2': 2710, '3': 2710, '4': 1800, '5': 2160, '6': 2416}

# %% [markdown]
# Using SMOTE to OverSample Training Data Only

# %%
import numpy as np
from imblearn.over_sampling import SMOTE

# Assuming you have a dataset with features X and labels y


# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X = X.astype(np.float32)
y = y.astype(np.float32)
# Fit and transform the data
X,y = smote.fit_resample(X, y)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X = scaler.fit_transform(X)

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {0.0: 2710, 1.0: 2710, 2.0: 2710, 3.0: 2710, 4.0: 2710, 5.0: 2710, 6.0: 2710}

# %%
print(X.shape)
print(y.shape)
print(Vx.shape)
print(Vy.shape)
# Out:
# (18970, 1)
# (18970,)
# (939, 1)
# (939,)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Perform Classification Using Decision Tree Classifier**

# %%
# Using simple Decision Tree classifier
from sklearn import tree
dt_clf = tree.DecisionTreeClassifier(max_depth=100,random_state=42,criterion='entropy',splitter='best')
dt_clf.fit(X, y)

print(dt_clf.score(X, y))
print(dt_clf.score(Vx, Vy))


prediction_test=dt_clf.predict(Vx)



Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.9897733263046916
# 0.18210862619808307
# Accuracy =  0.18210862619808307
# Precision =  0.18680903455424455
# Recall =  0.18210862619808307
# F1_Score =  0.18269590377053058

# %%
print(Vx.shape)
print(Vy.shape)
print(X.shape)
print(y.shape)
# Out:
# (939, 1)
# (939,)
# (18970, 1)
# (18970,)

# %% [markdown]
# **Perform Classification Using Random Forest Classifier**
#
# Now, we would see if we could get a better results using the the Random Forests Classifier.

# %%
from sklearn import ensemble
rf_clf = ensemble.RandomForestClassifier(n_estimators=10,random_state=42,max_features="sqrt")
rf_clf.fit(X, y)



prediction_test=rf_clf.predict(Vx)

Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.1757188498402556
# Precision =  0.18293191613124885
# Recall =  0.1757188498402556
# F1_Score =  0.17697040072491718

# %% [markdown]
# Ada boost classifier

# %%
ada_clf = ensemble.AdaBoostClassifier(n_estimators=50,learning_rate=0.001,random_state=42)
ada_clf.fit(X, y)
ada_clf.score(Vx, Vy)




prediction_test=ada_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.17145899893503727
# Precision =  0.10021498602191443
# Recall =  0.17145899893503727
# F1_Score =  0.07838630414678878
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Perform Classification Using Gradient Boosting Classifier**
#
# This classifier is available in the ensemble module which we already imported. So we don’t need to import anything

# %%
gb_clf = ensemble.GradientBoostingClassifier(n_estimators=30,max_depth=5,max_features=2,learning_rate=0.001)
gb_clf.fit(X, y)
gb_clf.score(Vx,Vy)

print(dt_clf.score(Vx, Vy))


prediction_test=gb_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.18210862619808307
# Accuracy =  0.20447284345047922
# Precision =  0.22448817377671065
# Recall =  0.20447284345047922
# F1_Score =  0.17011316036962312

# %%
from sklearn.neighbors import KNeighborsClassifier

# create knn classifier
knn = KNeighborsClassifier(n_neighbors = 19)
knn.fit(X, y)
knn.score(X, y)

print(knn.score(Vx, Vy))


prediction_test=knn.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.17145899893503727
# Accuracy =  0.17145899893503727
# Precision =  0.17784688164741586
# Recall =  0.17145899893503727
# F1_Score =  0.16969943863761114

# %%
import joblib
joblib.dump(rf_clf, "rf_Zcr.joblib")
# Out:
# ['rf_Zcr.joblib']

# %%
import joblib
joblib.dump(dt_clf, "dt_Zcr.joblib")
joblib.dump(gb_clf, "rf_Zcr.joblib")
joblib.dump(knn, "rf_Zcr.joblib")
joblib.dump(rf_clf, "rf_Zcr.joblib")
joblib.dump(ada_clf, "rf_Zcr.joblib")
# Out:
# ['dt_Zcr.joblib']

# %% [markdown]
# **LSTM,BI-LSTM model**

# %% [markdown]
# **Bi_lstm
# **

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data



df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# Drop irrelevant columns

df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for BI-LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# BI-LSTM Model
bilstm = Sequential()
bilstm.add(Bidirectional(LSTM(100, return_sequences=True), input_shape=(X_reshaped.shape[1], X_reshaped.shape[2])))  # Set return_sequences=True
bilstm.add(Dropout(0.1))
bilstm.add(Bidirectional(LSTM(50)))  # This layer now receives 3D input as expected
bilstm.add(Dropout(0.1))




bilstm.add(Dense(y_categorical.shape[1], activation='softmax'))














bilstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])






# Train the model
history = bilstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)









# Evaluate the model on the test set
y_pred = bilstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall=metrics.recall_score(y_test, y_pred_classes, average='weighted')



print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 9s 31ms/step - loss: 1.8610 - accuracy: 0.2318 - val_loss: 2.8426 - val_accuracy: 0.0337
# Epoch 2/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8135 - accuracy: 0.2370 - val_loss: 3.0632 - val_accuracy: 0.0369
# Epoch 3/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8080 - accuracy: 0.2390 - val_loss: 2.9910 - val_accuracy: 0.0287
# Epoch 4/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8060 - accuracy: 0.2370 - val_loss: 2.9562 - val_accuracy: 0.0303
# Epoch 5/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8044 - accuracy: 0.2370 - val_loss: 2.9515 - val_accuracy: 0.0329
# Epoch 6/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8028 - accuracy: 0.2380 - val_loss: 2.9028 - val_accuracy: 0.0414
# Epoch 7/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8037 - accuracy: 0.2405 - val_loss: 2.9345 - val_accuracy: 0.0387
# Epoch 8/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8012 - accuracy: 0.2418 - val_loss: 2.9670 - val_accuracy: 0.0216
# Epoch 9/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8005 - accuracy: 0.2399 - val_loss: 2.9100 - val_accuracy: 0.0235
# Epoch 10/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8002 - accuracy: 0.2414 - val_loss: 2.8829 - val_accuracy: 0.0298
# Epoch 11/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8010 - accuracy: 0.2423 - val_loss: 2.8657 - val_accuracy: 0.0303
# Epoch 12/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.7996 - accuracy: 0.2427 - val_loss: 2.8771 - val_accuracy: 0.0409
# Epoch 13/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7980 - accuracy: 0.2411 - val_loss: 2.9085 - val_accuracy: 0.0290
# Epoch 14/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7991 - accuracy: 0.2398 - val_loss: 2.9826 - val_accuracy: 0.0356
# Epoch 15/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.7990 - accuracy: 0.2408 - val_loss: 2.9143 - val_accuracy: 0.0322
# Epoch 16/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7981 - accuracy: 0.2428 - val_loss: 2.9643 - val_accuracy: 0.0329
# Epoch 17/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7987 - accuracy: 0.2418 - val_loss: 2.9618 - val_accuracy: 0.0327
# Epoch 18/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7985 - accuracy: 0.2401 - val_loss: 2.9351 - val_accuracy: 0.0319
# Epoch 19/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7976 - accuracy: 0.2426 - val_loss: 2.9245 - val_accuracy: 0.0337
# Epoch 20/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7979 - accuracy: 0.2447 - val_loss: 2.9522 - val_accuracy: 0.0316
# Epoch 21/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7975 - accuracy: 0.2406 - val_loss: 2.9763 - val_accuracy: 0.0290
# Epoch 22/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7983 - accuracy: 0.2432 - val_loss: 2.9346 - val_accuracy: 0.0345
# Epoch 23/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7981 - accuracy: 0.2393 - val_loss: 3.0019 - val_accuracy: 0.0345
# Epoch 24/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7973 - accuracy: 0.2408 - val_loss: 2.9732 - val_accuracy: 0.0369
# Epoch 25/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.7966 - accuracy: 0.2427 - val_loss: 2.9301 - val_accuracy: 0.0398
# Epoch 26/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.7974 - accuracy: 0.2428 - val_loss: 2.9085 - val_accuracy: 0.0372
# Epoch 27/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7967 - accuracy: 0.2448 - val_loss: 2.9943 - val_accuracy: 0.0274
# Epoch 28/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7966 - accuracy: 0.2453 - val_loss: 2.9948 - val_accuracy: 0.0308
# Epoch 29/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7969 - accuracy: 0.2418 - val_loss: 2.9653 - val_accuracy: 0.0343
# Epoch 30/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7962 - accuracy: 0.2458 - val_loss: 3.0091 - val_accuracy: 0.0285
# Epoch 31/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.7963 - accuracy: 0.2446 - val_loss: 2.9771 - val_accuracy: 0.0271
# Epoch 32/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7957 - accuracy: 0.2449 - val_loss: 2.9602 - val_accuracy: 0.0303
# Epoch 33/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.7963 - accuracy: 0.2412 - val_loss: 2.9532 - val_accuracy: 0.0343
# Epoch 34/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.7966 - accuracy: 0.2457 - val_loss: 2.9794 - val_accuracy: 0.0295
# Epoch 35/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.
120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7943 - accuracy: 0.2482 - val_loss: 2.9527 - val_accuracy: 0.0361
# Epoch 66/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.7942 - accuracy: 0.2444 - val_loss: 2.9918 - val_accuracy: 0.0327
# Epoch 67/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7940 - accuracy: 0.2435 - val_loss: 2.9200 - val_accuracy: 0.0324
# Epoch 68/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7943 - accuracy: 0.2429 - val_loss: 2.9397 - val_accuracy: 0.0348
# Epoch 69/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7934 - accuracy: 0.2470 - val_loss: 2.9859 - val_accuracy: 0.0311
# Epoch 70/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7938 - accuracy: 0.2445 - val_loss: 3.0373 - val_accuracy: 0.0372
# Epoch 71/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.7943 - accuracy: 0.2431 - val_loss: 2.9250 - val_accuracy: 0.0345
# Epoch 72/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7938 - accuracy: 0.2447 - val_loss: 3.0033 - val_accuracy: 0.0340
# Epoch 73/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7941 - accuracy: 0.2445 - val_loss: 2.9396 - val_accuracy: 0.0345
# Epoch 74/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7932 - accuracy: 0.2468 - val_loss: 2.9576 - val_accuracy: 0.0311
# Epoch 75/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7935 - accuracy: 0.2430 - val_loss: 2.9487 - val_accuracy: 0.0306
# Epoch 76/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7942 - accuracy: 0.2478 - val_loss: 2.9391 - val_accuracy: 0.0343
# Epoch 77/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7943 - accuracy: 0.2464 - val_loss: 2.9786 - val_accuracy: 0.0327
# Epoch 78/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.7938 - accuracy: 0.2466 - val_loss: 3.0265 - val_accuracy: 0.0298
# Epoch 79/120
# 119/119 [==============================] - 3s 23ms/step - loss: 1.7939 - accuracy: 0.2464 - val_loss: 2.9588 - val_accuracy: 0.0322
# Epoch 80/120
# 119/119 [==============================] - 3s 22ms/step - loss: 1.7938 - accuracy: 0.2455 - val_loss: 2.9437 - val_accuracy: 0.0345
# Epoch 81/120
# 119/119 [==============================] - 2s 21ms/step - loss: 1.7938 - accuracy: 0.2450 - val_loss: 2.9609 - val_accuracy: 0.0277
# Epoch 82/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.7943 - accuracy: 0.2485 - val_loss: 2.9830 - val_accuracy: 0.0282
# Epoch 83/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.7937 - accuracy: 0.2455 - val_loss: 2.9376 - val_accuracy: 0.0295
# Epoch 84/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.7936 - accuracy: 0.2464 - val_loss: 3.0061 - val_accuracy: 0.0345
# Epoch 85/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.7936 - accuracy: 0.2440 - val_loss: 2.9455 - val_accuracy: 0.0343
# Epoch 86/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7930 - accuracy: 0.2462 - val_loss: 2.9760 - val_accuracy: 0.0319
# Epoch 87/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7937 - accuracy: 0.2457 - val_loss: 2.9705 - val_accuracy: 0.0308
# Epoch 88/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7939 - accuracy: 0.2468 - val_loss: 2.9701 - val_accuracy: 0.0322
# Epoch 89/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7935 - accuracy: 0.2459 - val_loss: 2.9704 - val_accuracy: 0.0343
# Epoch 90/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7935 - accuracy: 0.2470 - val_loss: 2.9275 - val_accuracy: 0.0329
# Epoch 91/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7940 - accuracy: 0.2455 - val_loss: 2.9353 - val_accuracy: 0.0314
# Epoch 92/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7938 - accuracy: 0.2468 - val_loss: 2.9789 - val_accuracy: 0.0329
# Epoch 93/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7944 - accuracy: 0.2459 - val_loss: 3.0036 - val_accuracy: 0.0340
# Epoch 94/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.7936 - accuracy: 0.2444 - val_loss: 3.0137 - val_accuracy: 0.0285
# Epoch 95/120
# 119/119 [==============================] - 2s 21ms/step - loss: 1.7945 - accuracy: 0.2451 - val_loss: 2.9532 - val_accuracy: 0.0322
# Epoch 96/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.7939 - accuracy: 0.2451 - val_loss: 2.9861 - val_accuracy: 0.0319
# Epoch 97/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7933 - accuracy: 0.2477 - val_loss: 2.9246 - val_accuracy: 0.0329
# Epoch 98/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.7936 - accuracy: 0.2457 - val_loss: 2.9720 - val_accuracy: 0.0311
# Epoch 99/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.7936 - accuracy: 0.2445 - val_loss: 2.9726 - val_accuracy: 0.0327
# Epoch 100/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.7942 - accuracy: 0.2454 - val_loss: 2.9633 - val_accuracy: 0.0324
# Epoch 101/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7934 - accuracy: 0.2453 - val_loss: 2.9424 - val_accuracy: 0.0364
# Epoch 102/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7931 - accuracy: 0.2467 - val_loss: 2.9540 - val_accuracy: 0.0351
# Epoch 103/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7937 - accuracy: 0.2476 - val_loss: 2.9768 - val_accuracy: 0.0319
# Epoch 104/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7939 - accuracy: 0.2463 - val_loss: 2.9403 - val_accuracy: 0.0348
# Epoch 105/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7936 - accuracy: 0.2446 - val_loss: 2.9661 - val_accuracy: 0.0314
# Epoch 106/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7937 - accuracy: 0.2450 - val_loss: 2.9272 - val_accuracy: 0.0324
# Epoch 107/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7934 - accuracy: 0.2457 - val_loss: 2.9048 - val_accuracy: 0.0303
# Epoch 108/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.7933 - accuracy: 0.2468 - val_loss: 2.9646 - val_accuracy: 0.0295
# Epoch 109/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.7941 - accuracy: 0.2475 - val_loss: 2.9859 - val_accuracy: 0.0298
# Epoch 110/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7938 - accuracy: 0.2468 - val_loss: 2.9647 - val_accuracy: 0.0300
# Epoch 111/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7931 - accuracy: 0.2459 - val_loss: 2.9966 - val_accuracy: 0.0361
# Epoch 112/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7938 - accuracy: 0.2458 - val_loss: 2.9659 - val_accuracy: 0.0308
# Epoch 113/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7940 - accuracy: 0.2443 - val_loss: 2.9864 - val_accuracy: 0.0269
# Epoch 114/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7930 - accuracy: 0.2455 - val_loss: 2.9465 - val_accuracy: 0.0329
# Epoch 115/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7934 - accuracy: 0.2464 - val_loss: 2.9887 - val_accuracy: 0.0279
# Epoch 116/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7939 - accuracy: 0.2470 - val_loss: 2.9749 - val_accuracy: 0.0345
# Epoch 117/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7930 - accuracy: 0.2468 - val_loss: 2.9559 - val_accuracy: 0.0306
# Epoch 118/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.7943 - accuracy: 0.2439 - val_loss: 2.9926 - val_accuracy: 0.0329
# Epoch 119/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7934 - accuracy: 0.2445 - val_loss: 3.0011 - val_accuracy: 0.0295
# Epoch 120/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7936 - accuracy: 0.2453 - val_loss: 2.9493 - val_accuracy: 0.0335
# 30/30 [==============================] - 1s 2ms/step
# Accuracy = 0.21192758253461128
# Precision = 0.1817447313362126
# Recall = 0.21192758253461128
# F1 Score = 0.13729654378733366
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ***lstm***

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data

df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')




df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# LSTM Model
lstm = Sequential()
lstm.add(LSTM(100, input_shape=(X_reshaped.shape[1], X_reshaped.shape[2]), return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(50, return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(20))
lstm.add(Dropout(0.1))

lstm.add(Dense(y_categorical.shape[1], activation='softmax'))

lstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])





# Train the model
history = lstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)







# Evaluate the model on the test set
y_pred = lstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall = metrics.recall_score(y_test, y_pred_classes, average='weighted')

print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 6s 14ms/step - loss: 1.8948 - accuracy: 0.2124 - val_loss: 2.4949 - val_accuracy: 0.0000e+00
# Epoch 2/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8205 - accuracy: 0.2324 - val_loss: 2.9021 - val_accuracy: 0.0348
# Epoch 3/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8114 - accuracy: 0.2356 - val_loss: 2.8885 - val_accuracy: 0.0358
# Epoch 4/120
# 119/119 [==============================] - 1s 6ms/step - loss: 1.8086 - accuracy: 0.2350 - val_loss: 2.9258 - val_accuracy: 0.0361
# Epoch 5/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8081 - accuracy: 0.2348 - val_loss: 2.9213 - val_accuracy: 0.0366
# Epoch 6/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8060 - accuracy: 0.2399 - val_loss: 2.9322 - val_accuracy: 0.0361
# Epoch 7/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.8063 - accuracy: 0.2385 - val_loss: 2.8832 - val_accuracy: 0.0369
# Epoch 8/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.8049 - accuracy: 0.2399 - val_loss: 2.9118 - val_accuracy: 0.0395
# Epoch 9/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8049 - accuracy: 0.2381 - val_loss: 2.8742 - val_accuracy: 0.0411
# Epoch 10/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8040 - accuracy: 0.2357 - val_loss: 2.9458 - val_accuracy: 0.0374
# Epoch 11/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8037 - accuracy: 0.2376 - val_loss: 2.9558 - val_accuracy: 0.0377
# Epoch 12/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8023 - accuracy: 0.2406 - val_loss: 2.9670 - val_accuracy: 0.0329
# Epoch 13/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8020 - accuracy: 0.2385 - val_loss: 2.9106 - val_accuracy: 0.0411
# Epoch 14/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8023 - accuracy: 0.2401 - val_loss: 2.9402 - val_accuracy: 0.0358
# Epoch 15/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8021 - accuracy: 0.2408 - val_loss: 2.8969 - val_accuracy: 0.0327
# Epoch 16/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8005 - accuracy: 0.2413 - val_loss: 2.9558 - val_accuracy: 0.0322
# Epoch 17/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8009 - accuracy: 0.2423 - val_loss: 2.9542 - val_accuracy: 0.0369
# Epoch 18/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8001 - accuracy: 0.2405 - val_loss: 2.9508 - val_accuracy: 0.0282
# Epoch 19/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.8005 - accuracy: 0.2419 - val_loss: 2.9271 - val_accuracy: 0.0311
# Epoch 20/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.8015 - accuracy: 0.2390 - val_loss: 2.9360 - val_accuracy: 0.0343
# Epoch 21/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8003 - accuracy: 0.2403 - val_loss: 2.9448 - val_accuracy: 0.0308
# Epoch 22/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7999 - accuracy: 0.2393 - val_loss: 2.9557 - val_accuracy: 0.0279
# Epoch 23/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.8010 - accuracy: 0.2424 - val_loss: 2.9397 - val_accuracy: 0.0274
# Epoch 24/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.8004 - accuracy: 0.2429 - val_loss: 2.9363 - val_accuracy: 0.0258
# Epoch 25/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7995 - accuracy: 0.2410 - val_loss: 2.9219 - val_accuracy: 0.0279
# Epoch 26/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7996 - accuracy: 0.2422 - val_loss: 2.9274 - val_accuracy: 0.0271
# Epoch 27/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7990 - accuracy: 0.2433 - val_loss: 2.8914 - val_accuracy: 0.0303
# Epoch 28/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7987 - accuracy: 0.2411 - val_loss: 2.9242 - val_accuracy: 0.0282
# Epoch 29/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7978 - accuracy: 0.2431 - val_loss: 2.9832 - val_accuracy: 0.0319
# Epoch 30/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7985 - accuracy: 0.2417 - val_loss: 2.9491 - val_accuracy: 0.0300
# Epoch 31/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7992 - accuracy: 0.2433 - val_loss: 2.9254 - val_accuracy: 0.0314
# Epoch 32/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7981 - accuracy: 0.2454 - val_loss: 2.9283 - val_accuracy: 0.0300
# Epoch 33/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7985 - accuracy: 0.2443 - val_loss: 2.9423 - val_accuracy: 0.0295
# Epoch 34/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7976 - accuracy: 0.2428 - val_loss: 2.9590 - val_accuracy: 0.0287
# Epoch 35/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7978 - accuracy: 0.2433 - val_loss: 2.9707 - val_accuracy: 0.0279
# Epoch 36/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7979 - accuracy: 0.2443 - val_loss: 2.9496 - val_accuracy: 0.0287
# Epoch 37/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7982 - accuracy: 0.2411 - val_loss: 2.9610 - val_accuracy: 0.0290
# Epoch 38/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7976 - accuracy: 0.2432 - val_loss: 2.9329 - val_accuracy: 0.0300
# Epoch 39/120
# 119/119 [==============================] - 1s 6ms/step - loss: 1.7974 - accuracy: 0.2451 - val_loss: 2.9355 - val_accuracy: 0.0316
# Epoch 40/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7976 - accuracy: 0.2441 - val_loss: 2.9748 - val_accuracy: 0.0322
# Epoch 41/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7982 - accuracy: 0.2441 - val_loss: 2.9291 - val_accuracy: 0.0285
# Epoch 42/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7963 - accuracy: 0.2445 - val_loss: 2.9992 - val_accuracy: 0.0329
# Epoch 43/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7970 - accuracy: 0.2457 - val_loss: 2.9653 - val_accuracy: 0.0343
# Epoch 44/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7970 - accuracy: 0.2438 - val_loss: 2.9353 - val_accuracy: 0.0319
# Epoch 45/120
# 119/119 [==============================] - 1s 6ms/step - loss: 1.7973 - accuracy: 0.2441 - val_loss: 2.9216 - val_accuracy: 0.0319
# Epoch 46/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7965 - accuracy: 0.2436 - val_loss: 2.9368 - val_accuracy: 0.0343
# Epoch 47/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7966 - accuracy: 0.2438 - val_loss: 2.9388 - val_accuracy: 0.0311
# Epoch 48/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7957 - accuracy: 0.2460 - val_loss: 2.9376 - val_accuracy: 0.0311
# Epoch 49/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7973 - accuracy: 0.2424 - val_loss: 2.9482 - val_accuracy: 0.0316
# Epoch 50/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7970 - accuracy: 0.2458 - val_loss: 2.9190 - val_accuracy: 0.0311
# Epoch 51/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7966 - accuracy: 0.2431 - val_loss: 2.9807 - val_accuracy: 0.0298
# Epoch 52/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7955 - accuracy: 0.2445 - val_loss: 2.9168 - val_accuracy: 0.0324
# Epoch 53/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7954 - accuracy: 0.2441 - val_loss: 2.9722 - val_accuracy: 0.0314
# Epoch 54/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7957 - accuracy: 0.2439 - val_loss: 2.9774 - val_accuracy: 0.0311
# Epoch 55/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7960 - accuracy: 0.2452 - val_loss: 2.9326 - val_accuracy: 0.0329
# Epoch 56/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7964 - accuracy: 0.2431 - val_loss: 2.9119 - val_accuracy: 0.0340
# Epoch 57/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7960 - accuracy: 0.2460 - val_loss: 2.9222 - val_accuracy: 0.0348
# Epoch 58/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7953 - accuracy: 0.2459 - val_loss: 2.9676 - val_accuracy: 0.0295
# Epoch 59/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7957 - accuracy: 0.2459 - val_loss: 2.9661 - val_accuracy: 0.0319
# Epoch 60/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7962 - accuracy: 0.2441 - val_loss: 2.9560 - val_accuracy: 0.0322
# Epoch 61/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7959 - accuracy: 0.2464 - val_loss: 2.9479 - val_accuracy: 0.0308
# Epoch 62/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7957 - accuracy: 0.2457 - val_loss: 2.9261 - val_accuracy: 0.0319
# Epoch 63/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7950 - accuracy: 0.2441 - val_loss: 2.9545 - val_accuracy: 0.0327
# Epoch 64/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7962 - accuracy: 0.2464 - val_loss: 2.9716 - val_accuracy: 0.0285
# Epoch 65/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7966 - accuracy: 0.2446 - val_loss: 2.9612 - val_accuracy: 0.0306
# Epoch 66/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7954 - accuracy: 0.2450 - val_loss: 2.9577 - val_accuracy: 0.0303
# Epoch 67/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7955 - accuracy: 0.2449 - val_loss: 2.9129 - val_accuracy: 0.0324
# Epoch 68/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7942 - accuracy: 0.2464 - val_loss: 2.9384 - val_accuracy: 0.0316
# Epoch 69/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7949 - accuracy: 0.2479 - val_loss: 2.9388 - val_accuracy: 0.0316
# Epoch 70/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7964 - accuracy: 0.2451 - val_loss: 2.9382 - val_accuracy: 0.0340
# Epoch 71/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.7948 - accuracy: 0.2434 - val_loss: 2.9585 - val_accuracy: 0.0324
# Epoch 72/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7948 - accuracy: 0.2458 - val_loss: 2.9542 - val_accuracy: 0.0316
# Epoch 73/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7972 - accuracy: 0.2424 - val_loss: 2.9398 - val_accuracy: 0.0322
# Epoch 74/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7957 - accuracy: 0.2447 - val_loss: 2.9125 - val_accuracy: 0.0345
# Epoch 75/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7955 - accuracy: 0.2453 - val_loss: 2.9474 - val_accuracy: 0.0319
# Epoch 76/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7951 - accuracy: 0.2467 - val_loss: 2.9451 - val_accuracy: 0.0327
# Epoch 77/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7946 - accuracy: 0.2455 - val_loss: 2.9384 - val_accuracy: 0.0327
# Epoch 78/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7952 - accuracy: 0.2467 - val_loss: 2.9538 - val_accuracy: 0.0319
# Epoch 79/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7951 - accuracy: 0.2447 - val_loss: 2.9627 - val_accuracy: 0.0343
# Epoch 80/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7958 - accuracy: 0.2451 - val_loss: 2.9407 - val_accuracy: 0.0332
# Epoch 81/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7948 - accuracy: 0.2450 - val_loss: 2.9547 - val_accuracy: 0.0308
# Epoch 82/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7951 - accuracy: 0.2444 - val_loss: 2.9313 - val_accuracy: 0.0298
# Epoch 83/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7949 - accuracy: 0.2466 - val_loss: 2.8997 - val_accuracy: 0.0327
# Epoch 84/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.7954 - accuracy: 0.2445 - val_loss: 2.9178 - val_accuracy: 0.0340
# Epoch 85/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7950 - accuracy: 0.2444 - val_loss: 2.9636 - val_accuracy: 0.0345
# Epoch 86/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7953 - accuracy: 0.2452 - val_loss: 2.9257 - val_accuracy: 0.0324
# Epoch 87/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7949 - accuracy: 0.2455 - val_loss: 2.9287 - val_accuracy: 0.0314
# Epoch 88/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7947 - accuracy: 0.2465 - val_loss: 2.9611 - val_accuracy: 0.0314
# Epoch 89/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7936 - accuracy: 0.2455 - val_loss: 2.9762 - val_accuracy: 0.0329
# Epoch 90/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7945 - accuracy: 0.2482 - val_loss: 2.9668 - val_accuracy: 0.0322
# Epoch 91/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7941 - accuracy: 0.2463 - val_loss: 2.9668 - val_accuracy: 0.0327
# Epoch 92/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7945 - accuracy: 0.2447 - val_loss: 2.9327 - val_accuracy: 0.0329
# Epoch 93/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7948 - accuracy: 0.2451 - val_loss: 2.9647 - val_accuracy: 0.0332
# Epoch 94/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.7950 - accuracy: 0.2454 - val_loss: 2.9268 - val_accuracy: 0.0343
# Epoch 95/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.7949 - accuracy: 0.2419 - val_loss: 2.9498 - val_accuracy: 0.0327
# Epoch 96/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.7951 - accuracy: 0.2448 - val_loss: 2.9372 - val_accuracy: 0.0327
# Epoch 97/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7946 - accuracy: 0.2458 - val_loss: 2.9409 - val_accuracy: 0.0314
# Epoch 98/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7944 - accuracy: 0.2463 - val_loss: 2.9662 - val_accuracy: 0.0319
# Epoch 99/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7944 - accuracy: 0.2470 - val_loss: 2.9430 - val_accuracy: 0.0308
# Epoch 100/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7944 - accuracy: 0.2449 - val_loss: 2.9550 - val_accuracy: 0.0316
# Epoch 101/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7951 - accuracy: 0.2464 - val_loss: 2.9239 - val_accuracy: 0.0335
# Epoch 102/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7938 - accuracy: 0.2480 - val_loss: 2.9816 - val_accuracy: 0.0277
# Epoch 103/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7948 - accuracy: 0.2468 - val_loss: 2.9422 - val_accuracy: 0.0324
# Epoch 104/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.7949 - accuracy: 0.2460 - val_loss: 2.9525 - val_accuracy: 0.0343
# Epoch 105/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7946 - accuracy: 0.2457 - val_loss: 2.9411 - val_accuracy: 0.0311
# Epoch 106/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7950 - accuracy: 0.2430 - val_loss: 2.9377 - val_accuracy: 0.0306
# Epoch 107/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7944 - accuracy: 0.2440 - val_loss: 2.9610 - val_accuracy: 0.0337
# Epoch 108/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.7943 - accuracy: 0.2455 - val_loss: 2.9418 - val_accuracy: 0.0300
# Epoch 109/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7949 - accuracy: 0.2451 - val_loss: 2.9388 - val_accuracy: 0.0335
# Epoch 110/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7941 - accuracy: 0.2465 - val_loss: 2.9489 - val_accuracy: 0.0343
# Epoch 111/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7951 - accuracy: 0.2474 - val_loss: 2.9504 - val_accuracy: 0.0322
# Epoch 112/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7936 - accuracy: 0.2451 - val_loss: 2.9333 - val_accuracy: 0.0345
# Epoch 113/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7936 - accuracy: 0.2477 - val_loss: 2.9580 - val_accuracy: 0.0345
# Epoch 114/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7937 - accuracy: 0.2458 - val_loss: 2.9303 - val_accuracy: 0.0324
# Epoch 115/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7941 - accuracy: 0.2464 - val_loss: 2.9593 - val_accuracy: 0.0298
# Epoch 116/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7945 - accuracy: 0.2487 - val_loss: 2.9386 - val_accuracy: 0.0345
# Epoch 117/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7941 - accuracy: 0.2464 - val_loss: 2.9613 - val_accuracy: 0.0303
# Epoch 118/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7955 - accuracy: 0.2450 - val_loss: 2.9531 - val_accuracy: 0.0327
# Epoch 119/120
# 119/119 [==============================] - 1s 7ms/step - loss: 1.7938 - accuracy: 0.2449 - val_loss: 2.9568 - val_accuracy: 0.0322
# Epoch 120/120
# 119/119 [==============================] - 1s 8ms/step - loss: 1.7942 - accuracy: 0.2453 - val_loss: 2.9665 - val_accuracy: 0.0324
# 30/30 [==============================] - 1s 2ms/step
# Accuracy = 0.20234291799787008
# Precision = 0.17415079223158114
# Recall = 0.20234291799787008
# F1 Score = 0.12225131379048403
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# 1. Make predictions with each model and convert them to integers
dt_predictions = dt_clf.predict(Vx).astype(int)
rf_predictions = rf_clf.predict(Vx).astype(int)
ada_predictions = ada_clf.predict(Vx).astype(int)
gb_predictions = gb_clf.predict(Vx).astype(int)
knn_predictions = knn.predict(Vx).astype(int)





lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)


lstm_probs = np.argmax(lstm_probs, axis=1)
bilstm_probs = np.argmax(bilstm_probs, axis=1)


# 2. Aggregate predictions for hard voting
predictions = np.array([dt_predictions, rf_predictions, ada_predictions, gb_predictions, knn_predictions,lstm_probs,bilstm_probs])

# 3. Perform hard voting
hard_votes = np.apply_along_axis(lambda x: np.bincount(x, minlength=len(np.unique(predictions))).argmax(), arr=predictions, axis=0)

# 4. Evaluate hard voting ensemble
hard_voting_accuracy = np.mean(hard_votes == Vy)
print("Hard Voting Accuracy:", hard_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, hard_votes, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, hard_votes, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, hard_votes, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step
# Hard Voting Accuracy: 0.3343982960596379
# Precision: 0.33751312539793965
# Recall: 0.3343982960596379
# F1 Score: 0.3283686309912158

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
dt_probs = dt_clf.predict_proba(Vx)
rf_probs = rf_clf.predict_proba(Vx)
ada_probs = ada_clf.predict_proba(Vx)
gb_probs = gb_clf.predict_proba(Vx)
knn_probs = knn.predict_proba(Vx)


lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)




# KNN should already be able to predict probabilities, but if not, adjustments might be needed.

# 2. Aggregate probabilities for soft voting
probabilities = np.array([dt_probs, rf_probs, ada_probs, gb_probs,knn_probs,lstm_probs,bilstm_probs])

# 3. Perform soft voting
soft_votes = np.mean(probabilities, axis=0)

# 4. Determine the final prediction based on the highest probability
soft_voting_predictions = np.argmax(soft_votes, axis=1)

# 5. Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy:", soft_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, soft_voting_predictions, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, soft_voting_predictions, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, soft_voting_predictions, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 11ms/step
# Soft Voting Accuracy: 0.8242811501597445
# Precision: 0.8295611840760729
# Recall: 0.8242811501597445
# F1 Score: 0.8169353991058335

# %%
# Combine all soft predictions



all_soft_predictions = np.mean(np.array([
    dt_probs, rf_probs, ada_probs, gb_probs,  # Assuming these models provide class probabilities
    lstm_probs, bilstm_probs
]), axis=0)

# Perform soft voting
soft_voting_predictions = np.argmax(all_soft_predictions, axis=1)

# Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy with LSTM and Bi-LSTM:", soft_voting_accuracy)
# Out:
# Soft Voting Accuracy with LSTM and Bi-LSTM: 0.8008519701810437
