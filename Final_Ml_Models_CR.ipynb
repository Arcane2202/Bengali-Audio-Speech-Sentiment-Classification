# %%
# Import the neccessary modules
import pandas as pd
import numpy as np
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read the dataset into a pandas dataframe, df

# %%
# Read the dataset into a dataframe
df = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# %% [markdown]
# **Drop Non Recquired Columns**

# %%
df
# Out:
#                                                    mfccs  zero_crossing_rate  \
# 0      [-4.7883154e+02  3.3325115e+01 -6.4487829e+00 ...            0.158221
# 1      [-4.8954865e+02  2.7738764e+01 -1.2382742e+01 ...            0.337466
# 2      [-4.35193085e+02  4.40335197e+01 -2.84056549e+...            0.287352
# 3      [-4.5051022e+02  3.5520393e+01 -2.6201200e+01 ...            0.319214
# 4      [-4.7573129e+02  2.5805241e+01 -1.5824142e+01 ...            0.154203
# ...                                                  ...                 ...
# 16851  [-4.0630850e+02  3.8935593e+01  4.7740480e-01 ...            0.251618
# 16852  [-3.3170786e+02  4.6200230e+01  3.0691259e+00 ...            0.337181
# 16853  [-3.7679736e+02  4.1225876e+01  5.9078252e-01 ...            0.247278
# 16854  [-3.2025311e+02  4.7039799e+01  2.6084688e-01 ...            0.333771
# 16855  [-3.8849210e+02  4.5433468e+01 -1.5515751e+00 ...            0.235671
#
#        spectral_bandwidth    chroma       rms class_label  \
# 0             2811.724720  0.432150  0.029986       Angry
# 1             2627.283008  0.583449  0.011966       Angry
# 2             2173.834795  0.537973  0.050250       Angry
# 3             2375.562237  0.547021  0.025544       Angry
# 4             2169.616633  0.471881  0.046953       Angry
# ...                   ...       ...       ...         ...
# 16851         2595.763125  0.489838  0.039640    Surprise
# 16852         2410.996505  0.389710  0.117963    Surprise
# 16853         2594.630202  0.492712  0.052451    Surprise
# 16854         2389.176638  0.392537  0.123277    Surprise
# 16855         2539.527857  0.501296  0.050754    Surprise
#
#                                     file_name      mfcc0      mfcc1  \
# 0                    03-01-03-02-01-01-01.wav -478.83154  33.325115
# 1          03-01-03-02-01-01-01_augmented.wav -489.54865  27.738764
# 2                    03-01-03-02-01-01-02.wav -435.19308  44.033520
# 3          03-01-03-02-01-01-02_augmented.wav -450.51022  35.520393
# 4                    03-01-03-02-01-01-04.wav -475.73130  25.805240
# ...                                       ...        ...        ...
# 16851  M_10_EVAN_S_9_SURPRISE_3_augmented.wav -406.30850  38.935593
# 16852            M_10_EVAN_S_9_SURPRISE_4.wav -331.70786  46.200230
# 16853  M_10_EVAN_S_9_SURPRISE_4_augmented.wav -376.79736  41.225876
# 16854            M_10_EVAN_S_9_SURPRISE_5.wav -320.25310  47.039800
# 16855  M_10_EVAN_S_9_SURPRISE_5_augmented.wav -388.49210  45.433468
#
#            mfcc2  ...    mfcc30    mfcc31    mfcc32    mfcc33    mfcc34  \
# 0      -6.448783  ...  0.328626  2.993545  1.607269  0.753363  0.795460
# 1     -12.382742  ...  3.152687  3.479581  0.999255  0.446273 -0.756348
# 2     -28.405655  ... -0.770171 -0.912993 -0.610560 -1.106990 -0.785358
# 3     -26.201200  ...  0.600577  0.524650  0.813930 -1.485857  0.499522
# 4     -15.824142  ... -1.276900 -2.355503  2.545179 -1.319387  0.711873
# ...          ...  ...       ...       ...       ...       ...       ...
# 16851   0.477405  ... -0.671915 -0.215386  0.026275  0.219410 -0.046814
# 16852   3.069126  ...  2.917920  2.602964  0.847366  0.522375 -0.207175
# 16853   0.590782  ...  1.994877  1.314048  1.387961  0.246608  1.195332
# 16854   0.260847  ...  2.386777  2.104635  0.633636  0.841800  0.382966
# 16855  -1.551575  ...  1.153872  1.444134  1.134689  1.218682 -0.183612
#
#          mfcc35    mfcc36    mfcc37    mfcc38    mfcc39
# 0      0.657204  0.285984  0.347409  0.218164 -0.362225
# 1     -0.987419 -0.684020 -0.347724 -0.050397 -0.133484
# 2     -0.564920 -0.417357  0.537306  0.718312  0.528304
# 3     -0.771937  0.126429  0.860468  0.581919  1.637959
# 4      0.455794 -1.546776  0.536169 -0.651819  0.355566
# ...         ...       ...       ...       ...       ...
# 16851 -2.131241 -2.373210 -1.189148  1.648045  1.386102
# 16852  0.567925  0.032568 -0.259393  0.193821  1.031203
# 16853 -0.975989 -0.565488  0.153799  1.977247  1.530025
# 16854  0.831771 -0.528826 -0.969811 -0.152325  0.219692
# 16855 -0.686899 -1.285852  1.008845  0.933691  0.729580
#
# [16856 rows x 47 columns]

# %%
df_test
# Out:
#                                                  mfccs  zero_crossing_rate  \
# 0    [-3.9012119e+02  4.4109344e+01 -1.2921607e+01 ...            0.084918
# 1    [-4.67160522e+02  2.91869411e+01 -1.70986462e+...            0.391429
# 2    [-3.4629849e+02  2.0243580e+01 -1.1391698e+01 ...            0.120882
# 3    [-3.9613730e+02  4.1812637e+01 -1.2806710e+01 ...            0.149057
# 4    [-4.08084534e+02  3.21562920e+01 -1.13426485e+...            0.128189
# ..                                                 ...                 ...
# 934  [-3.15789490e+02  4.11579781e+01 -4.66505718e+...            0.368006
# 935  [-3.0825998e+02  4.2420658e+01 -3.6246645e+00 ...            0.344019
# 936  [-2.97977112e+02  3.52298622e+01 -1.60021079e+...            0.375373
# 937  [-3.0559796e+02  3.6652721e+01 -9.1293299e-01 ...            0.360817
# 938  [-3.4388855e+02  3.9960506e+01  1.3614115e+00 ...            0.372584
#
#      spectral_bandwidth    chroma       rms class_label  \
# 0           2010.457276  0.467693  0.075098       Angry
# 1           2372.973040  0.412228  0.035136       Angry
# 2           2457.125273  0.414273  0.125970       Angry
# 3           2480.510451  0.512132  0.080969       Angry
# 4           2642.601731  0.450778  0.046662       Angry
# ..                  ...       ...       ...         ...
# 934         2421.570717  0.378931  0.104968    Surprise
# 935         2396.946955  0.391811  0.113606    Surprise
# 936         2483.153256  0.394186  0.136011    Surprise
# 937         2486.361872  0.385032  0.128843    Surprise
# 938         2388.725618  0.383467  0.112313    Surprise
#
#                         file_name      mfcc0      mfcc1      mfcc2  ...  \
# 0        03-01-03-02-01-01-03.wav -390.12120  44.109344 -12.921607  ...
# 1        03-01-03-02-01-01-14.wav -467.16052  29.186941 -17.098646  ...
# 2        03-01-03-02-01-01-30.wav -346.29850  20.243580 -11.391698  ...
# 3        03-01-03-02-01-02-25.wav -396.13730  41.812637 -12.806710  ...
# 4        03-01-03-02-01-03-01.wav -408.08453  32.156292 -11.342648  ...
# ..                            ...        ...        ...        ...  ...
# 934  M_10_EVAN_S_5_SURPRISE_3.wav -315.78950  41.157978  -4.665057  ...
# 935  M_10_EVAN_S_5_SURPRISE_4.wav -308.25998  42.420660  -3.624665  ...
# 936  M_10_EVAN_S_6_SURPRISE_2.wav -297.97710  35.229862  -1.600211  ...
# 937  M_10_EVAN_S_6_SURPRISE_5.wav -305.59796  36.652720  -0.912933  ...
# 938  M_10_EVAN_S_9_SURPRISE_2.wav -343.88855  39.960506   1.361411  ...
#
#        mfcc30    mfcc31    mfcc32    mfcc33    mfcc34    mfcc35    mfcc36  \
# 0    0.450648  2.404330  2.840697  4.679700  3.358691  2.829290  2.049688
# 1    2.546051 -0.345007  1.761566  0.331160 -0.264679 -0.082578 -0.519460
# 2    1.983120  2.254916 -0.430221  0.366129 -0.073306 -0.460280  0.677957
# 3    5.819712  1.589295  0.174151 -1.593609  1.364120  1.444026  0.774227
# 4   -1.079431  2.334728 -0.123283  0.738071 -1.139498 -0.480123  1.070031
# ..        ...       ...       ...       ...       ...       ...       ...
# 934  1.781141  2.212446  0.255170  0.355328 -0.191172  0.538170 -0.836946
# 935  1.077347  1.734812 -0.640567  0.225346 -0.893579  0.445937 -0.518387
# 936 -0.261475  1.704446  0.119918  2.339397  0.122162  0.819136  0.680564
# 937 -0.964675  1.582144  0.123939  1.008998 -0.414467  1.555154  1.006149
# 938  2.973702  1.852571 -0.603280  1.001840  1.788876  2.220832  0.560587
#
#        mfcc37    mfcc38    mfcc39
# 0   -0.031819  1.511454  1.466245
# 1   -0.226637 -2.060637 -0.626951
# 2    1.134820 -1.294887  0.309249
# 3    0.248576 -1.265227  0.026068
# 4    0.191624  1.218494  1.468383
# ..        ...       ...       ...
# 934 -0.600881 -0.154892 -0.400183
# 935  1.034477  1.081573  0.678320
# 936  0.174210 -0.836902 -0.645632
# 937  0.085300  0.355210  1.037921
# 938 -0.403364  0.905810  1.237246
#
# [939 rows x 47 columns]

# %%
       """   'zero_crossing_rate',
                'spectral_bandwidth',
                #'chroma',
                'rms',
                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
                """
# Out:
# "   'zero_crossing_rate',\n         'spectral_bandwidth',\n         #'chroma',\n         'rms',\n         'mfcc0',\n         'mfcc1',\n         'mfcc2',\n         'mfcc3',\n         'mfcc4',\n         'mfcc5',\n         'mfcc6',\n         'mfcc7',\n         'mfcc8',\n         'mfcc9',\n         'mfcc10',\n         'mfcc11',\n         'mfcc12',\n         'mfcc13',\n         'mfcc14',\n         'mfcc15',\n         'mfcc16',\n         'mfcc17',\n         'mfcc18',\n         'mfcc19',\n         'mfcc20',\n           'mfcc21',\n             'mfcc22',\n               'mfcc23',\n                  'mfcc24',\n                    'mfcc25',\n                      'mfcc26',\n                        'mfcc27',\n                          'mfcc28',\n                            'mfcc29',\n                              'mfcc30',\n                                'mfcc31',\n                                  'mfcc32',\n                                    'mfcc33',\n                                        'mfcc34',\n                                          'mfcc35',\n                                            'mfcc36',\n                                              'mfcc37',\n                                                'mfcc38',\n                                                  'mfcc39',\n         "

# %%
# Drop some columns which is not relevant to the analysis (they are not numeric)
cols_to_drop=['file_name',
              'mfccs',
              'spectral_bandwidth',

            'zero_crossing_rate',

            #'chroma',
              'rms',


                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
              ]

df = df.drop(cols_to_drop, axis=1)



df_test = df_test.drop(cols_to_drop, axis=1)

# %%
df_test
# Out:
#        chroma class_label
# 0    0.467693       Angry
# 1    0.412228       Angry
# 2    0.414273       Angry
# 3    0.512132       Angry
# 4    0.450778       Angry
# ..        ...         ...
# 934  0.378931    Surprise
# 935  0.391811    Surprise
# 936  0.394186    Surprise
# 937  0.385032    Surprise
# 938  0.383467    Surprise
#
# [939 rows x 2 columns]

# %% [markdown]
# **Label Mapping**

# %%
import pandas as pd

# Sample DataFrame

# Anger, Disgust, Fear, Happiness, Neutral, Sadness and Surprise
# Define a dictionary to map old labels to new labels
label_mapping = {'Happy': '0','Surprise': '1','Angry': '2','Sad': '3','Fear': '4','Disgust': '5','Neutral': '6' }

# Use the map method to change class labels
df['class_label'] = df['class_label'].replace(label_mapping)
df_test['class_label'] = df_test['class_label'].replace(label_mapping)
# Display the updated DataFrame
print(df)
print(df_test)
# Out:
#          chroma class_label
# 0      0.432150           2
# 1      0.583449           2
# 2      0.537973           2
# 3      0.547021           2
# 4      0.471881           2
# ...         ...         ...
# 16851  0.489838           1
# 16852  0.389710           1
# 16853  0.492712           1
# 16854  0.392537           1
# 16855  0.501296           1
#
# [16856 rows x 2 columns]
#        chroma class_label
# 0    0.467693           2
# 1    0.412228           2
# 2    0.414273           2
# 3    0.512132           2
# 4    0.450778           2
# ..        ...         ...
# 934  0.378931           1
# 935  0.391811           1
# 936  0.394186           1
# 937  0.385032           1
# 938  0.383467           1
#
# [939 rows x 2 columns]

# %%
# Seperate the dataframe into X and y data
X = df.values
y = df['class_label'].values

# Delete the Survived column from X
X=df.drop('class_label', axis=1).values

# separate X and y for validation




Vx=df_test.values
Vy=df_test['class_label'].values
Vx= df_test.drop('class_label', axis=1).values

# %%
print(Vx)
# Out:
# [[0.46769324]
#  [0.41222763]
#  [0.41427264]
#  [0.51213247]
#  [0.4507784 ]
#  [0.3893332 ]
#  [0.4573328 ]
#  [0.44774818]
#  [0.43545476]
#  [0.35461277]
#  [0.39948756]
#  [0.45037836]
#  [0.33070183]
#  [0.54371965]
#  [0.4132214 ]
#  [0.37984124]
#  [0.44196236]
#  [0.41536397]
#  [0.43774503]
#  [0.51792735]
#  [0.4112189 ]
#  [0.47118294]
#  [0.39559096]
#  [0.3744774 ]
#  [0.56116337]
#  [0.39411867]
#  [0.287089  ]
#  [0.269022  ]
#  [0.32316855]
#  [0.39548612]
#  [0.3744849 ]
#  [0.40253836]
#  [0.4539842 ]
#  [0.5382944 ]
#  [0.5048251 ]
#  [0.29416755]
#  [0.39136028]
#  [0.5660065 ]
#  [0.42865264]
#  [0.2949085 ]
#  [0.32653406]
#  [0.29246134]
#  [0.43604967]
#  [0.27192613]
#  [0.33665174]
#  [0.57829547]
#  [0.2551503 ]
#  [0.39549395]
#  [0.36009157]
#  [0.36412275]
#  [0.3680109 ]
#  [0.40118378]
#  [0.40227517]
#  [0.29378366]
#  [0.40069792]
#  [0.3914332 ]
#  [0.3795314 ]
#  [0.3713227 ]
#  [0.35721537]
#  [0.38006186]
#  [0.39427975]
#  [0.3827226 ]
#  [0.37877342]
#  [0.37623283]
#  [0.39763668]
#  [0.3912335 ]
#  [0.41830096]
#  [0.431704  ]
#  [0.41693756]
#  [0.3983977 ]
#  [0.408166  ]
#  [0.41040322]
#  [0.44760442]
#  [0.42896068]
#  [0.35477212]
#  [0.3960522 ]
#  [0.40721923]
#  [0.33187076]
#  [0.34422863]
#  [0.3600552 ]
#  [0.37464184]
#  [0.3933193 ]
#  [0.41637897]
#  [0.3554124 ]
#  [0.3461216 ]
#  [0.3997157 ]
#  [0.3810561 ]
#  [0.38875395]
#  [0.38453206]
#  [0.39791253]
#  [0.4097638 ]
#  [0.360594  ]
#  [0.35443926]
#  [0.34325066]
#  [0.34407055]
#  [0.37710068]
#  [0.3795766 ]
#  [0.3854041 ]
#  [0.3756495 ]
#  [0.3823891 ]
#  [0.38494128]
#  [0.38747242]
#  [0.37569645]
#  [0.43110335]
#  [0.4358642 ]
#  [0.3802034 ]
#  [0.4011979 ]
#  [0.3987626 ]
#  [0.39625743]
#  [0.44558102]
#  [0.37949157]
#  [0.4228865 ]
#  [0.42876476]
#  [0.37796408]
#  [0.44483086]
#  [0.2875744 ]
#  [0.32468712]
#  [0.3166874 ]
#  [0.33696008]
#  [0.38316196]
#  [0.38025048]
#  [0.24861583]
#  [0.2916827 ]
#  [0.30739358]
#  [0.36109826]
#  [0.34977764]
#  [0.32084104]
#  [0.25391483]
#  [0.26446143]
#  [0.37300244]
#  [0.324863  ]
#  [0.32796964]
#  [0.3869441 ]
#  [0.38666344]
#  [0.38325822]
#  [0.39555544]
#  [0.36778992]
#  [0.3449527 ]
#  [0.3779715 ]
#  [0.37643075]
#  [0.38376218]
#  [0.39672905]
#  [0.4235203 ]
#  [0.35335636]
#  [0.3505365 ]
#  [0.36078846]
#  [0.37378892]
#  [0.36612564]
#  [0.34651282]
#  [0.33771366]
#  [0.370593  ]
#  [0.35799018]
#  [0.3522875 ]
#  [0.35154817]
#  [0.33920488]
#  [0.35308018]
#  [0.34414726]
#  [0.37432238]
#  [0.3653831 ]
#  [0.43673608]
#  [0.40868172]
#  [0.3942118 ]
#  [0.3582733 ]
#  [0.3282979 ]
#  [0.3136596 ]
#  [0.33144298]
#  [0.36306357]
#  [0.3671655 ]
#  [0.35708737]
#  [0.37878513]
#  [0.37278712]
#  [0.3828286 ]
#  [0.38617048]
#  [0.37088275]
#  [0.38567668]
#  [0.37486622]
#  [0.41123733]
#  [0.4180509 ]
#  [0.29683524]
#  [0.3041121 ]
#  [0.3957552 ]
#  [0.37289026]
#  [0.37643844]
#  [0.37734044]
#  [0.30589232]
#  [0.39462143]
#  [0.3805683 ]
#  [0.3956728 ]
#  [0.41950512]
#  [0.43169326]
#  [0.36717203]
#  [0.34432507]
#  [0.3608973 ]
#  [0.3856587 ]
#  [0.3727907 ]
#  [0.39268738]
#  [0.40378183]
#  [0.39712164]
#  [0.39897752]
#  [0.38065773]
#  [0.3903465 ]
#  [0.37315422]
#  [0.38883805]
#  [0.386524  ]
#  [0.37998903]
#  [0.4139234 ]
#  [0.3996973 ]
#  [0.3757462 ]
#  [0.41389635]
#  [0.34713313]
#  [0.37197238]
#  [0.33838287]
#  [0.37271404]
#  [0.37579843]
#  [0.3905079 ]
#  [0.3747093 ]
#  [0.37805676]
#  [0.37893102]
#  [0.3918105 ]
#  [0.39418566]
#  [0.3850317 ]
#  [0.3834674 ]]

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {'0': 2710, '1': 2350, '2': 2710, '3': 2710, '4': 1800, '5': 2160, '6': 2416}

# %% [markdown]
# Using SMOTE to OverSample Training Data Only

# %%
import numpy as np
from imblearn.over_sampling import SMOTE

# Assuming you have a dataset with features X and labels y


# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X = X.astype(np.float32)
y = y.astype(np.float32)
# Fit and transform the data
X,y = smote.fit_resample(X, y)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X = scaler.fit_transform(X)

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {0.0: 2710, 1.0: 2710, 2.0: 2710, 3.0: 2710, 4.0: 2710, 5.0: 2710, 6.0: 2710}

# %%
print(X.shape)
print(y.shape)
print(Vx.shape)
print(Vy.shape)
# Out:
# (18970, 1)
# (18970,)
# (939, 1)
# (939,)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Perform Classification Using Decision Tree Classifier**

# %%
# Using simple Decision Tree classifier
from sklearn import tree
dt_clf = tree.DecisionTreeClassifier(max_depth=100,random_state=42,criterion='entropy',splitter='best')
dt_clf.fit(X, y)

print(dt_clf.score(X, y))
print(dt_clf.score(Vx, Vy))


prediction_test=dt_clf.predict(Vx)



Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.991723774380601
# 0.0
# Accuracy =  0.14909478168264112
# Precision =  0.1533394818336038
# Recall =  0.14909478168264112
# F1_Score =  0.15043343050038915

# %%
print(Vx.shape)
print(Vy.shape)
print(X.shape)
print(y.shape)
# Out:
# (939, 1)
# (939,)
# (18970, 1)
# (18970,)

# %% [markdown]
# **Perform Classification Using Random Forest Classifier**
#
# Now, we would see if we could get a better results using the the Random Forests Classifier.

# %%
from sklearn import ensemble
rf_clf = ensemble.RandomForestClassifier(n_estimators=100,random_state=42,max_features="sqrt")
rf_clf.fit(X, y)



prediction_test=rf_clf.predict(Vx)

Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.14909478168264112
# Precision =  0.152756226574519
# Recall =  0.14909478168264112
# F1_Score =  0.15026967958586673

# %% [markdown]
# Ada boost classifier

# %%
ada_clf = ensemble.AdaBoostClassifier(n_estimators=50,learning_rate=0.001,random_state=42)
ada_clf.fit(X, y)
ada_clf.score(Vx, Vy)




prediction_test=ada_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.1501597444089457
# Precision =  0.04950238948911327
# Recall =  0.1501597444089457
# F1_Score =  0.06924517916035948
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Perform Classification Using Gradient Boosting Classifier**
#
# This classifier is available in the ensemble module which we already imported. So we don’t need to import anything

# %%
gb_clf = ensemble.GradientBoostingClassifier(n_estimators=30,max_depth=5,max_features=2,learning_rate=0.001)
gb_clf.fit(X, y)
gb_clf.score(Vx,Vy)

print(dt_clf.score(Vx, Vy))


prediction_test=gb_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.14909478168264112
# Accuracy =  0.20766773162939298
# Precision =  0.1840218888845167
# Recall =  0.20766773162939298
# F1_Score =  0.15809808840032355
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.neighbors import KNeighborsClassifier

# create knn classifier
knn = KNeighborsClassifier(n_neighbors = 19)
knn.fit(X, y)
knn.score(X, y)

print(knn.score(Vx, Vy))


prediction_test=knn.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.15761448349307774
# Accuracy =  0.15761448349307774
# Precision =  0.16986484071298513
# Recall =  0.15761448349307774
# F1_Score =  0.15986378496042333

# %%
import joblib
joblib.dump(rf_clf, "rf_Zcr.joblib")
# Out:
# ['rf_Zcr.joblib']

# %%
import joblib
joblib.dump(dt_clf, "dt_Zcr.joblib")
joblib.dump(gb_clf, "rf_Zcr.joblib")
joblib.dump(knn, "rf_Zcr.joblib")
joblib.dump(rf_clf, "rf_Zcr.joblib")
joblib.dump(ada_clf, "rf_Zcr.joblib")
# Out:
# ['dt_Zcr.joblib']

# %% [markdown]
# **LSTM,BI-LSTM model**

# %% [markdown]
# **Bi_lstm
# **

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data



df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# Drop irrelevant columns

df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for BI-LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# BI-LSTM Model
bilstm = Sequential()
bilstm.add(Bidirectional(LSTM(100, return_sequences=True), input_shape=(X_reshaped.shape[1], X_reshaped.shape[2])))  # Set return_sequences=True
bilstm.add(Dropout(0.1))
bilstm.add(Bidirectional(LSTM(50)))  # This layer now receives 3D input as expected
bilstm.add(Dropout(0.1))




bilstm.add(Dense(y_categorical.shape[1], activation='softmax'))














bilstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])






# Train the model
history = bilstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)









# Evaluate the model on the test set
y_pred = bilstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall=metrics.recall_score(y_test, y_pred_classes, average='weighted')



print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 12s 33ms/step - loss: 1.8901 - accuracy: 0.2076 - val_loss: 2.5520 - val_accuracy: 0.0000e+00
# Epoch 2/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8662 - accuracy: 0.2101 - val_loss: 2.6244 - val_accuracy: 0.0000e+00
# Epoch 3/120
# 119/119 [==============================] - 2s 21ms/step - loss: 1.8647 - accuracy: 0.2063 - val_loss: 2.6045 - val_accuracy: 0.0000e+00
# Epoch 4/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.8635 - accuracy: 0.2106 - val_loss: 2.5947 - val_accuracy: 0.0000e+00
# Epoch 5/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8633 - accuracy: 0.2113 - val_loss: 2.5892 - val_accuracy: 0.0000e+00
# Epoch 6/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8636 - accuracy: 0.2099 - val_loss: 2.5657 - val_accuracy: 0.0000e+00
# Epoch 7/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8633 - accuracy: 0.2099 - val_loss: 2.5863 - val_accuracy: 0.0000e+00
# Epoch 8/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8622 - accuracy: 0.2085 - val_loss: 2.6333 - val_accuracy: 0.0000e+00
# Epoch 9/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8629 - accuracy: 0.2085 - val_loss: 2.6171 - val_accuracy: 0.0000e+00
# Epoch 10/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8623 - accuracy: 0.2094 - val_loss: 2.6342 - val_accuracy: 0.0000e+00
# Epoch 11/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8618 - accuracy: 0.2105 - val_loss: 2.6110 - val_accuracy: 0.0000e+00
# Epoch 12/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8618 - accuracy: 0.2107 - val_loss: 2.6413 - val_accuracy: 0.0000e+00
# Epoch 13/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8614 - accuracy: 0.2097 - val_loss: 2.6275 - val_accuracy: 0.0000e+00
# Epoch 14/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8623 - accuracy: 0.2092 - val_loss: 2.6077 - val_accuracy: 0.0000e+00
# Epoch 15/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8612 - accuracy: 0.2118 - val_loss: 2.6040 - val_accuracy: 0.0000e+00
# Epoch 16/120
# 119/119 [==============================] - 5s 44ms/step - loss: 1.8614 - accuracy: 0.2095 - val_loss: 2.6147 - val_accuracy: 0.0000e+00
# Epoch 17/120
# 119/119 [==============================] - 4s 35ms/step - loss: 1.8613 - accuracy: 0.2099 - val_loss: 2.6225 - val_accuracy: 0.0000e+00
# Epoch 18/120
# 119/119 [==============================] - 4s 31ms/step - loss: 1.8607 - accuracy: 0.2105 - val_loss: 2.6128 - val_accuracy: 0.0000e+00
# Epoch 19/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8614 - accuracy: 0.2081 - val_loss: 2.6411 - val_accuracy: 0.0000e+00
# Epoch 20/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8611 - accuracy: 0.2101 - val_loss: 2.5951 - val_accuracy: 0.0000e+00
# Epoch 21/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8607 - accuracy: 0.2082 - val_loss: 2.5718 - val_accuracy: 0.0000e+00
# Epoch 22/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8610 - accuracy: 0.2087 - val_loss: 2.5763 - val_accuracy: 0.0000e+00
# Epoch 23/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8609 - accuracy: 0.2120 - val_loss: 2.6460 - val_accuracy: 0.0000e+00
# Epoch 24/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8610 - accuracy: 0.2088 - val_loss: 2.6282 - val_accuracy: 0.0000e+00
# Epoch 25/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8609 - accuracy: 0.2082 - val_loss: 2.6066 - val_accuracy: 0.0000e+00
# Epoch 26/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8611 - accuracy: 0.2111 - val_loss: 2.5881 - val_accuracy: 0.0000e+00
# Epoch 27/120
# 119/119 [==============================] - 4s 33ms/step - loss: 1.8613 - accuracy: 0.2104 - val_loss: 2.5709 - val_accuracy: 0.0000e+00
# Epoch 28/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8605 - accuracy: 0.2066 - val_loss: 2.5776 - val_accuracy: 0.0000e+00
# Epoch 29/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8607 - accuracy: 0.2097 - val_loss: 2.6505 - val_accuracy: 0.0000e+00
# Epoch 30/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8606 - accuracy: 0.2126 - val_loss: 2.6350 - val_accuracy: 0.0000e+00
# Epoch 31/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8604 - accuracy: 0.2092 - val_loss: 2.6053 - val_accuracy: 0.0000e+00
# Epoch 32/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8601 - accuracy: 0.2118 - val_loss: 2.6467 - val_accuracy: 0.0000e+00
# Epoch 33/120
# 119/119 [==============================] - 3s 23ms/step - loss: 1.8601 - accuracy: 0.2117 - val_loss: 2.6553 - val_accuracy: 0.0000e+00
# Epoch 34/120
# 119/119 [==============================] - 3s 22ms/step - loss: 1.8600 - accuracy: 0.2116 - val_loss: 2.6023 - val_accuracy: 0.0000e+00
# Epoch 35/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8595 - accuracy: 0.2131 - val_loss: 2.6082 - val_accuracy: 0.0000e+00
# Epoch 36/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8598 - accuracy: 0.2093 - val_loss: 2.6237 - val_accuracy: 0.0000e+00
# Epoch 37/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8597 - accuracy: 0.2116 - val_loss: 2.5857 - val_accuracy: 0.0000e+00
# Epoch 38/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8595 - accuracy: 0.2093 - val_loss: 2.5596 - val_accuracy: 0.0000e+00
# Epoch 39/120
# 119/119 [==============================] - 3s 22ms/step - loss: 1.8596 - accuracy: 0.2107 - val_loss: 2.5804 - val_accuracy: 0.0000e+00
# Epoch 40/120
# 119/119 [==============================] - 3s 23ms/step - loss: 1.8595 - accuracy: 0.2079 - val_loss: 2.6140 - val_accuracy: 0.0000e+00
# Epoch 41/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8592 - accuracy: 0.2130 - val_loss: 2.6430 - val_accuracy: 0.0000e+00
# Epoch 42/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8592 - accuracy: 0.2105 - val_loss: 2.6374 - val_accuracy: 0.0000e+00
# Epoch 43/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8589 - accuracy: 0.2116 - val_loss: 2.6125 - val_accuracy: 0.0000e+00
# Epoch 44/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8586 - accuracy: 0.2139 - val_loss: 2.5910 - val_accuracy: 0.0000e+00
# Epoch 45/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8589 - accuracy: 0.2101 - val_loss: 2.5744 - val_accuracy: 0.0000e+00
# Epoch 46/120
# 119/119 [==============================] - 3s 29ms/step - loss: 1.8586 - accuracy: 0.2125 - val_loss: 2.6214 - val_accuracy: 0.0000e+00
# Epoch 47/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8583 - accuracy: 0.2161 - val_loss: 2.6081 - val_accuracy: 0.0000e+00
# Epoch 48/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8583 - accuracy: 0.2127 - val_loss: 2.5938 - val_accuracy: 0.0000e+00
# Epoch 49/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8579 - accuracy: 0.2146 - val_loss: 2.6576 - val_accuracy: 0.0000e+00
# Epoch 50/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8583 - accuracy: 0.2157 - val_loss: 2.5939 - val_accuracy: 0.0000e+00
# Epoch 51/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8581 - accuracy: 0.2115 - val_loss: 2.6142 - val_accuracy: 0.0000e+00
# Epoch 52/120
# 119/119 [==============================] - 3s 22ms/step - loss: 1.8584 - accuracy: 0.2161 - val_loss: 2.6265 - val_accuracy: 0.0000e+00
# Epoch 53/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8582 - accuracy: 0.2148 - val_loss: 2.5596 - val_accuracy: 0.0000e+00
# Epoch 54/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8582 - accuracy: 0.2164 - val_loss: 2.6290 - val_accuracy: 0.0000e+00
# Epoch 55/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8582 - accuracy: 0.2164 - val_loss: 2.6276 - val_accuracy: 0.0000e+00
# Epoch 56/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8578 - accuracy: 0.2165 - val_loss: 2.6227 - val_accuracy: 0.0000e+00
# Epoch 57/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8579 - accuracy: 0.2172 - val_loss: 2.6936 - val_accuracy: 0.0000e+00
# Epoch 58/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.8576 - accuracy: 0.2149 - val_loss: 2.6117 - val_accuracy: 0.0000e+00
# Epoch 59/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8578 - accuracy: 0.2163 - val_loss: 2.6516 - val_accuracy: 0.0000e+00
# Epoch 60/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8580 - accuracy: 0.2138 - val_loss: 2.5854 - val_accuracy: 0.0000e+00
# Epoch 61/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8574 - accuracy: 0.2167 - val_loss: 2.6132 - val_accuracy: 0.0000e+00
# Epoch 62/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8577 - accuracy: 0.2149 - val_loss: 2.6334 - val_accuracy: 0.0000e+00
# Epoch 63/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8578 - accuracy: 0.2151 - val_loss: 2.6199 - val_accuracy: 0.0000e+00
# Epoch 64/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.8575 - accuracy: 0.2153 - val_loss: 2.6474 - val_accuracy: 0.0000e+00
# Epoch 65/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8570 - accuracy: 0.2190 - val_loss: 2.5992 - val_accuracy: 0.0000e+00
# Epoch 66/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8568 - accuracy: 0.2159 - val_loss: 2.6719 - val_accuracy: 0.0000e+00
# Epoch 67/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8577 - accuracy: 0.2151 - val_loss: 2.6170 - val_accuracy: 0.0000e+00
# Epoch 68/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8572 - accuracy: 0.2149 - val_loss: 2.6002 - val_accuracy: 0.0000e+00
# Epoch 69/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8570 - accuracy: 0.2169 - val_loss: 2.6787 - val_accuracy: 0.0000e+00
# Epoch 70/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8568 - accuracy: 0.2158 - val_loss: 2.5713 - val_accuracy: 0.0000e+00
# Epoch 71/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.8571 - accuracy: 0.2167 - val_loss: 2.6334 - val_accuracy: 0.0000e+00
# Epoch 72/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.8565 - accuracy: 0.2170 - val_loss: 2.5717 - val_accuracy: 0.0000e+00
# Epoch 73/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8579 - accuracy: 0.2167 - val_loss: 2.6219 - val_accuracy: 0.0000e+00
# Epoch 74/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8562 - accuracy: 0.2192 - val_loss: 2.5913 - val_accuracy: 0.0000e+00
# Epoch 75/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8572 - accuracy: 0.2161 - val_loss: 2.5676 - val_accuracy: 0.0000e+00
# Epoch 76/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8572 - accuracy: 0.2157 - val_loss: 2.6513 - val_accuracy: 0.0000e+00
# Epoch 77/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8567 - accuracy: 0.2144 - val_loss: 2.6240 - val_accuracy: 0.0000e+00
# Epoch 78/120
# 119/119 [==============================] - 3s 27ms/step - loss: 1.8569 - accuracy: 0.2171 - val_loss: 2.6331 - val_accuracy: 0.0000e+00
# Epoch 79/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8572 - accuracy: 0.2167 - val_loss: 2.6424 - val_accuracy: 0.0000e+00
# Epoch 80/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8565 - accuracy: 0.2155 - val_loss: 2.6066 - val_accuracy: 0.0000e+00
# Epoch 81/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8567 - accuracy: 0.2173 - val_loss: 2.6260 - val_accuracy: 0.0000e+00
# Epoch 82/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8567 - accuracy: 0.2165 - val_loss: 2.6573 - val_accuracy: 0.0000e+00
# Epoch 83/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8567 - accuracy: 0.2162 - val_loss: 2.6520 - val_accuracy: 0.0000e+00
# Epoch 84/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8574 - accuracy: 0.2169 - val_loss: 2.6123 - val_accuracy: 0.0000e+00
# Epoch 85/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8562 - accuracy: 0.2169 - val_loss: 2.6322 - val_accuracy: 0.0000e+00
# Epoch 86/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8574 - accuracy: 0.2149 - val_loss: 2.6773 - val_accuracy: 0.0000e+00
# Epoch 87/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8565 - accuracy: 0.2165 - val_loss: 2.6578 - val_accuracy: 0.0000e+00
# Epoch 88/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8566 - accuracy: 0.2185 - val_loss: 2.5867 - val_accuracy: 0.0000e+00
# Epoch 89/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.8563 - accuracy: 0.2165 - val_loss: 2.6022 - val_accuracy: 0.0000e+00
# Epoch 90/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8570 - accuracy: 0.2161 - val_loss: 2.6017 - val_accuracy: 0.0000e+00
# Epoch 91/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8565 - accuracy: 0.2137 - val_loss: 2.6349 - val_accuracy: 0.0000e+00
# Epoch 92/120
# 119/119 [==============================] - 3s 22ms/step - loss: 1.8569 - accuracy: 0.2168 - val_loss: 2.6293 - val_accuracy: 0.0000e+00
# Epoch 93/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8560 - accuracy: 0.2169 - val_loss: 2.6282 - val_accuracy: 0.0000e+00
# Epoch 94/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8564 - accuracy: 0.2180 - val_loss: 2.6009 - val_accuracy: 0.0000e+00
# Epoch 95/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.8564 - accuracy: 0.2169 - val_loss: 2.6248 - val_accuracy: 0.0000e+00
# Epoch 96/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8566 - accuracy: 0.2169 - val_loss: 2.6100 - val_accuracy: 0.0000e+00
# Epoch 97/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8560 - accuracy: 0.2149 - val_loss: 2.6639 - val_accuracy: 0.0000e+00
# Epoch 98/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8561 - accuracy: 0.2185 - val_loss: 2.6344 - val_accuracy: 0.0000e+00
# Epoch 99/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8563 - accuracy: 0.2156 - val_loss: 2.6134 - val_accuracy: 0.0000e+00
# Epoch 100/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8563 - accuracy: 0.2171 - val_loss: 2.6125 - val_accuracy: 0.0000e+00
# Epoch 101/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8570 - accuracy: 0.2135 - val_loss: 2.5627 - val_accuracy: 0.0000e+00
# Epoch 102/120
# 119/119 [==============================] - 3s 27ms/step - loss: 1.8570 - accuracy: 0.2154 - val_loss: 2.5973 - val_accuracy: 0.0000e+00
# Epoch 103/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8575 - accuracy: 0.2138 - val_loss: 2.5964 - val_accuracy: 0.0000e+00
# Epoch 104/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8564 - accuracy: 0.2162 - val_loss: 2.6323 - val_accuracy: 0.0000e+00
# Epoch 105/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8565 - accuracy: 0.2155 - val_loss: 2.6012 - val_accuracy: 0.0000e+00
# Epoch 106/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8559 - accuracy: 0.2173 - val_loss: 2.6590 - val_accuracy: 0.0000e+00
# Epoch 107/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8564 - accuracy: 0.2167 - val_loss: 2.6310 - val_accuracy: 0.0000e+00
# Epoch 108/120
# 119/119 [==============================] - 3s 27ms/step - loss: 1.8563 - accuracy: 0.2167 - val_loss: 2.6235 - val_accuracy: 0.0000e+00
# Epoch 109/120
# 119/119 [==============================] - 4s 36ms/step - loss: 1.8562 - accuracy: 0.2159 - val_loss: 2.6125 - val_accuracy: 0.0000e+00
# Epoch 110/120
# 119/119 [==============================] - 4s 33ms/step - loss: 1.8561 - accuracy: 0.2175 - val_loss: 2.6457 - val_accuracy: 0.0000e+00
# Epoch 111/120
# 119/119 [==============================] - 4s 36ms/step - loss: 1.8562 - accuracy: 0.2161 - val_loss: 2.5956 - val_accuracy: 0.0000e+00
# Epoch 112/120
# 119/119 [==============================] - 5s 40ms/step - loss: 1.8554 - accuracy: 0.2158 - val_loss: 2.6225 - val_accuracy: 0.0000e+00
# Epoch 113/120
# 119/119 [==============================] - 4s 35ms/step - loss: 1.8560 - accuracy: 0.2158 - val_loss: 2.6196 - val_accuracy: 0.0000e+00
# Epoch 114/120
# 119/119 [==============================] - 3s 27ms/step - loss: 1.8559 - accuracy: 0.2161 - val_loss: 2.6754 - val_accuracy: 0.0000e+00
# Epoch 115/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.8561 - accuracy: 0.2171 - val_loss: 2.6003 - val_accuracy: 0.0000e+00
# Epoch 116/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.8562 - accuracy: 0.2159 - val_loss: 2.6129 - val_accuracy: 0.0000e+00
# Epoch 117/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8553 - accuracy: 0.2165 - val_loss: 2.6132 - val_accuracy: 0.0000e+00
# Epoch 118/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8556 - accuracy: 0.2153 - val_loss: 2.6443 - val_accuracy: 0.0000e+00
# Epoch 119/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8556 - accuracy: 0.2171 - val_loss: 2.6340 - val_accuracy: 0.0000e+00
# Epoch 120/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8559 - accuracy: 0.2135 - val_loss: 2.5939 - val_accuracy: 0.0000e+00
# 30/30 [==============================] - 2s 3ms/step
# Accuracy = 0.2161874334398296
# Precision = 0.1037728258372502
# Recall = 0.2161874334398296
# F1 Score = 0.13797974944115207
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ***lstm***

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data

df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')




df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# LSTM Model
lstm = Sequential()
lstm.add(LSTM(100, input_shape=(X_reshaped.shape[1], X_reshaped.shape[2]), return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(50, return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(20))
lstm.add(Dropout(0.1))

lstm.add(Dense(y_categorical.shape[1], activation='softmax'))

lstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])





# Train the model
history = lstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)







# Evaluate the model on the test set
y_pred = lstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall = metrics.recall_score(y_test, y_pred_classes, average='weighted')

print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 9s 27ms/step - loss: 1.9062 - accuracy: 0.2025 - val_loss: 2.5005 - val_accuracy: 0.0000e+00
# Epoch 2/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8700 - accuracy: 0.2101 - val_loss: 2.5886 - val_accuracy: 0.0000e+00
# Epoch 3/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8682 - accuracy: 0.2080 - val_loss: 2.5717 - val_accuracy: 0.0000e+00
# Epoch 4/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8670 - accuracy: 0.2104 - val_loss: 2.5541 - val_accuracy: 0.0000e+00
# Epoch 5/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8655 - accuracy: 0.2113 - val_loss: 2.5533 - val_accuracy: 0.0000e+00
# Epoch 6/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8649 - accuracy: 0.2089 - val_loss: 2.6112 - val_accuracy: 0.0000e+00
# Epoch 7/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8645 - accuracy: 0.2112 - val_loss: 2.5988 - val_accuracy: 0.0000e+00
# Epoch 8/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8655 - accuracy: 0.2094 - val_loss: 2.5942 - val_accuracy: 0.0000e+00
# Epoch 9/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8632 - accuracy: 0.2121 - val_loss: 2.6370 - val_accuracy: 0.0000e+00
# Epoch 10/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8643 - accuracy: 0.2095 - val_loss: 2.6860 - val_accuracy: 0.0000e+00
# Epoch 11/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8633 - accuracy: 0.2097 - val_loss: 2.6396 - val_accuracy: 0.0000e+00
# Epoch 12/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8633 - accuracy: 0.2102 - val_loss: 2.5492 - val_accuracy: 0.0000e+00
# Epoch 13/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8634 - accuracy: 0.2082 - val_loss: 2.6179 - val_accuracy: 0.0000e+00
# Epoch 14/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8622 - accuracy: 0.2113 - val_loss: 2.5757 - val_accuracy: 0.0000e+00
# Epoch 15/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8627 - accuracy: 0.2099 - val_loss: 2.6083 - val_accuracy: 0.0000e+00
# Epoch 16/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8625 - accuracy: 0.2112 - val_loss: 2.5998 - val_accuracy: 0.0000e+00
# Epoch 17/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8628 - accuracy: 0.2117 - val_loss: 2.6171 - val_accuracy: 0.0000e+00
# Epoch 18/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8625 - accuracy: 0.2084 - val_loss: 2.5989 - val_accuracy: 0.0000e+00
# Epoch 19/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8629 - accuracy: 0.2074 - val_loss: 2.5735 - val_accuracy: 0.0000e+00
# Epoch 20/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8627 - accuracy: 0.2109 - val_loss: 2.5955 - val_accuracy: 0.0000e+00
# Epoch 21/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8628 - accuracy: 0.2128 - val_loss: 2.6039 - val_accuracy: 0.0000e+00
# Epoch 22/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.8629 - accuracy: 0.2092 - val_loss: 2.5979 - val_accuracy: 0.0000e+00
# Epoch 23/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8631 - accuracy: 0.2092 - val_loss: 2.6220 - val_accuracy: 0.0000e+00
# Epoch 24/120
# 119/119 [==============================] - 4s 30ms/step - loss: 1.8618 - accuracy: 0.2128 - val_loss: 2.5816 - val_accuracy: 0.0000e+00
# Epoch 25/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8619 - accuracy: 0.2091 - val_loss: 2.5803 - val_accuracy: 0.0000e+00
# Epoch 26/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8611 - accuracy: 0.2121 - val_loss: 2.5752 - val_accuracy: 0.0000e+00
# Epoch 27/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8619 - accuracy: 0.2111 - val_loss: 2.6046 - val_accuracy: 0.0000e+00
# Epoch 28/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8606 - accuracy: 0.2128 - val_loss: 2.6185 - val_accuracy: 0.0000e+00
# Epoch 29/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8618 - accuracy: 0.2084 - val_loss: 2.6179 - val_accuracy: 0.0000e+00
# Epoch 30/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8605 - accuracy: 0.2083 - val_loss: 2.6195 - val_accuracy: 0.0000e+00
# Epoch 31/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8609 - accuracy: 0.2107 - val_loss: 2.6028 - val_accuracy: 0.0000e+00
# Epoch 32/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8608 - accuracy: 0.2113 - val_loss: 2.6247 - val_accuracy: 0.0000e+00
# Epoch 33/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8619 - accuracy: 0.2088 - val_loss: 2.6061 - val_accuracy: 0.0000e+00
# Epoch 34/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8611 - accuracy: 0.2146 - val_loss: 2.6004 - val_accuracy: 0.0000e+00
# Epoch 35/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8608 - accuracy: 0.2089 - val_loss: 2.5805 - val_accuracy: 0.0000e+00
# Epoch 36/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8604 - accuracy: 0.2122 - val_loss: 2.6164 - val_accuracy: 0.0000e+00
# Epoch 37/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8598 - accuracy: 0.2117 - val_loss: 2.5991 - val_accuracy: 0.0000e+00
# Epoch 38/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8600 - accuracy: 0.2122 - val_loss: 2.6195 - val_accuracy: 0.0000e+00
# Epoch 39/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8600 - accuracy: 0.2099 - val_loss: 2.5696 - val_accuracy: 0.0000e+00
# Epoch 40/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8599 - accuracy: 0.2135 - val_loss: 2.5972 - val_accuracy: 0.0000e+00
# Epoch 41/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8593 - accuracy: 0.2153 - val_loss: 2.5915 - val_accuracy: 0.0000e+00
# Epoch 42/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8592 - accuracy: 0.2117 - val_loss: 2.6139 - val_accuracy: 0.0000e+00
# Epoch 43/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8594 - accuracy: 0.2131 - val_loss: 2.6292 - val_accuracy: 0.0000e+00
# Epoch 44/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8589 - accuracy: 0.2146 - val_loss: 2.5871 - val_accuracy: 0.0000e+00
# Epoch 45/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8596 - accuracy: 0.2163 - val_loss: 2.5896 - val_accuracy: 0.0000e+00
# Epoch 46/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8592 - accuracy: 0.2163 - val_loss: 2.6140 - val_accuracy: 0.0000e+00
# Epoch 47/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8590 - accuracy: 0.2128 - val_loss: 2.6100 - val_accuracy: 0.0000e+00
# Epoch 48/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8582 - accuracy: 0.2129 - val_loss: 2.6426 - val_accuracy: 0.0000e+00
# Epoch 49/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8593 - accuracy: 0.2138 - val_loss: 2.5993 - val_accuracy: 0.0000e+00
# Epoch 50/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8582 - accuracy: 0.2138 - val_loss: 2.6331 - val_accuracy: 0.0000e+00
# Epoch 51/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8585 - accuracy: 0.2147 - val_loss: 2.6092 - val_accuracy: 0.0000e+00
# Epoch 52/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8576 - accuracy: 0.2161 - val_loss: 2.6137 - val_accuracy: 0.0000e+00
# Epoch 53/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8573 - accuracy: 0.2169 - val_loss: 2.6373 - val_accuracy: 0.0000e+00
# Epoch 54/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8580 - accuracy: 0.2157 - val_loss: 2.6386 - val_accuracy: 0.0000e+00
# Epoch 55/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8582 - accuracy: 0.2119 - val_loss: 2.6120 - val_accuracy: 0.0000e+00
# Epoch 56/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8575 - accuracy: 0.2122 - val_loss: 2.6213 - val_accuracy: 0.0000e+00
# Epoch 57/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8583 - accuracy: 0.2173 - val_loss: 2.6119 - val_accuracy: 0.0000e+00
# Epoch 58/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8580 - accuracy: 0.2124 - val_loss: 2.6181 - val_accuracy: 0.0000e+00
# Epoch 59/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8578 - accuracy: 0.2138 - val_loss: 2.6201 - val_accuracy: 0.0000e+00
# Epoch 60/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8573 - accuracy: 0.2169 - val_loss: 2.6416 - val_accuracy: 0.0000e+00
# Epoch 61/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.8571 - accuracy: 0.2163 - val_loss: 2.6200 - val_accuracy: 0.0000e+00
# Epoch 62/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8577 - accuracy: 0.2159 - val_loss: 2.5767 - val_accuracy: 0.0000e+00
# Epoch 63/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8577 - accuracy: 0.2157 - val_loss: 2.6284 - val_accuracy: 0.0000e+00
# Epoch 64/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8584 - accuracy: 0.2155 - val_loss: 2.6093 - val_accuracy: 0.0000e+00
# Epoch 65/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8569 - accuracy: 0.2159 - val_loss: 2.6360 - val_accuracy: 0.0000e+00
# Epoch 66/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8576 - accuracy: 0.2153 - val_loss: 2.6439 - val_accuracy: 0.0000e+00
# Epoch 67/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8571 - accuracy: 0.2151 - val_loss: 2.6179 - val_accuracy: 0.0000e+00
# Epoch 68/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8569 - accuracy: 0.2157 - val_loss: 2.6160 - val_accuracy: 0.0000e+00
# Epoch 69/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8575 - accuracy: 0.2147 - val_loss: 2.6294 - val_accuracy: 0.0000e+00
# Epoch 70/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8577 - accuracy: 0.2162 - val_loss: 2.6232 - val_accuracy: 0.0000e+00
# Epoch 71/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8576 - accuracy: 0.2177 - val_loss: 2.6348 - val_accuracy: 0.0000e+00
# Epoch 72/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8569 - accuracy: 0.2173 - val_loss: 2.6394 - val_accuracy: 0.0000e+00
# Epoch 73/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8580 - accuracy: 0.2163 - val_loss: 2.6163 - val_accuracy: 0.0000e+00
# Epoch 74/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8571 - accuracy: 0.2159 - val_loss: 2.6141 - val_accuracy: 0.0000e+00
# Epoch 75/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8563 - accuracy: 0.2182 - val_loss: 2.6349 - val_accuracy: 0.0000e+00
# Epoch 76/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8575 - accuracy: 0.2178 - val_loss: 2.6074 - val_accuracy: 0.0000e+00
# Epoch 77/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8568 - accuracy: 0.2169 - val_loss: 2.6252 - val_accuracy: 0.0000e+00
# Epoch 78/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8570 - accuracy: 0.2186 - val_loss: 2.6165 - val_accuracy: 0.0000e+00
# Epoch 79/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8573 - accuracy: 0.2151 - val_loss: 2.5926 - val_accuracy: 0.0000e+00
# Epoch 80/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8578 - accuracy: 0.2145 - val_loss: 2.6081 - val_accuracy: 0.0000e+00
# Epoch 81/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8565 - accuracy: 0.2156 - val_loss: 2.6258 - val_accuracy: 0.0000e+00
# Epoch 82/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8568 - accuracy: 0.2186 - val_loss: 2.6280 - val_accuracy: 0.0000e+00
# Epoch 83/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8573 - accuracy: 0.2145 - val_loss: 2.6020 - val_accuracy: 0.0000e+00
# Epoch 84/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8569 - accuracy: 0.2153 - val_loss: 2.6207 - val_accuracy: 0.0000e+00
# Epoch 85/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8566 - accuracy: 0.2166 - val_loss: 2.6399 - val_accuracy: 0.0000e+00
# Epoch 86/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8561 - accuracy: 0.2171 - val_loss: 2.6053 - val_accuracy: 0.0000e+00
# Epoch 87/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8576 - accuracy: 0.2165 - val_loss: 2.6350 - val_accuracy: 0.0000e+00
# Epoch 88/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8562 - accuracy: 0.2196 - val_loss: 2.6395 - val_accuracy: 0.0000e+00
# Epoch 89/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8561 - accuracy: 0.2154 - val_loss: 2.6215 - val_accuracy: 0.0000e+00
# Epoch 90/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8575 - accuracy: 0.2165 - val_loss: 2.6158 - val_accuracy: 0.0000e+00
# Epoch 91/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8569 - accuracy: 0.2186 - val_loss: 2.6235 - val_accuracy: 0.0000e+00
# Epoch 92/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8573 - accuracy: 0.2168 - val_loss: 2.6146 - val_accuracy: 0.0000e+00
# Epoch 93/120
# 119/119 [==============================] - 2s 21ms/step - loss: 1.8564 - accuracy: 0.2157 - val_loss: 2.6310 - val_accuracy: 0.0000e+00
# Epoch 94/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8573 - accuracy: 0.2143 - val_loss: 2.6240 - val_accuracy: 0.0000e+00
# Epoch 95/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8568 - accuracy: 0.2172 - val_loss: 2.6148 - val_accuracy: 0.0000e+00
# Epoch 96/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8573 - accuracy: 0.2172 - val_loss: 2.6216 - val_accuracy: 0.0000e+00
# Epoch 97/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8563 - accuracy: 0.2169 - val_loss: 2.6092 - val_accuracy: 0.0000e+00
# Epoch 98/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8562 - accuracy: 0.2178 - val_loss: 2.6266 - val_accuracy: 0.0000e+00
# Epoch 99/120
# 119/119 [==============================] - 3s 22ms/step - loss: 1.8569 - accuracy: 0.2165 - val_loss: 2.6189 - val_accuracy: 0.0000e+00
# Epoch 100/120
# 119/119 [==============================] - 2s 21ms/step - loss: 1.8562 - accuracy: 0.2151 - val_loss: 2.6272 - val_accuracy: 0.0000e+00
# Epoch 101/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8566 - accuracy: 0.2184 - val_loss: 2.6325 - val_accuracy: 0.0000e+00
# Epoch 102/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8563 - accuracy: 0.2151 - val_loss: 2.6194 - val_accuracy: 0.0000e+00
# Epoch 103/120
# 119/119 [==============================] - 3s 21ms/step - loss: 1.8550 - accuracy: 0.2178 - val_loss: 2.6261 - val_accuracy: 0.0000e+00
# Epoch 104/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8577 - accuracy: 0.2172 - val_loss: 2.6101 - val_accuracy: 0.0000e+00
# Epoch 105/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8568 - accuracy: 0.2159 - val_loss: 2.6279 - val_accuracy: 0.0000e+00
# Epoch 106/120
# 119/119 [==============================] - 3s 25ms/step - loss: 1.8564 - accuracy: 0.2140 - val_loss: 2.6283 - val_accuracy: 0.0000e+00
# Epoch 107/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8566 - accuracy: 0.2170 - val_loss: 2.6186 - val_accuracy: 0.0000e+00
# Epoch 108/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8554 - accuracy: 0.2182 - val_loss: 2.6303 - val_accuracy: 0.0000e+00
# Epoch 109/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8562 - accuracy: 0.2165 - val_loss: 2.6225 - val_accuracy: 0.0000e+00
# Epoch 110/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8568 - accuracy: 0.2135 - val_loss: 2.6168 - val_accuracy: 0.0000e+00
# Epoch 111/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8560 - accuracy: 0.2173 - val_loss: 2.6177 - val_accuracy: 0.0000e+00
# Epoch 112/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8565 - accuracy: 0.2194 - val_loss: 2.6196 - val_accuracy: 0.0000e+00
# Epoch 113/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8563 - accuracy: 0.2165 - val_loss: 2.6229 - val_accuracy: 0.0000e+00
# Epoch 114/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8554 - accuracy: 0.2161 - val_loss: 2.6260 - val_accuracy: 0.0000e+00
# Epoch 115/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8565 - accuracy: 0.2185 - val_loss: 2.6188 - val_accuracy: 0.0098
# Epoch 116/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8555 - accuracy: 0.2196 - val_loss: 2.6244 - val_accuracy: 0.0021
# Epoch 117/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8572 - accuracy: 0.2159 - val_loss: 2.6128 - val_accuracy: 0.0050
# Epoch 118/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8560 - accuracy: 0.2163 - val_loss: 2.6269 - val_accuracy: 0.0098
# Epoch 119/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8553 - accuracy: 0.2188 - val_loss: 2.6234 - val_accuracy: 0.0087
# Epoch 120/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8555 - accuracy: 0.2185 - val_loss: 2.6215 - val_accuracy: 0.0092
# 30/30 [==============================] - 2s 9ms/step
# Accuracy = 0.2055378061767838
# Precision = 0.12589948477602855
# Recall = 0.2055378061767838
# F1 Score = 0.15140521144131552
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# 1. Make predictions with each model and convert them to integers
dt_predictions = dt_clf.predict(Vx).astype(int)
rf_predictions = rf_clf.predict(Vx).astype(int)
ada_predictions = ada_clf.predict(Vx).astype(int)
gb_predictions = gb_clf.predict(Vx).astype(int)
knn_predictions = knn.predict(Vx).astype(int)





lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)


lstm_probs = np.argmax(lstm_probs, axis=1)
bilstm_probs = np.argmax(bilstm_probs, axis=1)


# 2. Aggregate predictions for hard voting
predictions = np.array([dt_predictions, rf_predictions, ada_predictions, gb_predictions, knn_predictions,lstm_probs,bilstm_probs])

# 3. Perform hard voting
hard_votes = np.apply_along_axis(lambda x: np.bincount(x, minlength=len(np.unique(predictions))).argmax(), arr=predictions, axis=0)

# 4. Evaluate hard voting ensemble
hard_voting_accuracy = np.mean(hard_votes == Vy)
print("Hard Voting Accuracy:", hard_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, hard_votes, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, hard_votes, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, hard_votes, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step
# Hard Voting Accuracy: 0.3343982960596379
# Precision: 0.33751312539793965
# Recall: 0.3343982960596379
# F1 Score: 0.3283686309912158

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
dt_probs = dt_clf.predict_proba(Vx)
rf_probs = rf_clf.predict_proba(Vx)
ada_probs = ada_clf.predict_proba(Vx)
gb_probs = gb_clf.predict_proba(Vx)
knn_probs = knn.predict_proba(Vx)


lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)




# KNN should already be able to predict probabilities, but if not, adjustments might be needed.

# 2. Aggregate probabilities for soft voting
probabilities = np.array([dt_probs, rf_probs, ada_probs, gb_probs,knn_probs,lstm_probs,bilstm_probs])

# 3. Perform soft voting
soft_votes = np.mean(probabilities, axis=0)

# 4. Determine the final prediction based on the highest probability
soft_voting_predictions = np.argmax(soft_votes, axis=1)

# 5. Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy:", soft_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, soft_voting_predictions, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, soft_voting_predictions, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, soft_voting_predictions, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 11ms/step
# Soft Voting Accuracy: 0.8242811501597445
# Precision: 0.8295611840760729
# Recall: 0.8242811501597445
# F1 Score: 0.8169353991058335

# %%
# Combine all soft predictions



all_soft_predictions = np.mean(np.array([
    dt_probs, rf_probs, ada_probs, gb_probs,  # Assuming these models provide class probabilities
    lstm_probs, bilstm_probs
]), axis=0)

# Perform soft voting
soft_voting_predictions = np.argmax(all_soft_predictions, axis=1)

# Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy with LSTM and Bi-LSTM:", soft_voting_accuracy)
# Out:
# Soft Voting Accuracy with LSTM and Bi-LSTM: 0.8008519701810437
