# %%
# Import the neccessary modules
import pandas as pd
import numpy as np
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read the dataset into a pandas dataframe, df

# %%
# Read the dataset into a dataframe
df = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# %% [markdown]
# **Drop Non Recquired Columns**

# %%
df
# Out:
#                                                    mfccs  zero_crossing_rate  \
# 0      [-4.7883154e+02  3.3325115e+01 -6.4487829e+00 ...            0.158221
# 1      [-4.8954865e+02  2.7738764e+01 -1.2382742e+01 ...            0.337466
# 2      [-4.35193085e+02  4.40335197e+01 -2.84056549e+...            0.287352
# 3      [-4.5051022e+02  3.5520393e+01 -2.6201200e+01 ...            0.319214
# 4      [-4.7573129e+02  2.5805241e+01 -1.5824142e+01 ...            0.154203
# ...                                                  ...                 ...
# 16851  [-4.0630850e+02  3.8935593e+01  4.7740480e-01 ...            0.251618
# 16852  [-3.3170786e+02  4.6200230e+01  3.0691259e+00 ...            0.337181
# 16853  [-3.7679736e+02  4.1225876e+01  5.9078252e-01 ...            0.247278
# 16854  [-3.2025311e+02  4.7039799e+01  2.6084688e-01 ...            0.333771
# 16855  [-3.8849210e+02  4.5433468e+01 -1.5515751e+00 ...            0.235671
#
#        spectral_bandwidth    chroma       rms class_label  \
# 0             2811.724720  0.432150  0.029986       Angry
# 1             2627.283008  0.583449  0.011966       Angry
# 2             2173.834795  0.537973  0.050250       Angry
# 3             2375.562237  0.547021  0.025544       Angry
# 4             2169.616633  0.471881  0.046953       Angry
# ...                   ...       ...       ...         ...
# 16851         2595.763125  0.489838  0.039640    Surprise
# 16852         2410.996505  0.389710  0.117963    Surprise
# 16853         2594.630202  0.492712  0.052451    Surprise
# 16854         2389.176638  0.392537  0.123277    Surprise
# 16855         2539.527857  0.501296  0.050754    Surprise
#
#                                     file_name      mfcc0      mfcc1  \
# 0                    03-01-03-02-01-01-01.wav -478.83154  33.325115
# 1          03-01-03-02-01-01-01_augmented.wav -489.54865  27.738764
# 2                    03-01-03-02-01-01-02.wav -435.19308  44.033520
# 3          03-01-03-02-01-01-02_augmented.wav -450.51022  35.520393
# 4                    03-01-03-02-01-01-04.wav -475.73130  25.805240
# ...                                       ...        ...        ...
# 16851  M_10_EVAN_S_9_SURPRISE_3_augmented.wav -406.30850  38.935593
# 16852            M_10_EVAN_S_9_SURPRISE_4.wav -331.70786  46.200230
# 16853  M_10_EVAN_S_9_SURPRISE_4_augmented.wav -376.79736  41.225876
# 16854            M_10_EVAN_S_9_SURPRISE_5.wav -320.25310  47.039800
# 16855  M_10_EVAN_S_9_SURPRISE_5_augmented.wav -388.49210  45.433468
#
#            mfcc2  ...    mfcc30    mfcc31    mfcc32    mfcc33    mfcc34  \
# 0      -6.448783  ...  0.328626  2.993545  1.607269  0.753363  0.795460
# 1     -12.382742  ...  3.152687  3.479581  0.999255  0.446273 -0.756348
# 2     -28.405655  ... -0.770171 -0.912993 -0.610560 -1.106990 -0.785358
# 3     -26.201200  ...  0.600577  0.524650  0.813930 -1.485857  0.499522
# 4     -15.824142  ... -1.276900 -2.355503  2.545179 -1.319387  0.711873
# ...          ...  ...       ...       ...       ...       ...       ...
# 16851   0.477405  ... -0.671915 -0.215386  0.026275  0.219410 -0.046814
# 16852   3.069126  ...  2.917920  2.602964  0.847366  0.522375 -0.207175
# 16853   0.590782  ...  1.994877  1.314048  1.387961  0.246608  1.195332
# 16854   0.260847  ...  2.386777  2.104635  0.633636  0.841800  0.382966
# 16855  -1.551575  ...  1.153872  1.444134  1.134689  1.218682 -0.183612
#
#          mfcc35    mfcc36    mfcc37    mfcc38    mfcc39
# 0      0.657204  0.285984  0.347409  0.218164 -0.362225
# 1     -0.987419 -0.684020 -0.347724 -0.050397 -0.133484
# 2     -0.564920 -0.417357  0.537306  0.718312  0.528304
# 3     -0.771937  0.126429  0.860468  0.581919  1.637959
# 4      0.455794 -1.546776  0.536169 -0.651819  0.355566
# ...         ...       ...       ...       ...       ...
# 16851 -2.131241 -2.373210 -1.189148  1.648045  1.386102
# 16852  0.567925  0.032568 -0.259393  0.193821  1.031203
# 16853 -0.975989 -0.565488  0.153799  1.977247  1.530025
# 16854  0.831771 -0.528826 -0.969811 -0.152325  0.219692
# 16855 -0.686899 -1.285852  1.008845  0.933691  0.729580
#
# [16856 rows x 47 columns]

# %%
df_test
# Out:
#                                                  mfccs  zero_crossing_rate  \
# 0    [-3.9012119e+02  4.4109344e+01 -1.2921607e+01 ...            0.084918
# 1    [-4.67160522e+02  2.91869411e+01 -1.70986462e+...            0.391429
# 2    [-3.4629849e+02  2.0243580e+01 -1.1391698e+01 ...            0.120882
# 3    [-3.9613730e+02  4.1812637e+01 -1.2806710e+01 ...            0.149057
# 4    [-4.08084534e+02  3.21562920e+01 -1.13426485e+...            0.128189
# ..                                                 ...                 ...
# 934  [-3.15789490e+02  4.11579781e+01 -4.66505718e+...            0.368006
# 935  [-3.0825998e+02  4.2420658e+01 -3.6246645e+00 ...            0.344019
# 936  [-2.97977112e+02  3.52298622e+01 -1.60021079e+...            0.375373
# 937  [-3.0559796e+02  3.6652721e+01 -9.1293299e-01 ...            0.360817
# 938  [-3.4388855e+02  3.9960506e+01  1.3614115e+00 ...            0.372584
#
#      spectral_bandwidth    chroma       rms class_label  \
# 0           2010.457276  0.467693  0.075098       Angry
# 1           2372.973040  0.412228  0.035136       Angry
# 2           2457.125273  0.414273  0.125970       Angry
# 3           2480.510451  0.512132  0.080969       Angry
# 4           2642.601731  0.450778  0.046662       Angry
# ..                  ...       ...       ...         ...
# 934         2421.570717  0.378931  0.104968    Surprise
# 935         2396.946955  0.391811  0.113606    Surprise
# 936         2483.153256  0.394186  0.136011    Surprise
# 937         2486.361872  0.385032  0.128843    Surprise
# 938         2388.725618  0.383467  0.112313    Surprise
#
#                         file_name      mfcc0      mfcc1      mfcc2  ...  \
# 0        03-01-03-02-01-01-03.wav -390.12120  44.109344 -12.921607  ...
# 1        03-01-03-02-01-01-14.wav -467.16052  29.186941 -17.098646  ...
# 2        03-01-03-02-01-01-30.wav -346.29850  20.243580 -11.391698  ...
# 3        03-01-03-02-01-02-25.wav -396.13730  41.812637 -12.806710  ...
# 4        03-01-03-02-01-03-01.wav -408.08453  32.156292 -11.342648  ...
# ..                            ...        ...        ...        ...  ...
# 934  M_10_EVAN_S_5_SURPRISE_3.wav -315.78950  41.157978  -4.665057  ...
# 935  M_10_EVAN_S_5_SURPRISE_4.wav -308.25998  42.420660  -3.624665  ...
# 936  M_10_EVAN_S_6_SURPRISE_2.wav -297.97710  35.229862  -1.600211  ...
# 937  M_10_EVAN_S_6_SURPRISE_5.wav -305.59796  36.652720  -0.912933  ...
# 938  M_10_EVAN_S_9_SURPRISE_2.wav -343.88855  39.960506   1.361411  ...
#
#        mfcc30    mfcc31    mfcc32    mfcc33    mfcc34    mfcc35    mfcc36  \
# 0    0.450648  2.404330  2.840697  4.679700  3.358691  2.829290  2.049688
# 1    2.546051 -0.345007  1.761566  0.331160 -0.264679 -0.082578 -0.519460
# 2    1.983120  2.254916 -0.430221  0.366129 -0.073306 -0.460280  0.677957
# 3    5.819712  1.589295  0.174151 -1.593609  1.364120  1.444026  0.774227
# 4   -1.079431  2.334728 -0.123283  0.738071 -1.139498 -0.480123  1.070031
# ..        ...       ...       ...       ...       ...       ...       ...
# 934  1.781141  2.212446  0.255170  0.355328 -0.191172  0.538170 -0.836946
# 935  1.077347  1.734812 -0.640567  0.225346 -0.893579  0.445937 -0.518387
# 936 -0.261475  1.704446  0.119918  2.339397  0.122162  0.819136  0.680564
# 937 -0.964675  1.582144  0.123939  1.008998 -0.414467  1.555154  1.006149
# 938  2.973702  1.852571 -0.603280  1.001840  1.788876  2.220832  0.560587
#
#        mfcc37    mfcc38    mfcc39
# 0   -0.031819  1.511454  1.466245
# 1   -0.226637 -2.060637 -0.626951
# 2    1.134820 -1.294887  0.309249
# 3    0.248576 -1.265227  0.026068
# 4    0.191624  1.218494  1.468383
# ..        ...       ...       ...
# 934 -0.600881 -0.154892 -0.400183
# 935  1.034477  1.081573  0.678320
# 936  0.174210 -0.836902 -0.645632
# 937  0.085300  0.355210  1.037921
# 938 -0.403364  0.905810  1.237246
#
# [939 rows x 47 columns]

# %%
       """   'zero_crossing_rate',
                'spectral_bandwidth',
                #'chroma',
                'rms',
                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
                """
# Out:
# "   'zero_crossing_rate',\n         'spectral_bandwidth',\n         #'chroma',\n         'rms',\n         'mfcc0',\n         'mfcc1',\n         'mfcc2',\n         'mfcc3',\n         'mfcc4',\n         'mfcc5',\n         'mfcc6',\n         'mfcc7',\n         'mfcc8',\n         'mfcc9',\n         'mfcc10',\n         'mfcc11',\n         'mfcc12',\n         'mfcc13',\n         'mfcc14',\n         'mfcc15',\n         'mfcc16',\n         'mfcc17',\n         'mfcc18',\n         'mfcc19',\n         'mfcc20',\n           'mfcc21',\n             'mfcc22',\n               'mfcc23',\n                  'mfcc24',\n                    'mfcc25',\n                      'mfcc26',\n                        'mfcc27',\n                          'mfcc28',\n                            'mfcc29',\n                              'mfcc30',\n                                'mfcc31',\n                                  'mfcc32',\n                                    'mfcc33',\n                                        'mfcc34',\n                                          'mfcc35',\n                                            'mfcc36',\n                                              'mfcc37',\n                                                'mfcc38',\n                                                  'mfcc39',\n         "

# %%
# Drop some columns which is not relevant to the analysis (they are not numeric)
cols_to_drop=['file_name',
              'mfccs',
              'spectral_bandwidth',

            #'zero_crossing_rate',

            'chroma',
              'rms',


                'mfcc0',
                'mfcc1',
                'mfcc2',
                'mfcc3',
                'mfcc4',
                'mfcc5',
                'mfcc6',
                'mfcc7',
                'mfcc8',
                'mfcc9',
                'mfcc10',
                'mfcc11',
                'mfcc12',
                'mfcc13',
                'mfcc14',
                'mfcc15',
                'mfcc16',
                'mfcc17',
                'mfcc18',
                'mfcc19',
                'mfcc20',
                  'mfcc21',
                    'mfcc22',
                      'mfcc23',
                         'mfcc24',
                           'mfcc25',
                             'mfcc26',
                               'mfcc27',
                                 'mfcc28',
                                   'mfcc29',
                                     'mfcc30',
                                       'mfcc31',
                                         'mfcc32',
                                           'mfcc33',
                                               'mfcc34',
                                                 'mfcc35',
                                                   'mfcc36',
                                                     'mfcc37',
                                                       'mfcc38',
                                                         'mfcc39',
              ]

df = df.drop(cols_to_drop, axis=1)



df_test = df_test.drop(cols_to_drop, axis=1)

# %%
df_test
# Out:
#      zero_crossing_rate class_label
# 0              0.084918       Angry
# 1              0.391429       Angry
# 2              0.120882       Angry
# 3              0.149057       Angry
# 4              0.128189       Angry
# ..                  ...         ...
# 934            0.368006    Surprise
# 935            0.344019    Surprise
# 936            0.375373    Surprise
# 937            0.360817    Surprise
# 938            0.372584    Surprise
#
# [939 rows x 2 columns]

# %% [markdown]
# **Label Mapping**

# %%
import pandas as pd

# Sample DataFrame

# Anger, Disgust, Fear, Happiness, Neutral, Sadness and Surprise
# Define a dictionary to map old labels to new labels
label_mapping = {'Happy': '0','Surprise': '1','Angry': '2','Sad': '3','Fear': '4','Disgust': '5','Neutral': '6' }

# Use the map method to change class labels
df['class_label'] = df['class_label'].replace(label_mapping)
df_test['class_label'] = df_test['class_label'].replace(label_mapping)
# Display the updated DataFrame
print(df)
print(df_test)
# Out:
#        zero_crossing_rate class_label
# 0                0.158221           2
# 1                0.337466           2
# 2                0.287352           2
# 3                0.319214           2
# 4                0.154203           2
# ...                   ...         ...
# 16851            0.251618           1
# 16852            0.337181           1
# 16853            0.247278           1
# 16854            0.333771           1
# 16855            0.235671           1
#
# [16856 rows x 2 columns]
#      zero_crossing_rate class_label
# 0              0.084918           2
# 1              0.391429           2
# 2              0.120882           2
# 3              0.149057           2
# 4              0.128189           2
# ..                  ...         ...
# 934            0.368006           1
# 935            0.344019           1
# 936            0.375373           1
# 937            0.360817           1
# 938            0.372584           1
#
# [939 rows x 2 columns]

# %%
# Seperate the dataframe into X and y data
X = df.values
y = df['class_label'].values

# Delete the Survived column from X
X=df.drop('class_label', axis=1).values

# separate X and y for validation




Vx=df_test.values
Vy=df_test['class_label'].values
Vx= df_test.drop('class_label', axis=1).values

# %%
print(Vx)
# Out:
# [[0.08491834]
#  [0.39142943]
#  [0.1208824 ]
#  [0.14905696]
#  [0.12818895]
#  [0.13148612]
#  [0.18807938]
#  [0.11876904]
#  [0.03222656]
#  [0.07275391]
#  [0.26135706]
#  [0.08260361]
#  [0.14608673]
#  [0.09660484]
#  [0.17394282]
#  [0.25108754]
#  [0.11932996]
#  [0.19089026]
#  [0.14601445]
#  [0.04428677]
#  [0.49677136]
#  [0.06993114]
#  [0.08554616]
#  [0.23495946]
#  [0.07708356]
#  [0.06940303]
#  [0.10013493]
#  [0.07353292]
#  [0.07161707]
#  [0.13613356]
#  [0.08578468]
#  [0.10775734]
#  [0.06550796]
#  [0.09092468]
#  [0.08890819]
#  [0.09286289]
#  [0.09197951]
#  [0.08678733]
#  [0.15064408]
#  [0.12043028]
#  [0.13210058]
#  [0.14645828]
#  [0.15559772]
#  [0.11082866]
#  [0.05803838]
#  [0.11460073]
#  [0.09297099]
#  [0.09665732]
#  [0.25333939]
#  [0.08381785]
#  [0.30552095]
#  [0.24051219]
#  [0.29575813]
#  [0.12107691]
#  [0.25351057]
#  [0.10855741]
#  [0.27981602]
#  [0.09386572]
#  [0.21443124]
#  [0.23350227]
#  [0.33216314]
#  [0.38104566]
#  [0.32101246]
#  [0.30976788]
#  [0.36951883]
#  [0.3723074 ]
#  [0.40028619]
#  [0.44549135]
#  [0.46309102]
#  [0.10853674]
#  [0.10727034]
#  [0.12684649]
#  [0.11028421]
#  [0.10107702]
#  [0.34992928]
#  [0.4274285 ]
#  [0.42558201]
#  [0.3026109 ]
#  [0.30210578]
#  [0.29359173]
#  [0.41172212]
#  [0.39139671]
#  [0.41899582]
#  [0.31206817]
#  [0.20089687]
#  [0.32690991]
#  [0.31591236]
#  [0.28601495]
#  [0.27074915]
#  [0.29178733]
#  [0.2633727 ]
#  [0.25131331]
#  [0.31484761]
#  [0.29818094]
#  [0.23567338]
#  [0.134257  ]
#  [0.0979753 ]
#  [0.05848555]
#  [0.31346212]
#  [0.36791992]
#  [0.37036728]
#  [0.37409088]
#  [0.32285493]
#  [0.40821154]
#  [0.44558751]
#  [0.23411122]
#  [0.17420759]
#  [0.39974993]
#  [0.31157956]
#  [0.42161122]
#  [0.2617861 ]
#  [0.27708558]
#  [0.27523628]
#  [0.16893685]
#  [0.12691664]
#  [0.13127469]
#  [0.36015232]
#  [0.36639722]
#  [0.33690845]
#  [0.29624842]
#  [0.29612855]
#  [0.40180553]
#  [0.32502133]
#  [0.41098605]
#  [0.42446035]
#  [0.29844087]
#  [0.35226967]
#  [0.35457637]
#  [0.40301163]
#  [0.24017476]
#  [0.25302348]
#  [0.30017578]
#  [0.48308232]
#  [0.38833094]
#  [0.3701768 ]
#  [0.2922281 ]
#  [0.2712106 ]
#  [0.35026136]
#  [0.23231462]
#  [0.29277512]
#  [0.38438959]
#  [0.38274234]
#  [0.41072872]
#  [0.40973251]
#  [0.37897921]
#  [0.39243862]
#  [0.3086162 ]
#  [0.42303958]
#  [0.28831605]
#  [0.41443573]
#  [0.35784   ]
#  [0.36481344]
#  [0.38716797]
#  [0.31852306]
#  [0.32378533]
#  [0.4018695 ]
#  [0.29587879]
#  [0.39812882]
#  [0.20941653]
#  [0.30151087]
#  [0.30918867]
#  [0.32516725]
#  [0.34080067]
#  [0.34035729]
#  [0.36800601]
#  [0.3440194 ]
#  [0.37537323]
#  [0.36081739]
#  [0.37258385]]

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {'0': 2710, '1': 2350, '2': 2710, '3': 2710, '4': 1800, '5': 2160, '6': 2416}

# %% [markdown]
# Using SMOTE to OverSample Training Data Only

# %%
import numpy as np
from imblearn.over_sampling import SMOTE

# Assuming you have a dataset with features X and labels y


# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X = X.astype(np.float32)
y = y.astype(np.float32)
# Fit and transform the data
X,y = smote.fit_resample(X, y)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X = scaler.fit_transform(X)

# %%
unique,count=np.unique(y,return_counts=True)
y_uniq_count={k:v for (k,v) in zip(unique,count)}
y_uniq_count
# Out:
# {0.0: 2710, 1.0: 2710, 2.0: 2710, 3.0: 2710, 4.0: 2710, 5.0: 2710, 6.0: 2710}

# %%
print(X.shape)
print(y.shape)
print(Vx.shape)
print(Vy.shape)
# Out:
# (18970, 1)
# (18970,)
# (939, 1)
# (939,)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Perform Classification Using Decision Tree Classifier**

# %%
# Using simple Decision Tree classifier
from sklearn import tree
dt_clf = tree.DecisionTreeClassifier(max_depth=100,random_state=42,criterion='entropy',splitter='best')
dt_clf.fit(X, y)

print(dt_clf.score(X, y))
print(dt_clf.score(Vx, Vy))


prediction_test=dt_clf.predict(Vx)



Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.9925144965735372
# 0.0
# Accuracy =  0.14376996805111822
# Precision =  0.14582769281825503
# Recall =  0.14376996805111822
# F1_Score =  0.1445542374057115

# %%
print(Vx.shape)
print(Vy.shape)
print(X.shape)
print(y.shape)
# Out:
# (939, 3)
# (939,)
# (18970, 3)
# (18970,)

# %% [markdown]
# **Perform Classification Using Random Forest Classifier**
#
# Now, we would see if we could get a better results using the the Random Forests Classifier.

# %%
from sklearn import ensemble
rf_clf = ensemble.RandomForestClassifier(n_estimators=100,random_state=42,max_features="sqrt")
rf_clf.fit(X, y)



prediction_test=rf_clf.predict(Vx)

Vy=Vy.astype('float32')
print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.1448349307774228
# Precision =  0.14691745411926455
# Recall =  0.1448349307774228
# F1_Score =  0.1456241889809422

# %% [markdown]
# Ada boost classifier

# %%
ada_clf = ensemble.AdaBoostClassifier(n_estimators=50,learning_rate=0.001,random_state=42)
ada_clf.fit(X, y)
ada_clf.score(Vx, Vy)




prediction_test=ada_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy =  0.134185303514377
# Precision =  0.05820409851945007
# Recall =  0.134185303514377
# F1_Score =  0.05958186387860793
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Perform Classification Using Gradient Boosting Classifier**
#
# This classifier is available in the ensemble module which we already imported. So we don’t need to import anything

# %%
gb_clf = ensemble.GradientBoostingClassifier(n_estimators=30,max_depth=5,max_features=2,learning_rate=0.001)
gb_clf.fit(X, y)
gb_clf.score(Vx,Vy)

print(dt_clf.score(Vx, Vy))


prediction_test=gb_clf.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.14376996805111822
# Accuracy =  0.16719914802981894
# Precision =  0.1433831961877087
# Recall =  0.16719914802981894
# F1_Score =  0.14446112739192035

# %%
from sklearn.neighbors import KNeighborsClassifier

# create knn classifier
knn = KNeighborsClassifier(n_neighbors = 19)
knn.fit(X, y)
knn.score(X, y)

print(knn.score(Vx, Vy))


prediction_test=knn.predict(Vx)

print("Accuracy = ",metrics.accuracy_score(Vy,prediction_test))
print("Precision = ",metrics.precision_score(Vy,prediction_test,average='weighted'))
print("Recall = ",metrics.recall_score(Vy,prediction_test,average='weighted'))
print("F1_Score = ",metrics.f1_score(Vy,prediction_test,average='weighted'))

# Confusion Matrix
conf_matrix = confusion_matrix(Vy,prediction_test)

# Custom class labels
class_labels = ['Happy','Surprise','Angry','Sad','Fear','Disgust','Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 0.16080937167199147
# Accuracy =  0.16080937167199147
# Precision =  0.1652936047505133
# Recall =  0.16080937167199147
# F1_Score =  0.16203974665751295

# %%
import joblib
joblib.dump(rf_clf, "rf_Zcr.joblib")
# Out:
# ['rf_Zcr.joblib']

# %%
import joblib
joblib.dump(dt_clf, "dt_Zcr.joblib")
joblib.dump(gb_clf, "rf_Zcr.joblib")
joblib.dump(knn, "rf_Zcr.joblib")
joblib.dump(rf_clf, "rf_Zcr.joblib")
joblib.dump(ada_clf, "rf_Zcr.joblib")
# Out:
# ['dt_Zcr.joblib']

# %% [markdown]
# **LSTM,BI-LSTM model**

# %% [markdown]
# **Bi_lstm
# **

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data



df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')

# Drop irrelevant columns

df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for BI-LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# BI-LSTM Model
bilstm = Sequential()
bilstm.add(Bidirectional(LSTM(100, return_sequences=True), input_shape=(X_reshaped.shape[1], X_reshaped.shape[2])))  # Set return_sequences=True
bilstm.add(Dropout(0.1))
bilstm.add(Bidirectional(LSTM(50)))  # This layer now receives 3D input as expected
bilstm.add(Dropout(0.1))




bilstm.add(Dense(y_categorical.shape[1], activation='softmax'))














bilstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])






# Train the model
history = bilstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)









# Evaluate the model on the test set
y_pred = bilstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall=metrics.recall_score(y_test, y_pred_classes, average='weighted')



print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 12s 28ms/step - loss: 1.8917 - accuracy: 0.2127 - val_loss: 2.7706 - val_accuracy: 0.0000e+00
# Epoch 2/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8659 - accuracy: 0.2123 - val_loss: 2.7579 - val_accuracy: 0.0000e+00
# Epoch 3/120
# 119/119 [==============================] - 3s 29ms/step - loss: 1.8659 - accuracy: 0.2159 - val_loss: 2.7364 - val_accuracy: 0.0000e+00
# Epoch 4/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8654 - accuracy: 0.2163 - val_loss: 2.7983 - val_accuracy: 0.0000e+00
# Epoch 5/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8647 - accuracy: 0.2143 - val_loss: 2.8541 - val_accuracy: 0.0000e+00
# Epoch 6/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8642 - accuracy: 0.2184 - val_loss: 2.7391 - val_accuracy: 0.0000e+00
# Epoch 7/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8637 - accuracy: 0.2161 - val_loss: 2.8060 - val_accuracy: 0.0000e+00
# Epoch 8/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8637 - accuracy: 0.2171 - val_loss: 2.8629 - val_accuracy: 0.0000e+00
# Epoch 9/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8629 - accuracy: 0.2170 - val_loss: 2.7614 - val_accuracy: 0.0000e+00
# Epoch 10/120
# 119/119 [==============================] - 3s 25ms/step - loss: 1.8627 - accuracy: 0.2149 - val_loss: 2.8091 - val_accuracy: 0.0000e+00
# Epoch 11/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8630 - accuracy: 0.2174 - val_loss: 2.7493 - val_accuracy: 0.0000e+00
# Epoch 12/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8620 - accuracy: 0.2186 - val_loss: 2.7359 - val_accuracy: 0.0000e+00
# Epoch 13/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8616 - accuracy: 0.2163 - val_loss: 2.7617 - val_accuracy: 0.0000e+00
# Epoch 14/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8620 - accuracy: 0.2173 - val_loss: 2.7685 - val_accuracy: 0.0000e+00
# Epoch 15/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8614 - accuracy: 0.2196 - val_loss: 2.7398 - val_accuracy: 0.0000e+00
# Epoch 16/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8614 - accuracy: 0.2173 - val_loss: 2.7506 - val_accuracy: 0.0000e+00
# Epoch 17/120
# 119/119 [==============================] - 3s 28ms/step - loss: 1.8608 - accuracy: 0.2191 - val_loss: 2.7540 - val_accuracy: 0.0000e+00
# Epoch 18/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8606 - accuracy: 0.2188 - val_loss: 2.7275 - val_accuracy: 0.0000e+00
# Epoch 19/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8604 - accuracy: 0.2176 - val_loss: 2.7570 - val_accuracy: 0.0000e+00
# Epoch 20/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8602 - accuracy: 0.2175 - val_loss: 2.7683 - val_accuracy: 0.0000e+00
# Epoch 21/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8597 - accuracy: 0.2167 - val_loss: 2.7449 - val_accuracy: 0.0000e+00
# Epoch 22/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8597 - accuracy: 0.2161 - val_loss: 2.7513 - val_accuracy: 0.0000e+00
# Epoch 23/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8592 - accuracy: 0.2165 - val_loss: 2.8229 - val_accuracy: 0.0000e+00
# Epoch 24/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8590 - accuracy: 0.2174 - val_loss: 2.7927 - val_accuracy: 0.0000e+00
# Epoch 25/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8597 - accuracy: 0.2173 - val_loss: 2.7549 - val_accuracy: 0.0000e+00
# Epoch 26/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8589 - accuracy: 0.2174 - val_loss: 2.7934 - val_accuracy: 0.0000e+00
# Epoch 27/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8591 - accuracy: 0.2178 - val_loss: 2.7601 - val_accuracy: 0.0000e+00
# Epoch 28/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8584 - accuracy: 0.2172 - val_loss: 2.8134 - val_accuracy: 0.0000e+00
# Epoch 29/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8577 - accuracy: 0.2178 - val_loss: 2.7600 - val_accuracy: 0.0000e+00
# Epoch 30/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8582 - accuracy: 0.2183 - val_loss: 2.7194 - val_accuracy: 0.0000e+00
# Epoch 31/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.8575 - accuracy: 0.2185 - val_loss: 2.7722 - val_accuracy: 0.0000e+00
# Epoch 32/120
# 119/119 [==============================] - 3s 21ms/step - loss: 1.8585 - accuracy: 0.2167 - val_loss: 2.7494 - val_accuracy: 0.0000e+00
# Epoch 33/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8576 - accuracy: 0.2192 - val_loss: 2.8065 - val_accuracy: 0.0000e+00
# Epoch 34/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8579 - accuracy: 0.2186 - val_loss: 2.7687 - val_accuracy: 0.0000e+00
# Epoch 35/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8565 - accuracy: 0.2175 - val_loss: 2.7747 - val_accuracy: 0.0000e+00
# Epoch 36/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8576 - accuracy: 0.2186 - val_loss: 2.7667 - val_accuracy: 0.0000e+00
# Epoch 37/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8562 - accuracy: 0.2204 - val_loss: 2.7337 - val_accuracy: 0.0000e+00
# Epoch 38/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8574 - accuracy: 0.2176 - val_loss: 2.7623 - val_accuracy: 0.0000e+00
# Epoch 39/120
# 119/119 [==============================] - 3s 23ms/step - loss: 1.8565 - accuracy: 0.2173 - val_loss: 2.7785 - val_accuracy: 0.0000e+00
# Epoch 40/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8575 - accuracy: 0.2192 - val_loss: 2.7777 - val_accuracy: 0.0000e+00
# Epoch 41/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8568 - accuracy: 0.2173 - val_loss: 2.7461 - val_accuracy: 0.0000e+00
# Epoch 42/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8580 - accuracy: 0.2198 - val_loss: 2.7262 - val_accuracy: 0.0000e+00
# Epoch 43/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8566 - accuracy: 0.2184 - val_loss: 2.7694 - val_accuracy: 2.6357e-04
# Epoch 44/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8567 - accuracy: 0.2166 - val_loss: 2.7474 - val_accuracy: 0.0000e+00
# Epoch 45/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8561 - accuracy: 0.2199 - val_loss: 2.8109 - val_accuracy: 0.0000e+00
# Epoch 46/120
# 119/119 [==============================] - 3s 25ms/step - loss: 1.8564 - accuracy: 0.2205 - val_loss: 2.7516 - val_accuracy: 0.0000e+00
# Epoch 47/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8571 - accuracy: 0.2174 - val_loss: 2.8424 - val_accuracy: 0.0000e+00
# Epoch 48/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8570 - accuracy: 0.2174 - val_loss: 2.7592 - val_accuracy: 0.0000e+00
# Epoch 49/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8572 - accuracy: 0.2165 - val_loss: 2.7732 - val_accuracy: 0.0000e+00
# Epoch 50/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8558 - accuracy: 0.2165 - val_loss: 2.7656 - val_accuracy: 0.0000e+00
# Epoch 51/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8567 - accuracy: 0.2190 - val_loss: 2.7785 - val_accuracy: 0.0000e+00
# Epoch 52/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8558 - accuracy: 0.2189 - val_loss: 2.7975 - val_accuracy: 0.0000e+00
# Epoch 53/120
# 119/119 [==============================] - 3s 23ms/step - loss: 1.8559 - accuracy: 0.2186 - val_loss: 2.7238 - val_accuracy: 7.9072e-04
# Epoch 54/120
# 119/119 [==============================] - 3s 25ms/step - loss: 1.8569 - accuracy: 0.2200 - val_loss: 2.7834 - val_accuracy: 0.0000e+00
# Epoch 55/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8559 - accuracy: 0.2209 - val_loss: 2.7759 - val_accuracy: 2.6357e-04
# Epoch 56/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8561 - accuracy: 0.2198 - val_loss: 2.8202 - val_accuracy: 0.0000e+00
# Epoch 57/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8560 - accuracy: 0.2205 - val_loss: 2.7059 - val_accuracy: 0.0011
# Epoch 58/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8559 - accuracy: 0.2173 - val_loss: 2.8205 - val_accuracy: 0.0000e+00
# Epoch 59/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8552 - accuracy: 0.2206 - val_loss: 2.7343 - val_accuracy: 2.6357e-04
# Epoch 60/120
# 119/119 [==============================] - 3s 25ms/step - loss: 1.8558 - accuracy: 0.2194 - val_loss: 2.7556 - val_accuracy: 0.0000e+00
# Epoch 61/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8551 - accuracy: 0.2205 - val_loss: 2.8216 - val_accuracy: 0.0024
# Epoch 62/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8555 - accuracy: 0.2176 - val_loss: 2.7748 - val_accuracy: 0.0018
# Epoch 63/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8563 - accuracy: 0.2174 - val_loss: 2.8057 - val_accuracy: 0.0021
# Epoch 64/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8557 - accuracy: 0.2211 - val_loss: 2.7655 - val_accuracy: 0.0011
# Epoch 65/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8544 - accuracy: 0.2203 - val_loss: 2.7694 - val_accuracy: 2.6357e-04
# Epoch 66/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8547 - accuracy: 0.2203 - val_loss: 2.7312 - val_accuracy: 0.0024
# Epoch 67/120
# 119/119 [==============================] - 3s 22ms/step - loss: 1.8545 - accuracy: 0.2180 - val_loss: 2.8087 - val_accuracy: 0.0011
# Epoch 68/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8554 - accuracy: 0.2184 - val_loss: 2.7404 - val_accuracy: 0.0000e+00
# Epoch 69/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8545 - accuracy: 0.2186 - val_loss: 2.7902 - val_accuracy: 0.0011
# Epoch 70/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8546 - accuracy: 0.2179 - val_loss: 2.8072 - val_accuracy: 5.2715e-04
# Epoch 71/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8541 - accuracy: 0.2176 - val_loss: 2.7689 - val_accuracy: 2.6357e-04
# Epoch 72/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8543 - accuracy: 0.2211 - val_loss: 2.7041 - val_accuracy: 0.0018
# Epoch 73/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8541 - accuracy: 0.2194 - val_loss: 2.7496 - val_accuracy: 0.0021
# Epoch 74/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8536 - accuracy: 0.2199 - val_loss: 2.7696 - val_accuracy: 0.0024
# Epoch 75/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8540 - accuracy: 0.2201 - val_loss: 2.7729 - val_accuracy: 0.0021
# Epoch 76/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8538 - accuracy: 0.2194 - val_loss: 2.7893 - val_accuracy: 0.0021
# Epoch 77/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8543 - accuracy: 0.2195 - val_loss: 2.7619 - val_accuracy: 5.2715e-04
# Epoch 78/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8536 - accuracy: 0.2190 - val_loss: 2.7448 - val_accuracy: 2.6357e-04
# Epoch 79/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8537 - accuracy: 0.2205 - val_loss: 2.7490 - val_accuracy: 0.0021
# Epoch 80/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8536 - accuracy: 0.2167 - val_loss: 2.7852 - val_accuracy: 0.0021
# Epoch 81/120
# 119/119 [==============================] - 2s 19ms/step - loss: 1.8535 - accuracy: 0.2192 - val_loss: 2.7850 - val_accuracy: 0.0013
# Epoch 82/120
# 119/119 [==============================] - 2s 21ms/step - loss: 1.8530 - accuracy: 0.2207 - val_loss: 2.7417 - val_accuracy: 7.9072e-04
# Epoch 83/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8528 - accuracy: 0.2201 - val_loss: 2.7886 - val_accuracy: 0.0024
# Epoch 84/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8528 - accuracy: 0.2192 - val_loss: 2.7288 - val_accuracy: 0.0026
# Epoch 85/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8530 - accuracy: 0.2190 - val_loss: 2.7632 - val_accuracy: 0.0021
# Epoch 86/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8531 - accuracy: 0.2179 - val_loss: 2.7332 - val_accuracy: 0.0013
# Epoch 87/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8535 - accuracy: 0.2207 - val_loss: 2.8086 - val_accuracy: 0.0013
# Epoch 88/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8524 - accuracy: 0.2195 - val_loss: 2.7772 - val_accuracy: 0.0021
# Epoch 89/120
# 119/119 [==============================] - 3s 26ms/step - loss: 1.8527 - accuracy: 0.2207 - val_loss: 2.7870 - val_accuracy: 0.0018
# Epoch 90/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8516 - accuracy: 0.2205 - val_loss: 2.7403 - val_accuracy: 0.0018
# Epoch 91/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8531 - accuracy: 0.2211 - val_loss: 2.7533 - val_accuracy: 0.0029
# Epoch 92/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8531 - accuracy: 0.2192 - val_loss: 2.7940 - val_accuracy: 0.0037
# Epoch 93/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8524 - accuracy: 0.2200 - val_loss: 2.7175 - val_accuracy: 0.0021
# Epoch 94/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.
120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8508 - accuracy: 0.2196 - val_loss: 2.7529 - val_accuracy: 0.0026
# 30/30 [==============================] - 2s 4ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy = 0.17252396166134185
# Precision = 0.1365885319613047
# Recall = 0.17252396166134185
# F1 Score = 0.10463957011072333

# %% [markdown]
# ***bi-lstm***

# %%
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load training data

df_train = pd.read_csv('/content/drive/MyDrive/Softcom/Train_Data.csv', sep=',', engine='python')
df_test = pd.read_csv('/content/drive/MyDrive/Softcom/Test_Data.csv', sep=',', engine='python')




df_train = df_train.drop(cols_to_drop, axis=1)

# Class label mapping
label_mapping = {'Happy': 0, 'Surprise': 1, 'Angry': 2, 'Sad': 3, 'Fear': 4, 'Disgust': 5, 'Neutral': 6}
df_train['class_label'] = df_train['class_label'].replace(label_mapping)

# Separate features and labels for training
X_train = df_train.drop('class_label', axis=1).values
y_train = df_train['class_label'].values

# Apply SMOTE for class imbalance
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# One-hot encode labels
y_categorical = to_categorical(y_resampled)

# Reshape features for LSTM
X_reshaped = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))



# Drop irrelevant columns
df_test = df_test.drop(cols_to_drop, axis=1)

# Class label mapping
df_test['class_label'] = df_test['class_label'].replace(label_mapping)

# Separate features and labels for testing
X_test = df_test.drop('class_label', axis=1).values
y_test = df_test['class_label'].values

# Standardize features for testing
X_test_scaled = scaler.transform(X_test)
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# LSTM Model
lstm = Sequential()
lstm.add(LSTM(100, input_shape=(X_reshaped.shape[1], X_reshaped.shape[2]), return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(50, return_sequences=True))
lstm.add(Dropout(0.1))
lstm.add(LSTM(20))
lstm.add(Dropout(0.1))

lstm.add(Dense(y_categorical.shape[1], activation='softmax'))

lstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])





# Train the model
history = lstm.fit(X_reshaped, y_categorical, epochs=120, batch_size=128, validation_split=0.2)







# Evaluate the model on the test set
y_pred = lstm.predict(X_test_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate evaluation metrics
accuracy = metrics.accuracy_score(y_test, y_pred_classes)
precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
f1_score = metrics.f1_score(y_test, y_pred_classes, average='weighted')
recall = metrics.recall_score(y_test, y_pred_classes, average='weighted')

print("Accuracy =", accuracy)
print("Precision =", precision)
print("Recall =", recall)
print("F1 Score =", f1_score)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Custom class labels
class_labels = ['Happy', 'Surprise', 'Angry', 'Sad', 'Fear', 'Disgust', 'Neutral']

# Display the confusion matrix using a heatmap
conf_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_df, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/120
# 119/119 [==============================] - 8s 20ms/step - loss: 1.9099 - accuracy: 0.2032 - val_loss: 2.6265 - val_accuracy: 0.0000e+00
# Epoch 2/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8699 - accuracy: 0.2069 - val_loss: 2.6999 - val_accuracy: 0.0000e+00
# Epoch 3/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8674 - accuracy: 0.2093 - val_loss: 2.7621 - val_accuracy: 0.0000e+00
# Epoch 4/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8683 - accuracy: 0.2157 - val_loss: 2.7295 - val_accuracy: 0.0000e+00
# Epoch 5/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8672 - accuracy: 0.2131 - val_loss: 2.7111 - val_accuracy: 0.0000e+00
# Epoch 6/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8660 - accuracy: 0.2156 - val_loss: 2.8000 - val_accuracy: 0.0000e+00
# Epoch 7/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8648 - accuracy: 0.2155 - val_loss: 2.7210 - val_accuracy: 0.0000e+00
# Epoch 8/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8646 - accuracy: 0.2159 - val_loss: 2.7709 - val_accuracy: 0.0000e+00
# Epoch 9/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8645 - accuracy: 0.2167 - val_loss: 2.7516 - val_accuracy: 0.0000e+00
# Epoch 10/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8634 - accuracy: 0.2152 - val_loss: 2.7530 - val_accuracy: 0.0000e+00
# Epoch 11/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8629 - accuracy: 0.2147 - val_loss: 2.7688 - val_accuracy: 0.0000e+00
# Epoch 12/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8634 - accuracy: 0.2175 - val_loss: 2.7423 - val_accuracy: 0.0000e+00
# Epoch 13/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8625 - accuracy: 0.2175 - val_loss: 2.7826 - val_accuracy: 0.0000e+00
# Epoch 14/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8614 - accuracy: 0.2192 - val_loss: 2.7982 - val_accuracy: 0.0000e+00
# Epoch 15/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8621 - accuracy: 0.2170 - val_loss: 2.7323 - val_accuracy: 0.0000e+00
# Epoch 16/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8613 - accuracy: 0.2181 - val_loss: 2.7509 - val_accuracy: 0.0000e+00
# Epoch 17/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8613 - accuracy: 0.2182 - val_loss: 2.7829 - val_accuracy: 0.0000e+00
# Epoch 18/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8604 - accuracy: 0.2164 - val_loss: 2.7453 - val_accuracy: 0.0000e+00
# Epoch 19/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8608 - accuracy: 0.2176 - val_loss: 2.7271 - val_accuracy: 0.0000e+00
# Epoch 20/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8603 - accuracy: 0.2182 - val_loss: 2.7463 - val_accuracy: 0.0000e+00
# Epoch 21/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8600 - accuracy: 0.2178 - val_loss: 2.7159 - val_accuracy: 0.0000e+00
# Epoch 22/120
# 119/119 [==============================] - 3s 21ms/step - loss: 1.8598 - accuracy: 0.2177 - val_loss: 2.7502 - val_accuracy: 0.0000e+00
# Epoch 23/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8595 - accuracy: 0.2179 - val_loss: 2.6859 - val_accuracy: 0.0000e+00
# Epoch 24/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8595 - accuracy: 0.2172 - val_loss: 2.7722 - val_accuracy: 0.0000e+00
# Epoch 25/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8585 - accuracy: 0.2175 - val_loss: 2.7492 - val_accuracy: 0.0000e+00
# Epoch 26/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8586 - accuracy: 0.2171 - val_loss: 2.7320 - val_accuracy: 0.0000e+00
# Epoch 27/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8578 - accuracy: 0.2187 - val_loss: 2.8140 - val_accuracy: 0.0000e+00
# Epoch 28/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8587 - accuracy: 0.2183 - val_loss: 2.8172 - val_accuracy: 0.0000e+00
# Epoch 29/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8581 - accuracy: 0.2184 - val_loss: 2.7458 - val_accuracy: 0.0000e+00
# Epoch 30/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8582 - accuracy: 0.2180 - val_loss: 2.7158 - val_accuracy: 0.0000e+00
# Epoch 31/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8577 - accuracy: 0.2174 - val_loss: 2.7251 - val_accuracy: 0.0000e+00
# Epoch 32/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8584 - accuracy: 0.2176 - val_loss: 2.7552 - val_accuracy: 0.0000e+00
# Epoch 33/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8582 - accuracy: 0.2153 - val_loss: 2.7421 - val_accuracy: 0.0000e+00
# Epoch 34/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8564 - accuracy: 0.2198 - val_loss: 2.7278 - val_accuracy: 0.0000e+00
# Epoch 35/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8577 - accuracy: 0.2192 - val_loss: 2.7468 - val_accuracy: 0.0000e+00
# Epoch 36/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8570 - accuracy: 0.2175 - val_loss: 2.7545 - val_accuracy: 0.0000e+00
# Epoch 37/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8579 - accuracy: 0.2182 - val_loss: 2.7570 - val_accuracy: 0.0000e+00
# Epoch 38/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8564 - accuracy: 0.2178 - val_loss: 2.7924 - val_accuracy: 0.0000e+00
# Epoch 39/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8581 - accuracy: 0.2199 - val_loss: 2.7268 - val_accuracy: 0.0000e+00
# Epoch 40/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8573 - accuracy: 0.2182 - val_loss: 2.7035 - val_accuracy: 0.0000e+00
# Epoch 41/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8565 - accuracy: 0.2173 - val_loss: 2.7430 - val_accuracy: 0.0000e+00
# Epoch 42/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8564 - accuracy: 0.2186 - val_loss: 2.7181 - val_accuracy: 0.0000e+00
# Epoch 43/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8567 - accuracy: 0.2199 - val_loss: 2.7492 - val_accuracy: 0.0000e+00
# Epoch 44/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8562 - accuracy: 0.2184 - val_loss: 2.7673 - val_accuracy: 0.0000e+00
# Epoch 45/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8567 - accuracy: 0.2172 - val_loss: 2.7229 - val_accuracy: 0.0000e+00
# Epoch 46/120
# 119/119 [==============================] - 2s 17ms/step - loss: 1.8557 - accuracy: 0.2195 - val_loss: 2.7397 - val_accuracy: 0.0000e+00
# Epoch 47/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8561 - accuracy: 0.2200 - val_loss: 2.7243 - val_accuracy: 0.0000e+00
# Epoch 48/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8562 - accuracy: 0.2171 - val_loss: 2.7914 - val_accuracy: 0.0000e+00
# Epoch 49/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8570 - accuracy: 0.2203 - val_loss: 2.7487 - val_accuracy: 0.0000e+00
# Epoch 50/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8567 - accuracy: 0.2184 - val_loss: 2.7871 - val_accuracy: 0.0000e+00
# Epoch 51/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8566 - accuracy: 0.2184 - val_loss: 2.7915 - val_accuracy: 0.0000e+00
# Epoch 52/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8566 - accuracy: 0.2184 - val_loss: 2.7451 - val_accuracy: 0.0000e+00
# Epoch 53/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8557 - accuracy: 0.2181 - val_loss: 2.7513 - val_accuracy: 0.0000e+00
# Epoch 54/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8556 - accuracy: 0.2163 - val_loss: 2.8105 - val_accuracy: 0.0000e+00
# Epoch 55/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8547 - accuracy: 0.2186 - val_loss: 2.7885 - val_accuracy: 0.0000e+00
# Epoch 56/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8553 - accuracy: 0.2194 - val_loss: 2.7768 - val_accuracy: 0.0000e+00
# Epoch 57/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8557 - accuracy: 0.2185 - val_loss: 2.7479 - val_accuracy: 0.0000e+00
# Epoch 58/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8563 - accuracy: 0.2204 - val_loss: 2.7771 - val_accuracy: 0.0000e+00
# Epoch 59/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8558 - accuracy: 0.2185 - val_loss: 2.7340 - val_accuracy: 0.0000e+00
# Epoch 60/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8551 - accuracy: 0.2211 - val_loss: 2.7550 - val_accuracy: 0.0000e+00
# Epoch 61/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8550 - accuracy: 0.2207 - val_loss: 2.7606 - val_accuracy: 0.0000e+00
# Epoch 62/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8551 - accuracy: 0.2190 - val_loss: 2.7996 - val_accuracy: 0.0000e+00
# Epoch 63/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8546 - accuracy: 0.2209 - val_loss: 2.7468 - val_accuracy: 0.0000e+00
# Epoch 64/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8554 - accuracy: 0.2210 - val_loss: 2.7757 - val_accuracy: 0.0000e+00
# Epoch 65/120
# 119/119 [==============================] - 1s 12ms/step - loss: 1.8551 - accuracy: 0.2176 - val_loss: 2.7453 - val_accuracy: 0.0000e+00
# Epoch 66/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8556 - accuracy: 0.2213 - val_loss: 2.8377 - val_accuracy: 0.0000e+00
# Epoch 67/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8547 - accuracy: 0.2194 - val_loss: 2.7763 - val_accuracy: 0.0000e+00
# Epoch 68/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8553 - accuracy: 0.2190 - val_loss: 2.7648 - val_accuracy: 0.0000e+00
# Epoch 69/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8543 - accuracy: 0.2209 - val_loss: 2.7827 - val_accuracy: 0.0000e+00
# Epoch 70/120
# 119/119 [==============================] - 3s 24ms/step - loss: 1.8550 - accuracy: 0.2194 - val_loss: 2.7516 - val_accuracy: 0.0000e+00
# Epoch 71/120
# 119/119 [==============================] - 3s 23ms/step - loss: 1.8548 - accuracy: 0.2187 - val_loss: 2.7778 - val_accuracy: 0.0000e+00
# Epoch 72/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8542 - accuracy: 0.2189 - val_loss: 2.7568 - val_accuracy: 0.0000e+00
# Epoch 73/120
# 119/119 [==============================] - 2s 20ms/step - loss: 1.8542 - accuracy: 0.2196 - val_loss: 2.7766 - val_accuracy: 0.0000e+00
# Epoch 74/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8546 - accuracy: 0.2183 - val_loss: 2.7760 - val_accuracy: 0.0000e+00
# Epoch 75/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8545 - accuracy: 0.2178 - val_loss: 2.7762 - val_accuracy: 0.0000e+00
# Epoch 76/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8539 - accuracy: 0.2207 - val_loss: 2.7897 - val_accuracy: 0.0000e+00
# Epoch 77/120
# 119/119 [==============================] - 2s 13ms/step - loss: 1.8546 - accuracy: 0.2187 - val_loss: 2.7948 - val_accuracy: 0.0000e+00
# Epoch 78/120
# 119/119 [==============================] - 2s 18ms/step - loss: 1.8544 - accuracy: 0.2199 - val_loss: 2.8042 - val_accuracy: 2.6357e-04
# Epoch 79/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8540 - accuracy: 0.2207 - val_loss: 2.7757 - val_accuracy: 2.6357e-04
# Epoch 80/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8541 - accuracy: 0.2200 - val_loss: 2.7989 - val_accuracy: 5.2715e-04
# Epoch 81/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8544 - accuracy: 0.2230 - val_loss: 2.7923 - val_accuracy: 0.0000e+00
# Epoch 82/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8543 - accuracy: 0.2177 - val_loss: 2.7725 - val_accuracy: 2.6357e-04
# Epoch 83/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8542 - accuracy: 0.2180 - val_loss: 2.7961 - val_accuracy: 2.6357e-04
# Epoch 84/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8545 - accuracy: 0.2217 - val_loss: 2.7812 - val_accuracy: 2.6357e-04
# Epoch 85/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8537 - accuracy: 0.2211 - val_loss: 2.7841 - val_accuracy: 0.0000e+00
# Epoch 86/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8536 - accuracy: 0.2194 - val_loss: 2.7526 - val_accuracy: 2.6357e-04
# Epoch 87/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8544 - accuracy: 0.2188 - val_loss: 2.8137 - val_accuracy: 0.0011
# Epoch 88/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8530 - accuracy: 0.2194 - val_loss: 2.8003 - val_accuracy: 0.0018
# Epoch 89/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8535 - accuracy: 0.2196 - val_loss: 2.7921 - val_accuracy: 2.6357e-04
# Epoch 90/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8545 - accuracy: 0.2190 - val_loss: 2.7892 - val_accuracy: 0.0018
# Epoch 91/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8550 - accuracy: 0.2180 - val_loss: 2.7659 - val_accuracy: 0.0000e+00
# Epoch 92/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8536 - accuracy: 0.2185 - val_loss: 2.7596 - val_accuracy: 0.0018
# Epoch 93/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8541 - accuracy: 0.2211 - val_loss: 2.7729 - val_accuracy: 0.0018
# Epoch 94/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8533 - accuracy: 0.2208 - val_loss: 2.8168 - val_accuracy: 2.6357e-04
# Epoch 95/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8543 - accuracy: 0.2197 - val_loss: 2.7698 - val_accuracy: 2.6357e-04
# Epoch 96/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8528 - accuracy: 0.2200 - val_loss: 2.7860 - val_accuracy: 0.0021
# Epoch 97/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8533 - accuracy: 0.2198 - val_loss: 2.7884 - val_accuracy: 2.6357e-04
# Epoch 98/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8550 - accuracy: 0.2173 - val_loss: 2.7680 - val_accuracy: 7.9072e-04
# Epoch 99/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8539 - accuracy: 0.2186 - val_loss: 2.7956 - val_accuracy: 2.6357e-04
# Epoch 100/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8533 - accuracy: 0.2202 - val_loss: 2.7890 - val_accuracy: 0.0013
# Epoch 101/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8531 - accuracy: 0.2208 - val_loss: 2.7937 - val_accuracy: 0.0018
# Epoch 102/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8525 - accuracy: 0.2168 - val_loss: 2.7331 - val_accuracy: 2.6357e-04
# Epoch 103/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8541 - accuracy: 0.2190 - val_loss: 2.7442 - val_accuracy: 2.6357e-04
# Epoch 104/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8526 - accuracy: 0.2185 - val_loss: 2.7811 - val_accuracy: 0.0011
# Epoch 105/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8530 - accuracy: 0.2199 - val_loss: 2.7768 - val_accuracy: 0.0011
# Epoch 106/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8521 - accuracy: 0.2192 - val_loss: 2.7792 - val_accuracy: 0.0011
# Epoch 107/120
# 119/119 [==============================] - 2s 16ms/step - loss: 1.8529 - accuracy: 0.2184 - val_loss: 2.7543 - val_accuracy: 0.0011
# Epoch 108/120
# 119/119 [==============================] - 2s 14ms/step - loss: 1.8519 - accuracy: 0.2207 - val_loss: 2.8221 - val_accuracy: 0.0021
# Epoch 109/120
# 119/119 [==============================] - 1s 9ms/step - loss: 1.8526 - accuracy: 0.2184 - val_loss: 2.7483 - val_accuracy: 2.6357e-04
# Epoch 110/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8530 - accuracy: 0.2200 - val_loss: 2.7587 - val_accuracy: 2.6357e-04
# Epoch 111/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8525 - accuracy: 0.2182 - val_loss: 2.7704 - val_accuracy: 0.0000e+00
# Epoch 112/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8518 - accuracy: 0.2207 - val_loss: 2.7609 - val_accuracy: 7.9072e-04
# Epoch 113/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8517 - accuracy: 0.2198 - val_loss: 2.8064 - val_accuracy: 0.0011
# Epoch 114/120
# 119/119 [==============================] - 1s 11ms/step - loss: 1.8525 - accuracy: 0.2174 - val_loss: 2.7528 - val_accuracy: 2.6357e-04
# Epoch 115/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8517 - accuracy: 0.2207 - val_loss: 2.7888 - val_accuracy: 2.6357e-04
# Epoch 116/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8526 - accuracy: 0.2180 - val_loss: 2.8099 - val_accuracy: 0.0021
# Epoch 117/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8525 - accuracy: 0.2188 - val_loss: 2.7651 - val_accuracy: 2.6357e-04
# Epoch 118/120
# 119/119 [==============================] - 2s 15ms/step - loss: 1.8522 - accuracy: 0.2209 - val_loss: 2.8099 - val_accuracy: 0.0018
# Epoch 119/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8524 - accuracy: 0.2182 - val_loss: 2.7761 - val_accuracy: 0.0018
# Epoch 120/120
# 119/119 [==============================] - 1s 10ms/step - loss: 1.8523 - accuracy: 0.2187 - val_loss: 2.7616 - val_accuracy: 7.9072e-04
# 30/30 [==============================] - 2s 3ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy = 0.17678381256656017
# Precision = 0.12346959296691339
# Recall = 0.17678381256656017
# F1 Score = 0.10728187530687777

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# 1. Make predictions with each model and convert them to integers
dt_predictions = dt_clf.predict(Vx).astype(int)
rf_predictions = rf_clf.predict(Vx).astype(int)
ada_predictions = ada_clf.predict(Vx).astype(int)
gb_predictions = gb_clf.predict(Vx).astype(int)
knn_predictions = knn.predict(Vx).astype(int)





lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)


lstm_probs = np.argmax(lstm_probs, axis=1)
bilstm_probs = np.argmax(bilstm_probs, axis=1)


# 2. Aggregate predictions for hard voting
predictions = np.array([dt_predictions, rf_predictions, ada_predictions, gb_predictions, knn_predictions,lstm_probs,bilstm_probs])

# 3. Perform hard voting
hard_votes = np.apply_along_axis(lambda x: np.bincount(x, minlength=len(np.unique(predictions))).argmax(), arr=predictions, axis=0)

# 4. Evaluate hard voting ensemble
hard_voting_accuracy = np.mean(hard_votes == Vy)
print("Hard Voting Accuracy:", hard_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, hard_votes, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, hard_votes, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, hard_votes, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step
# Hard Voting Accuracy: 0.3343982960596379
# Precision: 0.33751312539793965
# Recall: 0.3343982960596379
# F1 Score: 0.3283686309912158

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
dt_probs = dt_clf.predict_proba(Vx)
rf_probs = rf_clf.predict_proba(Vx)
ada_probs = ada_clf.predict_proba(Vx)
gb_probs = gb_clf.predict_proba(Vx)
knn_probs = knn.predict_proba(Vx)


lstm_probs= lstm.predict(X_test_reshaped)
bilstm_probs=bilstm.predict(X_test_reshaped)




# KNN should already be able to predict probabilities, but if not, adjustments might be needed.

# 2. Aggregate probabilities for soft voting
probabilities = np.array([dt_probs, rf_probs, ada_probs, gb_probs,knn_probs,lstm_probs,bilstm_probs])

# 3. Perform soft voting
soft_votes = np.mean(probabilities, axis=0)

# 4. Determine the final prediction based on the highest probability
soft_voting_predictions = np.argmax(soft_votes, axis=1)

# 5. Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy:", soft_voting_accuracy)



# Calculate Precision
precision = precision_score(Vy, soft_voting_predictions, average='weighted')
print("Precision:", precision)

# Calculate Recall
recall = recall_score(Vy, soft_voting_predictions, average='weighted')
print("Recall:", recall)

# Calculate F1 Score
f1 = f1_score(Vy, soft_voting_predictions, average='weighted')
print("F1 Score:", f1)
# Out:
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 11ms/step
# Soft Voting Accuracy: 0.8242811501597445
# Precision: 0.8295611840760729
# Recall: 0.8242811501597445
# F1 Score: 0.8169353991058335

# %%
# Combine all soft predictions



all_soft_predictions = np.mean(np.array([
    dt_probs, rf_probs, ada_probs, gb_probs,  # Assuming these models provide class probabilities
    lstm_probs, bilstm_probs
]), axis=0)

# Perform soft voting
soft_voting_predictions = np.argmax(all_soft_predictions, axis=1)

# Evaluate soft voting ensemble
soft_voting_accuracy = np.mean(soft_voting_predictions == Vy)
print("Soft Voting Accuracy with LSTM and Bi-LSTM:", soft_voting_accuracy)
# Out:
# Soft Voting Accuracy with LSTM and Bi-LSTM: 0.8008519701810437
